# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load performance log CSV files for both models
perfect_csv_file = 'new_learned_perfect_model_performance_log.csv'
imperfect_csv_file = 'new_learned_imperfect_model_performance_log.csv'

# Read the data for both models
perfect_data = pd.read_csv(perfect_csv_file)
imperfect_data = pd.read_csv(imperfect_csv_file)
# inference_perfect_test = pd.read_csv("perfect_inference_model_performance_log.csv")
# inference_imperfect_test = pd.read_csv("imperfect_inference_model_performance_log.csv")

# inference_imperfect = inference_imperfect_test.iloc[:10]
# inference_perfect = inference_perfect_test.iloc[:10]
# Convert dates to datetime format if needed
perfect_data['Date'] = pd.to_datetime(perfect_data['Date'])
imperfect_data['Date'] = pd.to_datetime(imperfect_data['Date'])

# gt_r = pd.read_csv('GT_performance_log.csv')
# gt = gt_r
plt.figure(figsize=(8, 8))


# Plot Training Time vs. Train Size for both models
plt.subplot(3,1,1)
plt.title("Interception Success Rate Over Varying Distance Thresholds")
plt.plot(perfect_data['interception_threshold'], perfect_data['Interception Success Rate'], marker='o', linestyle='-', label='Perfect Information', color='blue')
plt.xlabel('Distance Threshold')
plt.ylabel('Interception Success Rate')
plt.legend()
plt.grid()



# Adjust layout for readability
# plt.tight_layout()
# plt.show()

# plt.figure(figsize=(8, 4))


# Plot Training Time vs. Train Size for both models
plt.subplot(3,1,2)
plt.plot(imperfect_data['interception_threshold'], imperfect_data['Interception Success Rate'], marker='o', linestyle='--', color='red', label='Imperfect Information')
plt.xlabel('Distance Threshold')
plt.ylabel('Interception Success Rate')
plt.legend()
plt.grid()



# Adjust layout for readability
plt.tight_layout()
plt.show()




# # Plot MSE vs. Train Size for both models with a secondary y-axis
# plt.figure(figsize=(14, 8))

# # Create figure and axis for the MSE plot
# fig, ax1 = plt.subplots()

# # Plot for perfect model (primary axis)
# ax1.plot(perfect_data['interception_threshold'], perfect_data['Interception Success Rate'], marker='o', linestyle='-', label='Perfect Information', color='blue')
# ax1.set_xlabel('Training Dataset Size')
# ax1.set_ylabel('Mean Squared Error (MSE) - Perfect Info', color='blue')
# ax1.tick_params(axis='y', labelcolor='blue')
# ax1.grid()

# # Create secondary y-axis for the imperfect model
# ax2 = ax1.twinx()
# ax2.plot(imperfect_data['interception_threshold'], imperfect_data['Interception Success Rate'], marker='o', linestyle='--', color='red', label='Imperfect Information')
# ax2.set_ylabel('Mean Squared Error (MSE) - Imperfect Info', color='red')
# ax2.tick_params(axis='y', labelcolor='red')

# # Title and layout
# plt.title('Model Performance (MSE) vs. Training Dataset Size')
# ax1.legend(loc='upper left')
# ax2.legend(loc='upper right')

# # Adjust layout for readability
# plt.tight_layout()
# plt.show()

# # Plot Training Time vs. Train Size for both models
# plt.subplot(3, 1, 2)
# plt.plot(perfect_data['Train Size'], perfect_data['Train Time (s)'], marker='o', linestyle='-', label='Perfect Information', color='orange')
# plt.plot(imperfect_data['Train Size'], imperfect_data['Train Time (s)'], marker='o', linestyle='--', color='purple', label='Imperfect Information')
# plt.xlabel('Training Dataset Size')
# plt.ylabel('Training Time (s)')
# plt.legend()
# plt.grid()



# # Adjust layout for readability
# plt.tight_layout()
# plt.show()

# # Plot Inference Time vs. Train Size for both models
# plt.subplot(3, 1, 3)
# plt.plot(inference_perfect['Test Size'], inference_perfect['Inference Time (s)'], marker='o', linestyle='-', label='Perfect Information', color='green')
# plt.plot(inference_imperfect['Test Size'], inference_imperfect['Inference Time (s)'], marker='o', linestyle='--', color='blue', label='Imperfect Information')
# plt.xlabel('Test Dataset Size')
# plt.ylabel('Inference Time (s)')
# plt.legend()
# plt.grid()

# Adjust layout for readability
plt.tight_layout()
plt.show()
