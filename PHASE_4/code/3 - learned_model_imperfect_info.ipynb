# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pgmpy.models import BayesianNetwork, LinearGaussianBayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator, ExpectationMaximization, BayesianEstimator
from pgmpy.estimators import HillClimbSearch, BicScore, K2Score, BDsScore
import matplotlib.pyplot as plt
from pgmpy.inference import VariableElimination
import networkx as nx

# %%
def visualise(model, pos, projectile_color="skyblue", interceptor_color="lightcoral"):
    edges = model.edges()

    # Create separate lists for intra-time slice and inter-time slice edges
    intra_time_slice_edges = []
    inter_time_slice_edges = []

    for edge in edges:
        if abs(int(edge[0][-1]) - int(edge[1][-1])) == 0:
            intra_time_slice_edges.append(edge)
        else:
            inter_time_slice_edges.append(edge)

    # Create a directed graph object
    G = nx.DiGraph()

    # Add edges to the graph
    G.add_edges_from(edges)

    # Create a color map based on node type
    color_map = []
    for node in G.nodes():
        if "FP" in node:
            color_map.append("gray")
        elif "P" == node[0]:
            color_map.append(projectile_color)
        elif "I_" in node:
            color_map.append(interceptor_color)
        else:
            color_map.append("gray")  # Default color for any other nodes

    # Plot the graph with custom positions and colors
    plt.figure(figsize=(20, 12))

    # Draw edges first to ensure arrowheads are not covered
    nx.draw_networkx_edges(
        G, pos, edgelist=intra_time_slice_edges, arrows=True,
        edge_color='black', style='solid', arrowsize=15, arrowstyle='-|>',
        min_source_margin=10, min_target_margin=15  # Increase margins to make arrows shorter
    )

    nx.draw_networkx_edges(
        G, pos, edgelist=inter_time_slice_edges, arrows=True,
        edge_color='black', style=(0, (5, 10)), arrowsize=15, arrowstyle='-|>',
        min_source_margin=10, min_target_margin=15  # Increase margins to make arrows shorter
    )

    # Draw nodes after edges
    nx.draw_networkx_nodes(G, pos, node_size=1000, node_color=color_map)

    nx.draw_networkx_labels(G, pos, font_size=8, font_weight="bold")

    plt.title("Bayesian Network Graph")
    plt.show()

# %%
# Define positions manually for x and y positions
pos = {}

for i in range(6):
    if i % 2 == 0:
        # Projectile nodes positions (lower row)
        pos[f'P_FP_x{i}'] = (i * 3 - 1 - 1, 0)          # Final position x
        pos[f'P_FP_y{i}'] = (i * 3 - 1, 0)              # Final position y
        pos[f'P_V{i}'] = (i * 3 + 1 - 1, -1)            # Velocity
        pos[f'P_IP_x{i}'] = (i * 3 - 1 - 1, -1)         # Initial position x
        pos[f'P_IP_y{i}'] = (i * 3 - 1, -1)             # Initial position y

        # Interceptor nodes positions (upper row)
        pos[f'I_FP_x{i}'] = (i * 3 - 1, 3)          # Final position x
        pos[f'I_FP_y{i}'] = (i * 3, 3)              # Final position y
        pos[f'I_V{i}'] = (i * 3 + 1, 2)             # Velocity
        pos[f'I_IP_x{i}'] = (i * 3 - 1, 2)          # Initial position x
        pos[f'I_IP_y{i}'] = (i * 3, 2)              # Initial position y
    else:
        # Projectile nodes positions (lower row)
        pos[f'P_FP_x{i}'] = (i * 3 - 1 - 1, -1)         # Final position x
        pos[f'P_FP_y{i}'] = (i * 3 - 1, -1)             # Final position y
        pos[f'P_V{i}'] = (i * 3 + 1 - 1, -2)            # Velocity
        pos[f'P_IP_x{i}'] = (i * 3 - 1 - 1, -2)         # Initial position x
        pos[f'P_IP_y{i}'] = (i * 3 - 1, -2)             # Initial position y

        # Interceptor nodes positions (upper row)
        pos[f'I_FP_x{i}'] = (i * 3 - 1, 4)          # Final position x
        pos[f'I_FP_y{i}'] = (i * 3, 4)              # Final position y
        pos[f'I_V{i}'] = (i * 3 + 1, 3)             # Velocity
        pos[f'I_IP_x{i}'] = (i * 3 - 1, 3)          # Initial position x
        pos[f'I_IP_y{i}'] = (i * 3, 3)              # Initial position y

# %%
from pgmpy.factors.continuous import LinearGaussianCPD
from pgmpy.models import LinearGaussianBayesianNetwork

# Initialize the Bayesian Network model
GT = LinearGaussianBayesianNetwork()

for i in range(6):
    # Add nodes for final position (FP), velocity (V), and initial position (IP)
    GT.add_nodes_from([
        f'P_FP_x{i}', f'P_FP_y{i}', f'P_V{i}', f'P_IP_x{i}', f'P_IP_y{i}',  # Projectile nodes
        f'I_FP_x{i}', f'I_FP_y{i}', f'I_V{i}', f'I_IP_x{i}', f'I_IP_y{i}'   # Interceptor nodes
    ])
    
    # Add edges within each time slice for both x and y positions
    GT.add_edges_from([
        (f'P_FP_x{i}' , f'P_IP_x{i}'),  # Initial position (x) influences final position (x)
        (f'P_FP_x{i}' , f'P_V{i}'),     # Velocity influences final position (x)
        (f'P_FP_y{i}' , f'P_IP_y{i}'),  # Initial position (y) influences final position (y)
        (f'P_FP_y{i}', f'P_V{i}'),     # Velocity influences final position (y)
        
        (f'I_FP_x{i}' , f'I_IP_x{i}'),  # Interceptor: Initial position (x) influences final position (x)
        (f'I_FP_x{i}' , f'I_V{i}'),     # Velocity influences final position (x)
        (f'I_FP_y{i}' , f'I_IP_y{i}'),  # Initial position (y) influences final position (y)
        (f'I_FP_y{i}' , f'I_V{i}')      # Velocity influences final position (y)
    ])

    if i < 5:
        # Connect corresponding nodes between time slices for projectile and interceptor
        GT.add_edges_from([
            # Projectile time slice connections for x and y positions
            (f'P_FP_x{i}', f'P_FP_x{i + 1}'),
            (f'P_IP_x{i}', f'P_IP_x{i + 1}'),
            (f'P_FP_y{i}', f'P_FP_y{i + 1}'),
            (f'P_IP_y{i}', f'P_IP_y{i + 1}'),
            (f'P_V{i}', f'P_V{i + 1}'),

            # Interceptor time slice connections for x and y positions
            (f'I_FP_x{i}', f'I_FP_x{i + 1}'),
            (f'I_IP_x{i}', f'I_IP_x{i + 1}'),
            (f'I_FP_y{i}', f'I_FP_y{i + 1}'),
            (f'I_IP_y{i}', f'I_IP_y{i + 1}'),
            (f'I_V{i}', f'I_V{i + 1}')
        ])
        
        # Edge between projectile and interceptor across time slices
        GT.add_edges_from([
            (f'P_FP_x{i + 1}', f'I_FP_x{i}'),
            (f'P_FP_y{i + 1}', f'I_FP_y{i}')
        ])

# Final edges to ensure convergence at the last time slice
GT.add_edges_from([
    (f'P_FP_x{5}', f'I_FP_x{5}'),
    (f'P_FP_y{5}', f'I_FP_y{5}')
])


visualise(GT, pos)

# %%
def fit_cpd_for_node(node, parents, data):
    required_columns = [node] + parents

    # Ensure all required columns are in the data
    missing_columns = [col for col in required_columns if col not in data.columns]
    if missing_columns:
        raise KeyError(f"Missing columns in data: {missing_columns}")
    
    # Creating the correct column names and structure for fitting
    node_data_before = data[required_columns].copy()
    node_data_before.columns = ["(Y|X)" if col == node else col for col in node_data_before.columns]

    # Add noise to all 0.0 values in the DataFrame
    noise_std = 1e-5 
    node_data = node_data_before.map(lambda x: x + np.random.normal(0, noise_std) if x == 0.0 else x)

    print("Fitting CPD for node:", node)
    print("Parents:", parents)
    print("Data being used for fit:")
    print(node_data.head())  # Print the first few rows of node_data

    if parents:
        # Initialize a Linear Gaussian CPD object
        cpd = LinearGaussianCPD(
            variable=node,
            evidence_mean=[0] * (len(parents) + 1),  # Initial guess for betas
            evidence_variance=1,  # Initial variance guess
            evidence=parents
        )
        
        node = "(Y|X)"
        print(f"Node: {node} \n")
        print("-"*50)
        # Fit the CPD using MLE
        beta, variance = cpd.fit(node_data, states=[node] + parents, estimator="MLE")
        return cpd
    else:
        # If no parents, fit a univariate Gaussian
        mean = data[node].mean()
        variance = data[node].var()
        return LinearGaussianCPD(variable=node, evidence_mean=[mean], evidence_variance=variance)




data = pd.read_csv('trajectory_data.csv')

# Assuming you have a pandas DataFrame `data` with all necessary columns.
for i in range(6):
    if i == 0:
        # Fit Projectile CPDs for x and y positions
        # cpd_P_FP_x = fit_cpd_for_node(f'P_FP_x{i}', [], data)
        # cpd_P_FP_y = fit_cpd_for_node(f'P_FP_y{i}', [], data)
        cpd_P_V = fit_cpd_for_node(f'P_V{i}', [f'P_FP_x{i}', f'P_FP_y{i}'], data)
        cpd_P_IP_x = fit_cpd_for_node(f'P_IP_x{i}', [f'P_FP_x{i}'], data)
        cpd_P_IP_y = fit_cpd_for_node(f'P_IP_y{i}', [f'P_FP_y{i}'], data)
    else:
        # Fit Projectile CPDs for x and y positions
        # cpd_P_FP_x = fit_cpd_for_node(f'P_FP_x{i}', [f'P_FP_x{i - 1}'], data)
        # cpd_P_FP_y = fit_cpd_for_node(f'P_FP_y{i}', [f'P_FP_y{i - 1}'], data)
        cpd_P_V = fit_cpd_for_node(f'P_V{i}', [f'P_V{i - 1}',f'P_FP_x{i}', f'P_FP_y{i}'], data)
        cpd_P_IP_x = fit_cpd_for_node(f'P_IP_x{i}', [f'P_FP_x{i}', f'P_IP_x{i - 1}'], data)
        cpd_P_IP_y = fit_cpd_for_node(f'P_IP_y{i}', [f'P_FP_y{i}', f'P_IP_y{i - 1}'], data)

    # Add fitted CPDs to the network
    # GT.add_cpds(cpd_P_FP_x, cpd_P_FP_y, cpd_P_V, cpd_P_IP_x, cpd_P_IP_y)
    GT.add_cpds(cpd_P_V, cpd_P_IP_x, cpd_P_IP_y)

# Fit and add Interceptor CPDs
for i in range(6):
    if i == 0:
        # cpd_I_FP_x = fit_cpd_for_node(f'I_FP_x{i}', [f'P_FP_x{i+1}'], data)
        # cpd_I_FP_y = fit_cpd_for_node(f'I_FP_y{i}', [f'P_FP_y{i+1}'], data)
        cpd_I_V = fit_cpd_for_node(f'I_V{i}', [f'I_FP_x{i}', f'I_FP_y{i}'], data)
        cpd_I_IP_x = fit_cpd_for_node(f'I_IP_x{i}', [f'I_FP_x{i}'], data)
        cpd_I_IP_y = fit_cpd_for_node(f'I_IP_y{i}', [f'I_FP_y{i}'], data)
    else:
        # if i < 5:
            # cpd_I_FP_x = fit_cpd_for_node(f'I_FP_x{i}', [f'P_FP_x{i+1}', f'I_FP_x{i - 1}'], data)
            # cpd_I_FP_y = fit_cpd_for_node(f'I_FP_y{i}', [f'P_FP_y{i+1}', f'I_FP_y{i - 1}'], data)
        # else:
            # cpd_I_FP_x = fit_cpd_for_node(f'I_FP_x{i}', [f'I_FP_x{i - 1}', f'P_FP_x{i}'], data)
            # cpd_I_FP_y = fit_cpd_for_node(f'I_FP_y{i}', [f'I_FP_y{i - 1}', f'P_FP_y{i}'], data)

        cpd_I_V = fit_cpd_for_node(f'I_V{i}', [f'I_V{i - 1}',f'I_FP_x{i}',  f'I_FP_y{i}'], data)
        cpd_I_IP_x = fit_cpd_for_node(f'I_IP_x{i}', [f'I_FP_x{i}', f'I_IP_x{i - 1}'], data)
        cpd_I_IP_y = fit_cpd_for_node(f'I_IP_y{i}', [f'I_FP_y{i}', f'I_IP_y{i - 1}'], data)

    # Add fitted CPDs to the network
    # GT.add_cpds(cpd_I_FP_x, cpd_I_FP_y, cpd_I_V, cpd_I_IP_x, cpd_I_IP_y)
    GT.add_cpds(cpd_I_V, cpd_I_IP_x, cpd_I_IP_y)
# Out:
# Fitting CPD for node: P_V0
# Parents: ['P_FP_x0', 'P_FP_y0']
# Data being used for fit:
#        (Y|X)      P_FP_x0     P_FP_y0
# 0  24.296249  1030.007957   96.452990
# 1  17.317176   990.829499   86.778022
# 2  17.776180   978.458301  102.172884
# 3  19.180031  1006.994604  112.596307
# 4  18.237178  1024.530141   94.148815
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x0
# Parents: ['P_FP_x0']
# Data being used for fit:
#         (Y|X)      P_FP_x0
# 0  113.175616  1030.007957
# 1 -190.926838   990.829499
# 2 -206.153411   978.458301
# 3  174.406588  1006.994604
# 4  161.914609  1024.530141
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y0
# Parents: ['P_FP_y0']
# Data being used for fit:
#           (Y|X)     P_FP_y0
# 0  6.629772e-06   96.452990
# 1 -5.626788e-06   86.778022
# 2  2.516703e-06  102.172884
# 3  6.315374e-06  112.596307
# 4 -6.205983e-07   94.148815
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V1
# Parents: ['P_V0', 'P_FP_x1', 'P_FP_y1']
# Data being used for fit:
#         (Y|X)       P_V0      P_FP_x1     P_FP_y1
# 0  261.672524  24.296249  1943.721839  254.860120
# 1  252.033947  17.317176  1871.773245  238.170054
# 2  254.039698  17.776180  1875.489253  261.852781
# 3  257.009547  19.180031  1881.695238  272.499692
# 4  258.815707  18.237178  1915.095547  268.731536
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x1
# Parents: ['P_FP_x1', 'P_IP_x0']
# Data being used for fit:
#          (Y|X)      P_FP_x1     P_IP_x0
# 0  1028.652262  1943.721839  113.175616
# 1   836.385958  1871.773245 -190.926838
# 2   833.106150  1875.489253 -206.153411
# 3  1031.200672  1881.695238  174.406588
# 4  1037.058583  1915.095547  161.914609
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y1
# Parents: ['P_FP_y1', 'P_IP_y0']
# Data being used for fit:
#         (Y|X)     P_FP_y1   P_IP_y0
# 0  147.313434  254.860120  0.000002
# 1  114.210141  238.170054 -0.000006
# 2  152.308742  261.852781 -0.000006
# 3  140.567219  272.499692  0.000003
# 4  129.514921  268.731536 -0.000002
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V2
# Parents: ['P_V1', 'P_FP_x2', 'P_FP_y2']
# Data being used for fit:
#         (Y|X)        P_V1      P_FP_x2     P_FP_y2
# 0  599.088135  261.672524  2774.280551  431.440483
# 1  579.245552  252.033947  2693.182044  400.131676
# 2  583.621300  254.039698  2698.506142  426.786159
# 3  591.092259  257.009547  2721.024408  435.996889
# 4  598.259433  258.815707  2762.535530  421.067015
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x2
# Parents: ['P_FP_x2', 'P_IP_x1']
# Data being used for fit:
#          (Y|X)      P_FP_x2      P_IP_x1
# 0  1902.286250  2774.280551  1028.652262
# 1  1762.757148  2693.182044   836.385958
# 2  1766.142649  2698.506142   833.106150
# 3  1877.751960  2721.024408  1031.200672
# 4  1899.377596  2762.535530  1037.058583
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y2
# Parents: ['P_FP_y2', 'P_IP_y1']
# Data being used for fit:
#         (Y|X)     P_FP_y2     P_IP_y1
# 0  308.005787  431.440483  147.313434
# 1  248.739491  400.131676  114.210141
# 2  272.996590  426.786159  152.308742
# 3  264.736598  435.996889  140.567219
# 4  274.625050  421.067015  129.514921
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V3
# Parents: ['P_V2', 'P_FP_x3', 'P_FP_y3']
# Data being used for fit:
#          (Y|X)        P_V2      P_FP_x3     P_FP_y3
# 0  1023.782714  599.088135  3501.219055  581.583879
# 1  1002.408388  579.245552  3476.878565  526.617617
# 2  1006.679585  583.621300  3474.739373  525.667513
# 3  1021.148289  591.092259  3492.320923  606.102009
# 4  1028.453505  598.259433  3520.930086  563.041430
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x3
# Parents: ['P_FP_x3', 'P_IP_x2']
# Data being used for fit:
#          (Y|X)      P_FP_x3      P_IP_x2
# 0  2701.323073  3501.219055  1902.286250
# 1  2618.837980  3476.878565  1762.757148
# 2  2621.528105  3474.739373  1766.142649
# 3  2685.063179  3492.320923  1877.751960
# 4  2708.405303  3520.930086  1899.377596
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y3
# Parents: ['P_FP_y3', 'P_IP_y2']
# Data being used for fit:
#         (Y|X)     P_FP_y3     P_IP_y2
# 0  448.767502  581.583879  308.005787
# 1  398.671275  526.617617  248.739491
# 2  386.458509  525.667513  272.996590
# 3  463.613645  606.102009  264.736598
# 4  445.964411  563.041430  274.625050
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V4
# Parents: ['P_V3', 'P_FP_x4', 'P_FP_y4']
# Data being used for fit:
#          (Y|X)         P_V3      P_FP_x4     P_FP_y4
# 0  1526.085906  1023.782714  4237.360875  618.264423
# 1  1501.189612  1002.408388  4183.317807  585.513861
# 2  1506.610640  1006.679585  4184.394704  647.594745
# 3  1527.534698  1021.148289  4186.642021  669.225503
# 4  1533.530007  1028.453505  4209.758548  647.617381
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x4
# Parents: ['P_FP_x4', 'P_IP_x3']
# Data being used for fit:
#          (Y|X)      P_FP_x4      P_IP_x3
# 0  3467.800369  4237.360875  2701.323073
# 1  3397.601685  4183.317807  2618.837980
# 2  3404.855185  4184.394704  2621.528105
# 3  3436.507241  4186.642021  2685.063179
# 4  3457.072284  4209.758548  2708.405303
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y4
# Parents: ['P_FP_y4', 'P_IP_y3']
# Data being used for fit:
#         (Y|X)     P_FP_y4     P_IP_y3
# 0  577.556681  618.264423  448.767502
# 1  487.383505  585.513861  398.671275
# 2  515.027302  647.594745  386.458509
# 3  605.491663  669.225503  463.613645
# 4  558.289341  647.617381  445.964411
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V5
# Parents: ['P_V4', 'P_FP_x5', 'P_FP_y5']
# Data being used for fit:
#          (Y|X)         P_V4      P_FP_x5     P_FP_y5
# 0  2097.706694  1526.085906  4868.613187  638.247135
# 1  2064.019989  1501.189612  4857.490281  575.569707
# 2  2079.325415  1506.610640  4854.931949  654.648254
# 3  2094.800053  1527.534698  4840.107578  656.492499
# 4  2104.035758  1533.530007  4898.570916  637.570838
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x5
# Parents: ['P_FP_x5', 'P_IP_x4']
# Data being used for fit:
#          (Y|X)      P_FP_x5      P_IP_x4
# 0  4165.428189  4868.613187  3467.800369
# 1  4126.791797  4857.490281  3397.601685
# 2  4130.895212  4854.931949  3404.855185
# 3  4137.352116  4840.107578  3436.507241
# 4  4179.060045  4898.570916  3457.072284
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y5
# Parents: ['P_FP_y5', 'P_IP_y4']
# Data being used for fit:
#         (Y|X)     P_FP_y5     P_IP_y4
# 0  627.875046  638.247135  577.556681
# 1  530.656362  575.569707  487.383505
# 2  591.531078  654.648254  515.027302
# 3  635.702780  656.492499  605.491663
# 4  623.079315  637.570838  558.289341
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V0
# Parents: ['I_FP_x0', 'I_FP_y0']
# Data being used for fit:
#        (Y|X)      I_FP_x0     I_FP_y0
# 0  20.065682  8902.944359  116.140181
# 1  23.431355  8951.243979  128.801542
# 2  21.990533  9164.669277  119.117933
# 3  18.104066  8942.783227  114.312762
# 4  18.794881  9363.880685  147.298692
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x0
# Parents: ['I_FP_x0']
# Data being used for fit:
#           (Y|X)      I_FP_x0
# 0  10013.190544  8902.944359
# 1   9952.424429  8951.243979
# 2  10098.404759  9164.669277
# 3  10016.734279  8942.783227
# 4   9971.329335  9363.880685
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y0
# Parents: ['I_FP_y0']
# Data being used for fit:
#       (Y|X)     I_FP_y0
# 0 -0.000015  116.140181
# 1  0.000009  128.801542
# 2  0.000010  119.117933
# 3  0.000004  114.312762
# 4 -0.000001  147.298692
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V1
# Parents: ['I_V0', 'I_FP_x1', 'I_FP_y1']
# Data being used for fit:
#         (Y|X)       I_V0      I_FP_x1     I_FP_y1
# 0  883.003139  20.065682  8109.541298  301.607601
# 1  888.772899  23.431355  8197.228683  295.029898
# 2  892.195505  21.990533  8210.445648  290.900603
# 3  888.164151  18.104066  8195.797840  286.326853
# 4  887.378066  18.794881  8184.566610  281.248557
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x1
# Parents: ['I_FP_x1', 'I_IP_x0']
# Data being used for fit:
#          (Y|X)      I_FP_x1       I_IP_x0
# 0  9059.291658  8109.541298  10013.190544
# 1  9054.365340  8197.228683   9952.424429
# 2  9194.096666  8210.445648  10098.404759
# 3  9104.531924  8195.797840  10016.734279
# 4  9068.017606  8184.566610   9971.329335
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y1
# Parents: ['I_FP_y1', 'I_IP_y0']
# Data being used for fit:
#         (Y|X)     I_FP_y1       I_IP_y0
# 0  141.163196  301.607601  5.016847e-06
# 1  141.474925  295.029898 -4.463720e-06
# 2  131.794231  290.900603 -1.597366e-05
# 3  154.740090  286.326853  3.011577e-07
# 4  143.295075  281.248557 -3.453649e-06
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V2
# Parents: ['I_V1', 'I_FP_x2', 'I_FP_y2']
# Data being used for fit:
#          (Y|X)        I_V1      I_FP_x2     I_FP_y2
# 0  1674.967505  883.003139  7294.114400  433.668941
# 1  1684.801100  888.772899  7350.312378  416.639692
# 2  1691.164258  892.195505  7352.464242  419.416962
# 3  1687.486016  888.164151  7336.473999  463.582517
# 4  1682.195038  887.378066  7298.572111  451.463380
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x2
# Parents: ['I_FP_x2', 'I_IP_x1']
# Data being used for fit:
#          (Y|X)      I_FP_x2      I_IP_x1
# 0  8157.588046  7294.114400  9059.291658
# 1  8211.736955  7350.312378  9054.365340
# 2  8292.350276  7352.464242  9194.096666
# 3  8215.581830  7336.473999  9104.531924
# 4  8168.171739  7298.572111  9068.017606
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y2
# Parents: ['I_FP_y2', 'I_IP_y1']
# Data being used for fit:
#         (Y|X)     I_FP_y2     I_IP_y1
# 0  289.031966  433.668941  141.163196
# 1  259.083574  416.639692  141.474925
# 2  267.601327  419.416962  131.794231
# 3  301.627945  463.582517  154.740090
# 4  256.325809  451.463380  143.295075
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V3
# Parents: ['I_V2', 'I_FP_x3', 'I_FP_y3']
# Data being used for fit:
#          (Y|X)         I_V2      I_FP_x3     I_FP_y3
# 0  2399.606883  1674.967505  6502.395572  560.317542
# 1  2417.857548  1684.801100  6542.489393  550.178984
# 2  2420.306857  1691.164258  6547.270841  546.344017
# 3  2423.997084  1687.486016  6560.808550  580.783162
# 4  2412.835282  1682.195038  6528.555394  562.202186
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x3
# Parents: ['I_FP_x3', 'I_IP_x2']
# Data being used for fit:
#          (Y|X)      I_FP_x3      I_IP_x2
# 0  7332.497254  6502.395572  8157.588046
# 1  7353.070077  6542.489393  8211.736955
# 2  7407.394241  6547.270841  8292.350276
# 3  7386.449290  6560.808550  8215.581830
# 4  7337.915524  6528.555394  8168.171739
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y3
# Parents: ['I_FP_y3', 'I_IP_y2']
# Data being used for fit:
#         (Y|X)     I_FP_y3     I_IP_y2
# 0  395.468143  560.317542  289.031966
# 1  411.954169  550.178984  259.083574
# 2  406.165160  546.344017  267.601327
# 3  452.590104  580.783162  301.627945
# 4  437.962230  562.202186  256.325809
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V4
# Parents: ['I_V3', 'I_FP_x4', 'I_FP_y4']
# Data being used for fit:
#          (Y|X)         I_V3      I_FP_x4     I_FP_y4
# 0  3063.464507  2399.606883  5790.522995  622.856932
# 1  3072.081553  2417.857548  5780.213647  564.765012
# 2  3086.243684  2420.306857  5806.009869  656.998536
# 3  3092.883202  2423.997084  5865.206675  619.989317
# 4  3070.542759  2412.835282  5733.463186  619.570801
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x4
# Parents: ['I_FP_x4', 'I_IP_x3']
# Data being used for fit:
#          (Y|X)      I_FP_x4      I_IP_x3
# 0  6543.072218  5790.522995  7332.497254
# 1  6562.745441  5780.213647  7353.070077
# 2  6581.113804  5806.009869  7407.394241
# 3  6603.985940  5865.206675  7386.449290
# 4  6526.305801  5733.463186  7337.915524
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y4
# Parents: ['I_FP_y4', 'I_IP_y3']
# Data being used for fit:
#         (Y|X)     I_FP_y4     I_IP_y3
# 0  527.850221  622.856932  395.468143
# 1  493.561550  564.765012  411.954169
# 2  545.256150  656.998536  406.165160
# 3  495.484269  619.989317  452.590104
# 4  537.398905  619.570801  437.962230
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V5
# Parents: ['I_V4', 'I_FP_x5', 'I_FP_y5']
# Data being used for fit:
#          (Y|X)         I_V4      I_FP_x5     I_FP_y5
# 0  3638.933850  3063.464507  4890.954335  653.852569
# 1  3635.224079  3072.081553  4841.213934  622.825169
# 2  3663.554779  3086.243684  4867.355199  673.835060
# 3  3662.312675  3092.883202  4826.643477  635.711411
# 4  3651.205621  3070.542759  4921.566255  665.729139
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x5
# Parents: ['I_FP_x5', 'I_IP_x4']
# Data being used for fit:
#          (Y|X)      I_FP_x5      I_IP_x4
# 0  5706.989718  4890.954335  6543.072218
# 1  5706.654941  4841.213934  6562.745441
# 2  5748.239795  4867.355199  6581.113804
# 3  5696.488185  4826.643477  6603.985940
# 4  5712.695073  4921.566255  6526.305801
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y5
# Parents: ['I_FP_y5', 'I_IP_y4']
# Data being used for fit:
#         (Y|X)     I_FP_y5     I_IP_y4
# 0  590.354150  653.852569  527.850221
# 1  602.045989  622.825169  493.561550
# 2  618.219502  673.835060  545.256150
# 3  577.501499  635.711411  495.484269
# 4  559.112073  665.729139  537.398905
# Node: (Y|X)
#
# --------------------------------------------------

# %%
# Validation
if GT.check_model():
    print("The model is valid!")
else:
    print("The model is not valid. Please check the CPDs and network structure.")
# Out:
# The model is valid!

# %%
import pandas as pd
import numpy as np

# Load the test data
test_data = pd.read_csv("trajectory_test_data.csv")

def predict_with_linear_gaussian_cpd(evidence, cpd, current_node):
    """
    Predict values using a Linear Gaussian CPD.
    
    Parameters
    ----------
    evidence: dict
        Dictionary with observed values.
    cpd: LinearGaussianCPD
        The CPD object to use for prediction.
    
    Returns
    -------
    float
        Predicted value for the query variable.
    """
    # print(cpd)

    if cpd is None:
        # If the CPD is None and the node is an FP node, estimate using IP and velocity
        if current_node.startswith('P_FP') or current_node.startswith('I_FP'):
            # Extract the relevant time slice from the node name
            time_slice = int(current_node.split('x')[-1]) if 'x' in current_node else int(current_node.split('y')[-1])

            if time_slice == 0:

                # Use the initial position and velocity to estimate final position
                ip_x = evidence.get(f'P_IP_x{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_x{time_slice}', 0)
                ip_y = evidence.get(f'P_IP_y{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_y{time_slice}', 0)
                ip_x = max(ip_x,0)
                ip_y = max(ip_y,0)
                velocity = evidence.get(f'P_V{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_V{time_slice}', 0)



                # Estimate the final position (this estimation can be modified based on the motion model)
                # predicted_value = (200 + time_slice*900 if 'x' in current_node else 100*time_slice + 200) if current_node.startswith('P') else (10000 - time_slice*900 if 'x' in current_node else 100*time_slice + 200)
                predicted_value = (1.4*ip_x if 'x' in current_node else 100) if current_node.startswith('P') else (0.8*ip_x if 'x' in current_node else 100)
            else:
                # Use the initial position, velocity and previous final to estimate final position
                ip_x = evidence.get(f'P_IP_x{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_x{time_slice}', 0)
                ip_y = evidence.get(f'P_IP_y{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_y{time_slice}', 0)
                ip_x = max(ip_x,0)
                ip_y = max(ip_y,0)
                velocity = evidence.get(f'P_V{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_V{time_slice}', 0)
                fp_x = evidence.get(f'P_FP_x{time_slice - 1}', 0) if current_node.startswith('P') else evidence.get(f'I_FP_x{time_slice - 1}', 0)
                fp_y = evidence.get(f'P_FP_y{time_slice - 1}', 0) if current_node.startswith('P') else evidence.get(f'I_FP_y{time_slice - 1}', 0)
                ip_x = max(fp_x,0)
                ip_y = max(fp_y,0)

                # Estimate the final position (this estimation can be modified based on the motion model)
                # predicted_value = (200 + time_slice*900  if 'x' in current_node else 100*time_slice + 200) if current_node.startswith('P') else (10000 - time_slice*900 if 'x' in current_node else 100*time_slice + 200)
                predicted_value = (1.4*fp_x if 'x' in current_node else 1.4*fp_y) if current_node.startswith('P') else (0.8*fp_x if 'x' in current_node else 1.4*fp_y)

            if current_node.startswith('P'):
                print(f"Timeslice: {time_slice}")
                print(f"ip_x = {ip_x}" if 'x' in current_node else f"ip_y = {ip_y}")
                print(f"Estimate P = {predicted_value}")
            else:
                print(f"Timeslice: {time_slice}")
                print(f"ip_x = {ip_x}" if 'x' in current_node else f"ip_y = {ip_y}")
                print(f"Estimate I = {predicted_value}")

            return predicted_value
        else:
            # Return a fallback value if CPD is not fitted
            print(f"CPD not fitted for node. Returning default value.")
            return 0.0  # Replace with domain-specific default if needed

    if not hasattr(cpd, 'beta') or cpd.beta is None:
        # The node has no parents, return its mean value
        print(f"Node has no parents. Using mean for prediction.")
        return cpd.mean
    
    beta = cpd.beta
    mean_vector = cpd.mean
    variance = cpd.variance
    # print(f"Beta values: {beta}")
    # print(f"Mean vals: {mean_vector}")
    # print(f"Variance: {variance}")
    # print(f"Evidence required: {cpd.evidence}")
    evidence_vals = [evidence[var] for var in cpd.evidence]
    evidence_vals_array = np.array([val.flatten() if isinstance(val, np.ndarray) else [val] for val in evidence_vals])
    # print(f"Evidence vals: {evidence_vals_array}")
    # print(f"Coeffecients to be used: {beta[1:]}")
    predicted_mean = beta[0] + np.dot(
        evidence_vals_array.flatten(),
        beta[1:]
    )
    return predicted_mean

# List to store predictions for each row in test_data
predictions = []

# Iterate through each row in the test_data DataFrame
for index, row in test_data.iterrows():
    # Define initial evidence (time slice 0)
    evidence = {
        'P_IP_x0' : row['P_IP_x0'],   
        'P_IP_y0' : row['P_IP_y0'],   
        'P_V0'  : row['P_V0'],
        'I_IP_x0' : row['I_IP_x0'],    
        'I_IP_y0' : row['I_IP_y0'],
        'I_V0':  row['I_V0'],
    }
    
    # Empty dict to store predictions for this row
    row_predictions = {}

    # COMPLETING PREDICTION FOR FIRST TREE
 
    cpd_x = GT.get_cpds(f'P_FP_x0')
    cpd_y = GT.get_cpds(f'P_FP_y0')
    
    prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'P_FP_x0')
    evidence[f'P_FP_x0'] = prediction_x

    prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'P_FP_y0')
    evidence[f'P_FP_y0'] = prediction_y
    
    row_predictions[f'P_FP_x0'] = prediction_x
    row_predictions[f'P_FP_y0'] = prediction_y
    
    # Propagate predictions for multiple time slices
    for t in range(1,6):
        # Predict for time slice t using evidence from time slice t-1
        cpd_v = GT.get_cpds(f'P_V{t}')
        cpd_I_x = GT.get_cpds(f'P_IP_x{t}')
        cpd_I_y = GT.get_cpds(f'P_IP_y{t}')
        cpd_x = GT.get_cpds(f'P_FP_x{t}')
        cpd_y = GT.get_cpds(f'P_FP_y{t}')

        prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'P_FP_x{t}')
        evidence[f'P_FP_x{t}'] = prediction_x

        prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'P_FP_y{t}')
        evidence[f'P_FP_y{t}'] = prediction_y
        
        prediction_v = predict_with_linear_gaussian_cpd(evidence, cpd_v, f'P_V{t}')
        evidence[f'P_V{t}'] = prediction_v

        prediction_I_x = predict_with_linear_gaussian_cpd(evidence, cpd_I_x, f'P_IP_x{t}')
        evidence[f'P_IP_x{t}'] = prediction_I_x

        prediction_I_y = predict_with_linear_gaussian_cpd(evidence, cpd_I_y, f'P_IP_y{t}')
        evidence[f'P_IP_y{t}'] = prediction_I_y

        
        # Store the predictions for this time slice
        row_predictions[f'P_V{t}'] = prediction_v
        row_predictions[f'P_IP_x{t}'] = prediction_I_x
        row_predictions[f'P_IP_y{t}'] = prediction_I_y
        row_predictions[f'P_FP_x{t}'] = prediction_x
        row_predictions[f'P_FP_y{t}'] = prediction_y

        #INTERCEPTOR NODES
        if t == 1:
            prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'I_FP_x{t - 1}')
            evidence[f'I_FP_x{t - 1}'] = prediction_x

            prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'I_FP_y{t - 1}')
            evidence[f'I_FP_y{t - 1}'] = prediction_y

            row_predictions[f'I_FP_x{t - 1}'] = prediction_x
            row_predictions[f'I_FP_y{t - 1}'] = prediction_y
        elif t > 1 and t < 5:

            # Predict for time slice t using evidence from time slice t-1
            cpd_v = GT.get_cpds(f'I_V{t - 1}')
            cpd_I_x = GT.get_cpds(f'I_IP_x{t - 1}')
            cpd_I_y = GT.get_cpds(f'I_IP_y{t - 1}')
            cpd_x = GT.get_cpds(f'I_FP_x{t - 1}')
            cpd_y = GT.get_cpds(f'I_FP_y{t - 1}')

            prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'I_FP_x{t - 1}')
            evidence[f'I_FP_x{t - 1}'] = prediction_x

            prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'I_FP_y{t - 1}')
            evidence[f'I_FP_y{t - 1}'] = prediction_y

            
            prediction_v = predict_with_linear_gaussian_cpd(evidence, cpd_v, f'I_V{t - 1}')
            evidence[f'I_V{t - 1}'] = prediction_v

            prediction_I_x = predict_with_linear_gaussian_cpd(evidence, cpd_I_x, f'I_IP_x{t - 1}')
            evidence[f'I_IP_x{t - 1}'] = prediction_I_x

            prediction_I_y = predict_with_linear_gaussian_cpd(evidence, cpd_I_y, f'I_IP_y{t - 1}')
            evidence[f'I_IP_y{t - 1}'] = prediction_I_y

            
            
            
            # Store the predictions for this time slice
            row_predictions[f'I_V{t - 1}'] = prediction_v
            row_predictions[f'I_IP_x{t - 1}'] = prediction_I_x
            row_predictions[f'I_IP_y{t - 1}'] = prediction_I_y
            row_predictions[f'I_FP_x{t - 1}'] = prediction_x
            row_predictions[f'I_FP_y{t - 1}'] = prediction_y
        
        else:
            # for the last set of interceptor nodes, when t = 5 then 4 is calculated since I've been using t-1, so for the last t, we do 2 sets of predictions for 4 and then 5
            for i in range (5, 7):
                cpd_v = GT.get_cpds(f'I_V{i - 1}')
                cpd_I_x = GT.get_cpds(f'I_IP_x{i - 1}')
                cpd_I_y = GT.get_cpds(f'I_IP_y{i - 1}')
                cpd_x = GT.get_cpds(f'I_FP_x{i - 1}')
                cpd_y = GT.get_cpds(f'I_FP_y{i - 1}')

                
                prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'I_FP_x{i - 1}')
                evidence[f'I_FP_x{i - 1}'] = prediction_x

                prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'I_FP_y{i - 1}')
                evidence[f'I_FP_y{i - 1}'] = prediction_y
                
                prediction_v = predict_with_linear_gaussian_cpd(evidence, cpd_v, f'I_V{i - 1}')
                evidence[f'I_V{i - 1}'] = prediction_v

                prediction_I_x = predict_with_linear_gaussian_cpd(evidence, cpd_I_x, f'I_IP_x{i - 1}')
                evidence[f'I_IP_x{i - 1}'] = prediction_I_x

                prediction_I_y = predict_with_linear_gaussian_cpd(evidence, cpd_I_y, f'I_IP_y{i - 1}')
                evidence[f'I_IP_y{i - 1}'] = prediction_I_y


                
                
                # Store the predictions for this time slice
                row_predictions[f'I_V{i - 1}'] = prediction_v
                row_predictions[f'I_IP_x{i - 1}'] = prediction_I_x
                row_predictions[f'I_IP_y{i - 1}'] = prediction_I_y
                row_predictions[f'I_FP_x{i - 1}'] = prediction_x
                row_predictions[f'I_FP_y{i - 1}'] = prediction_y

    # Append predictions for this row
    predictions.append(row_predictions)

# Convert predictions to a DataFrame for easier analysis
predictions_df = pd.DataFrame(predictions)

# Print the prediction results
print(predictions_df)
# Out:
# Timeslice: 0
# ip_x = 395.225437405765
# Estimate P = 553.3156123680709
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 553.3156123680709
# Estimate P = 774.6418573152993
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10025.82674634623
# Estimate I = 8020.661397076985
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 774.6418573152993
# Estimate P = 1084.498600241419
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8020.661397076985
# Estimate I = 6416.529117661588
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 1084.498600241419
# Estimate P = 1518.2980403379863
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6416.529117661588
# Estimate I = 5133.223294129271
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 1518.2980403379863
# Estimate P = 2125.6172564731805
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5133.223294129271
# Estimate I = 4106.578635303417
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 2125.6172564731805
# Estimate P = 2975.8641590624525
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4106.578635303417
# Estimate I = 3285.262908242734
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3285.262908242734
# Estimate I = 2628.2103265941873
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 48.37891601854146
# Estimate P = 67.73048242595804
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 67.73048242595804
# Estimate P = 94.82267539634125
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10039.959738083038
# Estimate I = 8031.967790466431
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 94.82267539634125
# Estimate P = 132.75174555487774
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8031.967790466431
# Estimate I = 6425.574232373146
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 132.75174555487774
# Estimate P = 185.85244377682884
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6425.574232373146
# Estimate I = 5140.459385898517
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 185.85244377682884
# Estimate P = 260.19342128756034
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5140.459385898517
# Estimate I = 4112.367508718814
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 260.19342128756034
# Estimate P = 364.27078980258443
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4112.367508718814
# Estimate I = 3289.8940069750515
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3289.8940069750515
# Estimate I = 2631.9152055800414
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10001.152121926556
# Estimate I = 8000.9216975412455
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8000.9216975412455
# Estimate I = 6400.737358032997
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6400.737358032997
# Estimate I = 5120.589886426398
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5120.589886426398
# Estimate I = 4096.471909141119
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4096.471909141119
# Estimate I = 3277.177527312895
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3277.177527312895
# Estimate I = 2621.742021850316
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 87.07412437520493
# Estimate P = 121.9037741252869
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 121.9037741252869
# Estimate P = 170.66528377540166
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9963.40627196178
# Estimate I = 7970.725017569424
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 170.66528377540166
# Estimate P = 238.9313972855623
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7970.725017569424
# Estimate I = 6376.58001405554
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 238.9313972855623
# Estimate P = 334.5039561997872
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6376.58001405554
# Estimate I = 5101.264011244432
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 334.5039561997872
# Estimate P = 468.305538679702
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5101.264011244432
# Estimate I = 4081.011208995546
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 468.305538679702
# Estimate P = 655.6277541515827
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4081.011208995546
# Estimate I = 3264.808967196437
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3264.808967196437
# Estimate I = 2611.84717375715
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 270.8593742100385
# Estimate P = 379.2031238940539
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 379.2031238940539
# Estimate P = 530.8843734516754
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10051.361919108853
# Estimate I = 8041.089535287083
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 530.8843734516754
# Estimate P = 743.2381228323455
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8041.089535287083
# Estimate I = 6432.871628229666
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 743.2381228323455
# Estimate P = 1040.5333719652838
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6432.871628229666
# Estimate I = 5146.297302583734
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 1040.5333719652838
# Estimate P = 1456.746720751397
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5146.297302583734
# Estimate I = 4117.037842066987
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 1456.746720751397
# Estimate P = 2039.4454090519557
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4117.037842066987
# Estimate I = 3293.6302736535895
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3293.6302736535895
# Estimate I = 2634.9042189228717
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 236.6085025992615
# Estimate P = 331.2519036389661
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 331.2519036389661
# Estimate P = 463.7526650945525
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9936.51603894626
# Estimate I = 7949.212831157009
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 463.7526650945525
# Estimate P = 649.2537311323734
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7949.212831157009
# Estimate I = 6359.370264925607
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 649.2537311323734
# Estimate P = 908.9552235853228
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6359.370264925607
# Estimate I = 5087.496211940486
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 908.9552235853228
# Estimate P = 1272.5373130194519
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5087.496211940486
# Estimate I = 4069.996969552389
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 1272.5373130194519
# Estimate P = 1781.5522382272325
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4069.996969552389
# Estimate I = 3255.9975756419117
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3255.9975756419117
# Estimate I = 2604.7980605135294
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 93.26597376900476
# Estimate P = 130.57236327660667
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 130.57236327660667
# Estimate P = 182.8013085872493
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10037.288288280184
# Estimate I = 8029.8306306241475
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 182.8013085872493
# Estimate P = 255.921832022149
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8029.8306306241475
# Estimate I = 6423.864504499318
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 255.921832022149
# Estimate P = 358.29056483100857
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6423.864504499318
# Estimate I = 5139.091603599455
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 358.29056483100857
# Estimate P = 501.60679076341194
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5139.091603599455
# Estimate I = 4111.273282879564
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 501.60679076341194
# Estimate P = 702.2495070687767
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4111.273282879564
# Estimate I = 3289.0186263036517
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3289.0186263036517
# Estimate I = 2631.2149010429216
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 35.85141299676466
# Estimate P = 50.19197819547052
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 50.19197819547052
# Estimate P = 70.26876947365872
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9944.556780049445
# Estimate I = 7955.645424039556
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 70.26876947365872
# Estimate P = 98.3762772631222
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7955.645424039556
# Estimate I = 6364.516339231645
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 98.3762772631222
# Estimate P = 137.7267881683711
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6364.516339231645
# Estimate I = 5091.613071385316
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 137.7267881683711
# Estimate P = 192.81750343571952
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5091.613071385316
# Estimate I = 4073.290457108253
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 192.81750343571952
# Estimate P = 269.9445048100073
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4073.290457108253
# Estimate I = 3258.6323656866025
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3258.6323656866025
# Estimate I = 2606.9058925492823
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9890.02699487397
# Estimate I = 7912.021595899176
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7912.021595899176
# Estimate I = 6329.617276719341
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6329.617276719341
# Estimate I = 5063.693821375473
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5063.693821375473
# Estimate I = 4050.9550571003783
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4050.9550571003783
# Estimate I = 3240.764045680303
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3240.764045680303
# Estimate I = 2592.6112365442423
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10000.985347853166
# Estimate I = 8000.788278282533
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8000.788278282533
# Estimate I = 6400.630622626027
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6400.630622626027
# Estimate I = 5120.504498100821
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5120.504498100821
# Estimate I = 4096.403598480657
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4096.403598480657
# Estimate I = 3277.1228787845257
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3277.1228787845257
# Estimate I = 2621.6983030276206
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 41.52015942729021
# Estimate P = 58.12822319820629
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 58.12822319820629
# Estimate P = 81.3795124774888
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10076.284164301644
# Estimate I = 8061.027331441315
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 81.3795124774888
# Estimate P = 113.93131746848431
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8061.027331441315
# Estimate I = 6448.821865153052
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 113.93131746848431
# Estimate P = 159.503844455878
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6448.821865153052
# Estimate I = 5159.057492122442
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 159.503844455878
# Estimate P = 223.3053822382292
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5159.057492122442
# Estimate I = 4127.245993697954
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 223.3053822382292
# Estimate P = 312.6275351335209
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4127.245993697954
# Estimate I = 3301.7967949583635
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3301.7967949583635
# Estimate I = 2641.437435966691
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9940.72433213991
# Estimate I = 7952.579465711928
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7952.579465711928
# Estimate I = 6362.063572569543
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6362.063572569543
# Estimate I = 5089.650858055635
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5089.650858055635
# Estimate I = 4071.720686444508
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4071.720686444508
# Estimate I = 3257.3765491556064
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3257.3765491556064
# Estimate I = 2605.9012393244852
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9997.179867145434
# Estimate I = 7997.743893716348
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7997.743893716348
# Estimate I = 6398.1951149730785
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6398.1951149730785
# Estimate I = 5118.556091978463
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5118.556091978463
# Estimate I = 4094.8448735827706
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4094.8448735827706
# Estimate I = 3275.8758988662166
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3275.8758988662166
# Estimate I = 2620.7007190929735
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 13.314392787806058
# Estimate P = 18.64014990292848
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 18.64014990292848
# Estimate P = 26.096209864099873
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9996.571611752825
# Estimate I = 7997.25728940226
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 26.096209864099873
# Estimate P = 36.53469380973982
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7997.25728940226
# Estimate I = 6397.805831521808
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 36.53469380973982
# Estimate P = 51.14857133363574
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6397.805831521808
# Estimate I = 5118.244665217447
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 51.14857133363574
# Estimate P = 71.60799986709003
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5118.244665217447
# Estimate I = 4094.5957321739575
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 71.60799986709003
# Estimate P = 100.25119981392604
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4094.5957321739575
# Estimate I = 3275.676585739166
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3275.676585739166
# Estimate I = 2620.541268591333
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 17.739998871812485
# Estimate P = 24.83599842053748
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 24.83599842053748
# Estimate P = 34.77039778875247
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10013.724938097948
# Estimate I = 8010.979950478359
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 34.77039778875247
# Estimate P = 48.678556904253455
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8010.979950478359
# Estimate I = 6408.783960382687
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 48.678556904253455
# Estimate P = 68.14997966595483
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6408.783960382687
# Estimate I = 5127.02716830615
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 68.14997966595483
# Estimate P = 95.40997153233675
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5127.02716830615
# Estimate I = 4101.62173464492
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 95.40997153233675
# Estimate P = 133.57396014527146
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4101.62173464492
# Estimate I = 3281.2973877159366
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3281.2973877159366
# Estimate I = 2625.0379101727494
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 90.20505594391392
# Estimate P = 126.28707832147948
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 126.28707832147948
# Estimate P = 176.80190965007128
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9982.186469585551
# Estimate I = 7985.749175668441
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 176.80190965007128
# Estimate P = 247.52267351009976
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7985.749175668441
# Estimate I = 6388.5993405347535
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 247.52267351009976
# Estimate P = 346.53174291413967
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6388.5993405347535
# Estimate I = 5110.879472427803
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 346.53174291413967
# Estimate P = 485.1444400797955
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5110.879472427803
# Estimate I = 4088.7035779422426
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 485.1444400797955
# Estimate P = 679.2022161117137
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4088.7035779422426
# Estimate I = 3270.962862353794
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3270.962862353794
# Estimate I = 2616.7702898830357
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10051.94892197345
# Estimate I = 8041.55913757876
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8041.55913757876
# Estimate I = 6433.247310063009
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6433.247310063009
# Estimate I = 5146.597848050407
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5146.597848050407
# Estimate I = 4117.278278440326
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4117.278278440326
# Estimate I = 3293.822622752261
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3293.822622752261
# Estimate I = 2635.058098201809
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10023.749663243569
# Estimate I = 8018.9997305948555
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8018.9997305948555
# Estimate I = 6415.199784475884
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6415.199784475884
# Estimate I = 5132.159827580708
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5132.159827580708
# Estimate I = 4105.727862064567
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4105.727862064567
# Estimate I = 3284.5822896516534
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3284.5822896516534
# Estimate I = 2627.665831721323
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 103.395755095304
# Estimate P = 144.7540571334256
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 144.7540571334256
# Estimate P = 202.6556799867958
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9962.63290376615
# Estimate I = 7970.106323012921
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 202.6556799867958
# Estimate P = 283.7179519815141
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7970.106323012921
# Estimate I = 6376.085058410337
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 283.7179519815141
# Estimate P = 397.2051327741197
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6376.085058410337
# Estimate I = 5100.86804672827
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 397.2051327741197
# Estimate P = 556.0871858837676
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5100.86804672827
# Estimate I = 4080.6944373826163
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 556.0871858837676
# Estimate P = 778.5220602372746
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4080.6944373826163
# Estimate I = 3264.5555499060933
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3264.5555499060933
# Estimate I = 2611.644439924875
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 32.25443530676047
# Estimate P = 45.15620942946465
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 45.15620942946465
# Estimate P = 63.21869320125051
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9939.332669754853
# Estimate I = 7951.466135803883
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 63.21869320125051
# Estimate P = 88.50617048175071
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7951.466135803883
# Estimate I = 6361.172908643107
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 88.50617048175071
# Estimate P = 123.908638674451
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6361.172908643107
# Estimate I = 5088.9383269144855
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 123.908638674451
# Estimate P = 173.4720941442314
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5088.9383269144855
# Estimate I = 4071.1506615315884
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 173.4720941442314
# Estimate P = 242.86093180192393
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4071.1506615315884
# Estimate I = 3256.920529225271
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3256.920529225271
# Estimate I = 2605.536423380217
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10094.213169893948
# Estimate I = 8075.370535915159
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8075.370535915159
# Estimate I = 6460.296428732127
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6460.296428732127
# Estimate I = 5168.237142985702
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5168.237142985702
# Estimate I = 4134.589714388562
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4134.589714388562
# Estimate I = 3307.67177151085
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3307.67177151085
# Estimate I = 2646.13741720868
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10006.400630902952
# Estimate I = 8005.120504722362
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8005.120504722362
# Estimate I = 6404.09640377789
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6404.09640377789
# Estimate I = 5123.2771230223125
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5123.2771230223125
# Estimate I = 4098.62169841785
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4098.62169841785
# Estimate I = 3278.8973587342803
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3278.8973587342803
# Estimate I = 2623.1178869874243
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 363.3375460886139
# Estimate P = 508.67256452405945
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 508.67256452405945
# Estimate P = 712.1415903336832
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10087.650991418464
# Estimate I = 8070.120793134772
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 712.1415903336832
# Estimate P = 996.9982264671564
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8070.120793134772
# Estimate I = 6456.096634507818
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 996.9982264671564
# Estimate P = 1395.797517054019
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6456.096634507818
# Estimate I = 5164.877307606254
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 1395.797517054019
# Estimate P = 1954.1165238756264
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5164.877307606254
# Estimate I = 4131.901846085004
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 1954.1165238756264
# Estimate P = 2735.7631334258767
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4131.901846085004
# Estimate I = 3305.5214768680034
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3305.5214768680034
# Estimate I = 2644.417181494403
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9982.062680049365
# Estimate I = 7985.650144039492
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7985.650144039492
# Estimate I = 6388.520115231594
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6388.520115231594
# Estimate I = 5110.816092185276
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5110.816092185276
# Estimate I = 4088.652873748221
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4088.652873748221
# Estimate I = 3270.922298998577
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3270.922298998577
# Estimate I = 2616.737839198862
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 134.12699892396597
# Estimate P = 187.77779849355235
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 187.77779849355235
# Estimate P = 262.8889178909733
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9988.400623200629
# Estimate I = 7990.720498560503
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 262.8889178909733
# Estimate P = 368.04448504736257
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7990.720498560503
# Estimate I = 6392.576398848403
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 368.04448504736257
# Estimate P = 515.2622790663075
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6392.576398848403
# Estimate I = 5114.061119078723
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 515.2622790663075
# Estimate P = 721.3671906928305
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5114.061119078723
# Estimate I = 4091.2488952629787
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 721.3671906928305
# Estimate P = 1009.9140669699626
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4091.2488952629787
# Estimate I = 3272.9991162103834
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3272.9991162103834
# Estimate I = 2618.399292968307
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 40.54020904802568
# Estimate P = 56.75629266723595
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 56.75629266723595
# Estimate P = 79.45880973413033
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9977.603790454012
# Estimate I = 7982.08303236321
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 79.45880973413033
# Estimate P = 111.24233362778246
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7982.08303236321
# Estimate I = 6385.6664258905685
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 111.24233362778246
# Estimate P = 155.73926707889544
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6385.6664258905685
# Estimate I = 5108.533140712455
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 155.73926707889544
# Estimate P = 218.0349739104536
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5108.533140712455
# Estimate I = 4086.826512569964
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 218.0349739104536
# Estimate P = 305.24896347463505
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4086.826512569964
# Estimate I = 3269.4612100559716
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3269.4612100559716
# Estimate I = 2615.5689680447776
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 100.61576854092142
# Estimate P = 140.86207595729
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 140.86207595729
# Estimate P = 197.20690634020596
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9956.506743418891
# Estimate I = 7965.205394735113
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 197.20690634020596
# Estimate P = 276.08966887628833
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7965.205394735113
# Estimate I = 6372.164315788091
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 276.08966887628833
# Estimate P = 386.5255364268036
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6372.164315788091
# Estimate I = 5097.731452630473
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 386.5255364268036
# Estimate P = 541.1357509975251
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5097.731452630473
# Estimate I = 4078.1851621043784
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 541.1357509975251
# Estimate P = 757.590051396535
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4078.1851621043784
# Estimate I = 3262.548129683503
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3262.548129683503
# Estimate I = 2610.0385037468022
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10022.72803450566
# Estimate I = 8018.182427604529
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8018.182427604529
# Estimate I = 6414.545942083623
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6414.545942083623
# Estimate I = 5131.636753666899
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5131.636753666899
# Estimate I = 4105.309402933519
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4105.309402933519
# Estimate I = 3284.2475223468155
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3284.2475223468155
# Estimate I = 2627.3980178774527
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 67.29315240909847
# Estimate P = 94.21041337273785
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 94.21041337273785
# Estimate P = 131.89457872183297
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9866.916383965858
# Estimate I = 7893.533107172687
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 131.89457872183297
# Estimate P = 184.65241021056616
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7893.533107172687
# Estimate I = 6314.82648573815
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 184.65241021056616
# Estimate P = 258.5133742947926
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6314.82648573815
# Estimate I = 5051.86118859052
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 258.5133742947926
# Estimate P = 361.9187240127096
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5051.86118859052
# Estimate I = 4041.4889508724164
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 361.9187240127096
# Estimate P = 506.68621361779344
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4041.4889508724164
# Estimate I = 3233.1911606979334
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3233.1911606979334
# Estimate I = 2586.552928558347
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9965.294386057763
# Estimate I = 7972.235508846211
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7972.235508846211
# Estimate I = 6377.788407076969
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6377.788407076969
# Estimate I = 5102.230725661575
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5102.230725661575
# Estimate I = 4081.78458052926
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4081.78458052926
# Estimate I = 3265.4276644234083
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3265.4276644234083
# Estimate I = 2612.342131538727
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9973.805839397108
# Estimate I = 7979.044671517687
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7979.044671517687
# Estimate I = 6383.23573721415
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6383.23573721415
# Estimate I = 5106.58858977132
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5106.58858977132
# Estimate I = 4085.270871817056
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4085.270871817056
# Estimate I = 3268.216697453645
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3268.216697453645
# Estimate I = 2614.573357962916
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 209.69820137772996
# Estimate P = 293.5774819288219
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 293.5774819288219
# Estimate P = 411.00847470035063
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10056.619085736704
# Estimate I = 8045.295268589363
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 411.00847470035063
# Estimate P = 575.4118645804908
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8045.295268589363
# Estimate I = 6436.236214871491
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 575.4118645804908
# Estimate P = 805.5766104126872
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6436.236214871491
# Estimate I = 5148.988971897194
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 805.5766104126872
# Estimate P = 1127.807254577762
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5148.988971897194
# Estimate I = 4119.191177517755
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 1127.807254577762
# Estimate P = 1578.9301564088667
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4119.191177517755
# Estimate I = 3295.352942014204
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3295.352942014204
# Estimate I = 2636.2823536113633
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 105.89761611762988
# Estimate P = 148.25666256468182
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 148.25666256468182
# Estimate P = 207.55932759055455
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10005.686242357044
# Estimate I = 8004.548993885635
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 207.55932759055455
# Estimate P = 290.58305862677634
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8004.548993885635
# Estimate I = 6403.639195108509
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 290.58305862677634
# Estimate P = 406.81628207748685
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6403.639195108509
# Estimate I = 5122.911356086807
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 406.81628207748685
# Estimate P = 569.5427949084816
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5122.911356086807
# Estimate I = 4098.329084869446
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 569.5427949084816
# Estimate P = 797.3599128718741
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4098.329084869446
# Estimate I = 3278.663267895557
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3278.663267895557
# Estimate I = 2622.930614316446
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 25.658229954163907
# Estimate P = 35.92152193582947
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 35.92152193582947
# Estimate P = 50.29013071016125
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9824.576492687384
# Estimate I = 7859.661194149907
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 50.29013071016125
# Estimate P = 70.40618299422574
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7859.661194149907
# Estimate I = 6287.728955319926
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 70.40618299422574
# Estimate P = 98.56865619191603
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6287.728955319926
# Estimate I = 5030.183164255941
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 98.56865619191603
# Estimate P = 137.99611866868244
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5030.183164255941
# Estimate I = 4024.1465314047527
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 137.99611866868244
# Estimate P = 193.1945661361554
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4024.1465314047527
# Estimate I = 3219.3172251238025
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3219.3172251238025
# Estimate I = 2575.453780099042
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 216.42565123310555
# Estimate P = 302.99591172634774
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 302.99591172634774
# Estimate P = 424.1942764168868
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9930.204032552334
# Estimate I = 7944.163226041867
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 424.1942764168868
# Estimate P = 593.8719869836415
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7944.163226041867
# Estimate I = 6355.330580833494
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 593.8719869836415
# Estimate P = 831.420781777098
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6355.330580833494
# Estimate I = 5084.264464666796
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 831.420781777098
# Estimate P = 1163.989094487937
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5084.264464666796
# Estimate I = 4067.411571733437
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 1163.989094487937
# Estimate P = 1629.5847322831119
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4067.411571733437
# Estimate I = 3253.9292573867497
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3253.9292573867497
# Estimate I = 2603.1434059094
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 167.5781564820681
# Estimate P = 234.60941907489533
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 234.60941907489533
# Estimate P = 328.45318670485347
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9937.38717972183
# Estimate I = 7949.909743777465
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 328.45318670485347
# Estimate P = 459.8344613867948
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7949.909743777465
# Estimate I = 6359.927795021973
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 459.8344613867948
# Estimate P = 643.7682459415128
# Timeslice: 3
# ...
# Estimate I = 4084.8939026028197
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4084.8939026028197
# Estimate I = 3267.915122082256
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3267.915122082256
# Estimate I = 2614.332097665805
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 32.47726138611507
# Estimate P = 45.46816594056109
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 45.46816594056109
# Estimate P = 63.65543231678553
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9920.753419569795
# Estimate I = 7936.602735655837
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 63.65543231678553
# Estimate P = 89.11760524349974
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7936.602735655837
# Estimate I = 6349.28218852467
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 89.11760524349974
# Estimate P = 124.76464734089963
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6349.28218852467
# Estimate I = 5079.425750819737
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 124.76464734089963
# Estimate P = 174.67050627725948
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5079.425750819737
# Estimate I = 4063.5406006557896
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 174.67050627725948
# Estimate P = 244.53870878816326
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4063.5406006557896
# Estimate I = 3250.832480524632
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3250.832480524632
# Estimate I = 2600.6659844197056
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 78.08015994843939
# Estimate P = 109.31222392781514
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 109.31222392781514
# Estimate P = 153.03711349894118
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9916.053979855262
# Estimate I = 7932.84318388421
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 153.03711349894118
# Estimate P = 214.25195889851764
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7932.84318388421
# Estimate I = 6346.274547107369
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 214.25195889851764
# Estimate P = 299.95274245792467
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6346.274547107369
# Estimate I = 5077.019637685895
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 299.95274245792467
# Estimate P = 419.9338394410945
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5077.019637685895
# Estimate I = 4061.615710148716
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 419.9338394410945
# Estimate P = 587.9073752175323
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4061.615710148716
# Estimate I = 3249.292568118973
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3249.292568118973
# Estimate I = 2599.4340544951788
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 104.10891101349814
# Estimate P = 145.7524754188974
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 145.7524754188974
# Estimate P = 204.05346558645635
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 10055.486844959536
# Estimate I = 8044.38947596763
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 204.05346558645635
# Estimate P = 285.6748518210389
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 8044.38947596763
# Estimate I = 6435.511580774104
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 285.6748518210389
# Estimate P = 399.9447925494544
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6435.511580774104
# Estimate I = 5148.409264619284
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 399.9447925494544
# Estimate P = 559.9227095692361
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5148.409264619284
# Estimate I = 4118.727411695428
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 559.9227095692361
# Estimate P = 783.8917933969304
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4118.727411695428
# Estimate I = 3294.9819293563423
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3294.9819293563423
# Estimate I = 2635.9855434850742
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 48.8065347800529
# Estimate P = 68.32914869207406
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 68.32914869207406
# Estimate P = 95.66080816890367
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9961.470951049065
# Estimate I = 7969.176760839252
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 95.66080816890367
# Estimate P = 133.92513143646514
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7969.176760839252
# Estimate I = 6375.341408671402
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 133.92513143646514
# Estimate P = 187.49518401105118
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6375.341408671402
# Estimate I = 5100.273126937122
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 187.49518401105118
# Estimate P = 262.49325761547163
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5100.273126937122
# Estimate I = 4080.2185015496975
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 262.49325761547163
# Estimate P = 367.49056066166025
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4080.2185015496975
# Estimate I = 3264.1748012397584
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3264.1748012397584
# Estimate I = 2611.339840991807
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9968.564462949178
# Estimate I = 7974.851570359343
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7974.851570359343
# Estimate I = 6379.881256287475
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6379.881256287475
# Estimate I = 5103.90500502998
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5103.90500502998
# Estimate I = 4083.1240040239845
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4083.1240040239845
# Estimate I = 3266.4992032191876
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3266.4992032191876
# Estimate I = 2613.1993625753503
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 3.631362546210088
# Estimate P = 5.0839075646941225
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 5.0839075646941225
# Estimate P = 7.117470590571771
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9972.714989159344
# Estimate I = 7978.171991327476
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 7.117470590571771
# Estimate P = 9.96445882680048
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7978.171991327476
# Estimate I = 6382.537593061981
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 9.96445882680048
# Estimate P = 13.95024235752067
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6382.537593061981
# Estimate I = 5106.030074449585
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 13.95024235752067
# Estimate P = 19.530339300528937
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5106.030074449585
# Estimate I = 4084.8240595596685
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 19.530339300528937
# Estimate P = 27.34247502074051
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4084.8240595596685
# Estimate I = 3267.859247647735
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3267.859247647735
# Estimate I = 2614.2873981181883
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 275.2599780445153
# Estimate P = 385.3639692623214
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 385.3639692623214
# Estimate P = 539.50955696725
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9907.300531509907
# Estimate I = 7925.840425207926
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 539.50955696725
# Estimate P = 755.3133797541499
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7925.840425207926
# Estimate I = 6340.672340166341
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 755.3133797541499
# Estimate P = 1057.4387316558098
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6340.672340166341
# Estimate I = 5072.5378721330735
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 1057.4387316558098
# Estimate P = 1480.4142243181336
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5072.5378721330735
# Estimate I = 4058.030297706459
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 1480.4142243181336
# Estimate P = 2072.579914045387
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4058.030297706459
# Estimate I = 3246.4242381651675
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3246.4242381651675
# Estimate I = 2597.1393905321343
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 0
# Estimate P = 0.0
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9866.884057410449
# Estimate I = 7893.507245928359
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7893.507245928359
# Estimate I = 6314.805796742688
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6314.805796742688
# Estimate I = 5051.844637394151
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5051.844637394151
# Estimate I = 4041.4757099153207
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 0.0
# Estimate P = 0.0
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4041.4757099153207
# Estimate I = 3233.180567932257
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3233.180567932257
# Estimate I = 2586.5444543458057
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
# Timeslice: 0
# ip_x = 71.2815257089513
# Estimate P = 99.79413599253182
# Timeslice: 0
# ip_y = 0.0
# Estimate P = 100
# Timeslice: 1
# ip_x = 99.79413599253182
# Estimate P = 139.71179038954455
# Timeslice: 1
# ip_y = 100
# Estimate P = 140.0
# Timeslice: 0
# ip_x = 9990.41719871664
# Estimate I = 7992.333758973312
# Timeslice: 0
# ip_y = 0.0
# Estimate I = 100
# Timeslice: 2
# ip_x = 139.71179038954455
# Estimate P = 195.59650654536236
# Timeslice: 2
# ip_y = 140.0
# Estimate P = 196.0
# Timeslice: 1
# ip_x = 7992.333758973312
# Estimate I = 6393.86700717865
# Timeslice: 1
# ip_y = 100
# Estimate I = 140.0
# Timeslice: 3
# ip_x = 195.59650654536236
# Estimate P = 273.8351091635073
# Timeslice: 3
# ip_y = 196.0
# Estimate P = 274.4
# Timeslice: 2
# ip_x = 6393.86700717865
# Estimate I = 5115.093605742921
# Timeslice: 2
# ip_y = 140.0
# Estimate I = 196.0
# Timeslice: 4
# ip_x = 273.8351091635073
# Estimate P = 383.3691528289102
# Timeslice: 4
# ip_y = 274.4
# Estimate P = 384.15999999999997
# Timeslice: 3
# ip_x = 5115.093605742921
# Estimate I = 4092.0748845943367
# Timeslice: 3
# ip_y = 196.0
# Estimate I = 274.4
# Timeslice: 5
# ip_x = 383.3691528289102
# Estimate P = 536.7168139604743
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate P = 537.824
# Timeslice: 4
# ip_x = 4092.0748845943367
# Estimate I = 3273.6599076754696
# Timeslice: 4
# ip_y = 274.4
# Estimate I = 384.15999999999997
# Timeslice: 5
# ip_x = 3273.6599076754696
# Estimate I = 2618.927926140376
# Timeslice: 5
# ip_y = 384.15999999999997
# Estimate I = 537.824
#        P_FP_x0  P_FP_y0        P_V1     P_IP_x1    P_IP_y1     P_FP_x1  \
# 0   553.315612      100  131.267520  585.139335  69.589383  774.641857
# 1    67.730482      100   62.048898   71.924605  69.589383   94.822675
# 2     0.000000      100   59.259241 -120.060336  69.589383    0.000000
# 3   121.903774      100   73.376952  129.180335  69.589383  170.665284
# 4   379.203124      100  107.640263  401.119915  69.589383  530.884373
# ..         ...      ...         ...         ...        ...         ...
# 95    0.000000      100   49.964882  -52.851758  69.589383    0.000000
# 96    5.083908      100   54.833716    5.713465  69.589383    7.117471
# 97  385.363969      100  100.859849  407.631310  69.589383  539.509557
# 98    0.000000      100   56.089255  -21.988221  69.589383    0.000000
# 99   99.794136      100   64.225425  105.812667  69.589383  139.711790
#
#     P_FP_y1      I_FP_x0  I_FP_y0        P_V2  ...         I_V4      I_IP_x4  \
# 0     140.0  8020.661397      100  278.694875  ...  2089.881808  4330.644276
# 1     140.0  8031.967790      100  113.900369  ...  2090.546936  4336.780076
# 2     140.0  8000.921698      100   97.779412  ...  2085.629316  4319.931854
# 3     140.0  7970.725018      100  135.891060  ...  2081.510287  4303.544596
# 4     140.0  8041.089535      100  220.797687  ...  2103.308903  4341.730302
# ..      ...          ...      ...         ...  ...          ...          ...
# 95    140.0  7974.851570      100   88.485277  ...  2084.808050  4305.784010
# 96    140.0  7978.171991      100   94.354657  ...  2085.588965  4307.585950
# 97    140.0  7925.840425      100  215.230074  ...  2072.311993  4279.186440
# 98    140.0  7893.507246      100   94.609502  ...  2057.301194  4261.639738
# 99    140.0  7992.333759      100  122.387921  ...  2087.031121  4315.271316
#
#        I_IP_y4      I_FP_x4  I_FP_y4         I_V5      I_IP_x5     I_IP_y5  \
# 0   292.781549  3285.262908   384.16  2425.606599  3479.491667  415.318117
# 1   292.781549  3289.894007   384.16  2426.643620  3484.412126  415.318117
# 2   292.781549  3277.177527   384.16  2420.704651  3470.901094  415.318117
# 3   292.781549  3264.808967   384.16  2415.592253  3457.759721  415.318117
# 4   292.781549  3293.630274   384.16  2439.706302  3488.381842  415.318117
# ..         ...          ...      ...          ...          ...         ...
# 95  292.781549  3266.499203   384.16  2419.025917  3459.555566  415.318117
# 96  292.781549  3267.859248   384.16  2419.916081  3461.000589  415.318117
# 97  292.781549  3246.424238   384.16  2404.917236  3438.226276  415.318117
# 98  292.781549  3233.180568   384.16  2388.842196  3424.155114  415.318117
# 99  292.781549  3273.659908   384.16  2421.824084  3467.163686  415.318117
#
#         I_FP_x5  I_FP_y5
# 0   2628.210327  537.824
# 1   2631.915206  537.824
# 2   2621.742022  537.824
# 3   2611.847174  537.824
# 4   2634.904219  537.824
# ..          ...      ...
# 95  2613.199363  537.824
# 96  2614.287398  537.824
# 97  2597.139391  537.824
# 98  2586.544454  537.824
# 99  2618.927926  537.824
#
# [100 rows x 54 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Create lists to store the actual and predicted values for comparison
actual_values = []
predicted_values = []

# Define the list of columns that we are interested in for comparison
columns_to_compare = [f'P_V{t}' for t in range(1,6)] + \
                     [f'P_IP_x{t}' for t in range(1,6)] + \
                     [f'P_IP_y{t}' for t in range(1,6)] + \
                     [f'P_FP_x{t}' for t in range(6)] + \
                     [f'P_FP_y{t}' for t in range(6)] + \
                     [f'I_V{t}' for t in range(1,6)] + \
                     [f'I_IP_x{t}' for t in range(1,6)] + \
                     [f'I_IP_y{t}' for t in range(1,6)] + \
                     [f'I_FP_x{t}' for t in range(6)] + \
                     [f'I_FP_y{t}' for t in range(6)]

# Iterate over each row in the test data
for index, row in test_data.iterrows():
    actual_row = []
    predicted_row = []

    # Get actual values and predicted values for the current row
    for col in columns_to_compare:
        actual_value = row[col]
        predicted_value = predictions_df.loc[index, col]
        
        actual_row.append(actual_value)
        predicted_row.append(predicted_value)

        # Print the column name and the corresponding values
        print(f"Column: {col}")
        print(f"  Actual: {actual_value}")
        print(f"  Predicted: {predicted_value}")
        print("-" * 30)

    # Print the row-wise summary
    print("=" * 50 + f" ROW {index} SUMMARY " + "=" * 50)
    print(f"Actual Values: {actual_row}")
    print(f"Predicted Values: {predicted_row}")
    print("\n")

    actual_values.extend(actual_row)
    predicted_values.extend(predicted_row)

# Convert the lists to numpy arrays for metric calculation
actual_values = np.array(actual_values)
predicted_values = np.array([val.flatten() if isinstance(val, np.ndarray) else [val] for val in predicted_values])

# Calculate accuracy metrics
mae = mean_absolute_error(actual_values, predicted_values)
mse = mean_squared_error(actual_values, predicted_values)
rmse = np.sqrt(mse)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Column: P_V1
#   Actual: 258.9851419335697
#   Predicted: 131.2675202578739
# ------------------------------
# Column: P_V2
#   Actual: 598.069106576205
#   Predicted: 278.69487546893293
# ------------------------------
# Column: P_V3
#   Actual: 1026.9683570220072
#   Predicted: 477.25574037835264
# ------------------------------
# Column: P_V4
#   Actual: 1537.6137981193176
#   Predicted: 748.7494294959564
# ------------------------------
# Column: P_V5
#   Actual: 2111.125621251568
#   Predicted: 1119.9628930142428
# ------------------------------
# Column: P_IP_x1
#   Actual: 1159.170258859047
#   Predicted: 585.1393345630468
# ------------------------------
# Column: P_IP_x2
#   Actual: 1955.831346824179
#   Predicted: 834.023441568146
# ------------------------------
# Column: P_IP_x3
#   Actual: 2721.706368399256
#   Predicted: 1176.9129858104275
# ------------------------------
# Column: P_IP_x4
#   Actual: 3462.056047720348
#   Predicted: 1651.5526098857767
# ------------------------------
# Column: P_IP_x5
#   Actual: 4162.5972961077205
#   Predicted: 2314.0757944056695
# ------------------------------
# Column: P_IP_y1
#   Actual: 118.13038156646088
#   Predicted: 69.58938313248983
# ------------------------------
# Column: P_IP_y2
#   Actual: 292.39099765456143
#   Predicted: 133.23633304501018
# ------------------------------
# Column: P_IP_y3
#   Actual: 435.2865762397316
#   Predicted: 202.29275134509825
# ------------------------------
# Column: P_IP_y4
#   Actual: 557.1220898940155
#   Predicted: 292.3683314055428
# ------------------------------
# Column: P_IP_y5
#   Actual: 604.585975458497
#   Predicted: 414.76992788374497
# ------------------------------
# Column: P_FP_x0
#   Actual: 984.9994031793044
#   Predicted: 553.3156123680709
# ------------------------------
# Column: P_FP_x1
#   Actual: 1922.5208061372052
#   Predicted: 774.6418573152993
# ------------------------------
# Column: P_FP_x2
#   Actual: 2750.129862807254
#   Predicted: 1084.498600241419
# ------------------------------
# Column: P_FP_x3
#   Actual: 3488.9812198295804
#   Predicted: 1518.2980403379863
# ------------------------------
# Column: P_FP_x4
#   Actual: 4202.743851123159
#   Predicted: 2125.6172564731805
# ------------------------------
# Column: P_FP_x5
#   Actual: 4861.281052297209
#   Predicted: 2975.8641590624525
# ------------------------------
# Column: P_FP_y0
#   Actual: 109.18690424340504
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 261.93686656162924
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 448.5129547138079
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 598.6362894384846
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 671.8268889448476
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 663.6949440344188
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 880.3653536616692
#   Predicted: 691.1955125549727
# ------------------------------
# Column: I_V2
#   Actual: 1670.3306729814417
#   Predicted: 1244.5537005446338
# ------------------------------
# Column: I_V3
#   Actual: 2398.703359946085
#   Predicted: 1702.3638221720173
# ------------------------------
# Column: I_V4
#   Actual: 3065.2028010822546
#   Predicted: 2089.8818075133663
# ------------------------------
# Column: I_V5
#   Actual: 3640.052810212405
#   Predicted: 2425.606598518291
# ------------------------------
# Column: I_IP_x1
#   Actual: 9082.582729569443
#   Predicted: 8219.874684426237
# ------------------------------
# Column: I_IP_x2
#   Actual: 8205.457040029381
#   Predicted: 6676.694941770809
# ------------------------------
# Column: I_IP_x3
#   Actual: 7345.448289653436
#   Predicted: 5386.733608015356
# ------------------------------
# Column: I_IP_x4
#   Actual: 6599.331044890888
#   Predicted: 4330.6442755320995
# ------------------------------
# Column: I_IP_x5
#   Actual: 5749.012306637109
#   Predicted: 3479.491666512142
# ------------------------------
# Column: I_IP_y1
#   Actual: 166.2946357042639
#   Predicted: 69.91712173868306
# ------------------------------
# Column: I_IP_y2
#   Actual: 275.6788361497171
#   Predicted: 132.6667017321747
# ------------------------------
# Column: I_IP_y3
#   Actual: 450.8650656489974
#   Predicted: 202.3064307064511
# ------------------------------
# Column: I_IP_y4
#   Actual: 551.1666043197112
#   Predicted: 292.7815491344932
# ------------------------------
# Column: I_IP_y5
#   Actual: 624.488920751576
#   Predicted: 415.3181172762701
# ------------------------------
# Column: I_FP_x0
#   Actual: 9069.771359881404
#   Predicted: 8020.661397076985
# ------------------------------
# Column: I_FP_x1
#   Actual: 8172.326232624206
#   Predicted: 6416.529117661588
# ------------------------------
# Column: I_FP_x2
#   Actual: 7328.147133427535
#   Predicted: 5133.223294129271
# ------------------------------
# Column: I_FP_x3
#   Actual: 6521.9251246755975
#   Predicted: 4106.578635303417
# ------------------------------
# Column: I_FP_x4
#   Actual: 5785.37206488104
#   Predicted: 3285.262908242734
# ------------------------------
# Column: I_FP_x5
#   Actual: 4871.742742535063
#   Predicted: 2628.2103265941873
# ------------------------------
# Column: I_FP_y0
#   Actual: 156.0865834890273
#   Predicted: 100
# ------------------------------
# Column: I_FP_y1
#   Actual: 289.2153129207197
#   Predicted: 140.0
# ------------------------------
# Column: I_FP_y2
#   Actual: 429.8540636801103
#   Predicted: 196.0
# ------------------------------
# Column: I_FP_y3
#   Actual: 567.9855997530134
#   Predicted: 274.4
# ------------------------------
# Column: I_FP_y4
#   Actual: 697.5227127543936
#   Predicted: 384.15999999999997
# ------------------------------
# Column: I_FP_y5
#   Actual: 675.4001287189715
#   Predicted: 537.824
# ------------------------------
# ================================================== ROW 0 SUMMARY ==================================================
# Actual Values: [np.float64(258.9851419335697), np.float64(598.069106576205), np.float64(1026.9683570220072), np.float64(1537.6137981193176), np.float64(2111.125621251568), np.float64(1159.170258859047), np.float64(1955.831346824179), np.float64(2721.706368399256), np.float64(3462.056047720348), np.float64(4162.5972961077205), np.float64(118.13038156646088), np.float64(292.39099765456143), np.float64(435.2865762397316), np.float64(557.1220898940155), np.float64(604.585975458497), np.float64(984.9994031793044), np.float64(1922.5208061372052), np.float64(2750.129862807254), np.float64(3488.9812198295804), np.float64(4202.743851123159), np.float64(4861.281052297209), np.float64(109.18690424340504), np.float64(261.93686656162924), np.float64(448.5129547138079), np.float64(598.6362894384846), np.float64(671.8268889448476), np.float64(663.6949440344188), np.float64(880.3653536616692), np.float64(1670.3306729814417), np.float64(2398.703359946085), np.float64(3065.2028010822546), np.float64(3640.052810212405), np.float64(9082.582729569443), np.float64(8205.457040029381), np.float64(7345.448289653436), np.float64(6599.331044890888), np.float64(5749.012306637109), np.float64(166.2946357042639), np.float64(275.6788361497171), np.float64(450.8650656489974), np.float64(551.1666043197112), np.float64(624.488920751576), np.float64(9069.771359881404), np.float64(8172.326232624206), np.float64(7328.147133427535), np.float64(6521.9251246755975), np.float64(5785.37206488104), np.float64(4871.742742535063), np.float64(156.0865834890273), np.float64(289.2153129207197), np.float64(429.8540636801103), np.float64(567.9855997530134), np.float64(697.5227127543936), np.float64(675.4001287189715)]
# Predicted Values: [np.float64(131.2675202578739), np.float64(278.69487546893293), np.float64(477.25574037835264), np.float64(748.7494294959564), np.float64(1119.9628930142428), np.float64(585.1393345630468), np.float64(834.023441568146), np.float64(1176.9129858104275), np.float64(1651.5526098857767), np.float64(2314.0757944056695), np.float64(69.58938313248983), np.float64(133.23633304501018), np.float64(202.29275134509825), np.float64(292.3683314055428), np.float64(414.76992788374497), np.float64(553.3156123680709), np.float64(774.6418573152993), np.float64(1084.498600241419), np.float64(1518.2980403379863), np.float64(2125.6172564731805), np.float64(2975.8641590624525), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824), np.float64(691.1955125549727), np.float64(1244.5537005446338), np.float64(1702.3638221720173), np.float64(2089.8818075133663), np.float64(2425.606598518291), np.float64(8219.874684426237), np.float64(6676.694941770809), np.float64(5386.733608015356), np.float64(4330.6442755320995), np.float64(3479.491666512142), np.float64(69.91712173868306), np.float64(132.6667017321747), np.float64(202.3064307064511), np.float64(292.7815491344932), np.float64(415.3181172762701), np.float64(8020.661397076985), np.float64(6416.529117661588), np.float64(5133.223294129271), np.float64(4106.578635303417), np.float64(3285.262908242734), np.float64(2628.2103265941873), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824)]
#
#
# Column: P_V1
#   Actual: 258.6365826203977
#   Predicted: 62.048897795075256
# ------------------------------
# Column: P_V2
#   Actual: 595.2982157853615
#   Predicted: 113.90036851899602
# ------------------------------
# Column: P_V3
#   Actual: 1023.0093223230964
#   Predicted: 178.8092588528581
# ------------------------------
# Column: P_V4
#   Actual: 1523.5924112874463
#   Predicted: 264.17482216628406
# ------------------------------
# Column: P_V5
#   Actual: 2092.06398424076
#   Predicted: 374.1111259868151
# ------------------------------
# Column: P_IP_x1
#   Actual: 962.7598894318968
#   Predicted: 71.92460456490025
# ------------------------------
# Column: P_IP_x2
#   Actual: 1841.2460263384955
#   Predicted: 101.08128456316902
# ------------------------------
# Column: P_IP_x3
#   Actual: 2658.2615352125254
#   Predicted: 144.73581794777647
# ------------------------------
# Column: P_IP_x4
#   Actual: 3412.5762313852256
#   Predicted: 202.9026304875282
# ------------------------------
# Column: P_IP_x5
#   Actual: 4118.77867692811
#   Predicted: 284.17121679638365
# ------------------------------
# Column: P_IP_y1
#   Actual: 124.9067859536968
#   Predicted: 69.58938313248983
# ------------------------------
# Column: P_IP_y2
#   Actual: 255.7554589709948
#   Predicted: 133.23633304501018
# ------------------------------
# Column: P_IP_y3
#   Actual: 432.0084759957515
#   Predicted: 202.29275134509825
# ------------------------------
# Column: P_IP_y4
#   Actual: 576.8300252278146
#   Predicted: 292.3683314055428
# ------------------------------
# Column: P_IP_y5
#   Actual: 593.4035332266432
#   Predicted: 414.76992788374497
# ------------------------------
# Column: P_FP_x0
#   Actual: 998.4649876766276
#   Predicted: 67.73048242595804
# ------------------------------
# Column: P_FP_x1
#   Actual: 1880.802768400912
#   Predicted: 94.82267539634125
# ------------------------------
# Column: P_FP_x2
#   Actual: 2720.7670696096066
#   Predicted: 132.75174555487774
# ------------------------------
# Column: P_FP_x3
#   Actual: 3474.0769108654654
#   Predicted: 185.85244377682884
# ------------------------------
# Column: P_FP_x4
#   Actual: 4166.310922454353
#   Predicted: 260.19342128756034
# ------------------------------
# Column: P_FP_x5
#   Actual: 4824.527933613893
#   Predicted: 364.27078980258443
# ------------------------------
# Column: P_FP_y0
#   Actual: 80.36836579282868
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 277.5454421935569
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 449.3804508612132
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 586.877792992273
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 642.8493021946215
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 633.7057065424772
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 879.0793791161517
#   Predicted: 690.0996055875896
# ------------------------------
# Column: I_V2
#   Actual: 1672.786868653253
#   Predicted: 1244.179200378631
# ------------------------------
# Column: I_V3
#   Actual: 2402.464137831056
#   Predicted: 1702.5675161322602
# ------------------------------
# Column: I_V4
#   Actual: 3065.713997087114
#   Predicted: 2090.546935524763
# ------------------------------
# Column: I_V5
#   Actual: 3628.310627750997
#   Predicted: 2426.6436200446665
# ------------------------------
# Column: I_IP_x1
#   Actual: 9092.163822648605
#   Predicted: 8231.474261645195
# ------------------------------
# Column: I_IP_x2
#   Actual: 8191.362276638094
#   Predicted: 6686.121955321027
# ------------------------------
# Column: I_IP_x3
#   Actual: 7374.038155632688
#   Predicted: 5394.34815245214
# ------------------------------
# Column: I_IP_x4
#   Actual: 6597.795775455367
#   Predicted: 4336.780075623462
# ------------------------------
# Column: I_IP_x5
#   Actual: 5707.961612693662
#   Predicted: 3484.4121258921264
# ------------------------------
# Column: I_IP_y1
#   Actual: 116.71972714983931
#   Predicted: 69.91712173868306
# ------------------------------
# Column: I_IP_y2
#   Actual: 268.7411622478383
#   Predicted: 132.6667017321747
# ------------------------------
# Column: I_IP_y3
#   Actual: 400.659907373152
#   Predicted: 202.3064307064511
# ------------------------------
# Column: I_IP_y4
#   Actual: 489.2393838469704
#   Predicted: 292.7815491344932
# ------------------------------
# Column: I_IP_y5
#   Actual: 567.1851499571176
#   Predicted: 415.3181172762701
# ------------------------------
# Column: I_FP_x0
#   Actual: 8699.206751587884
#   Predicted: 8031.967790466431
# ------------------------------
# Column: I_FP_x1
#   Actual: 8166.705819240891
#   Predicted: 6425.574232373146
# ------------------------------
# Column: I_FP_x2
#   Actual: 7315.588633367595
#   Predicted: 5140.459385898517
# ------------------------------
# Column: I_FP_x3
#   Actual: 6571.652568847845
#   Predicted: 4112.367508718814
# ------------------------------
# Column: I_FP_x4
#   Actual: 5824.088216143741
#   Predicted: 3289.8940069750515
# ------------------------------
# Column: I_FP_x5
#   Actual: 4813.117292439619
#   Predicted: 2631.9152055800414
# ------------------------------
# Column: I_FP_y0
#   Actual: 125.524040121968
#   Predicted: 100
# ------------------------------
# Column: I_FP_y1
#   Actual: 292.7799234878552
#   Predicted: 140.0
# ------------------------------
# Column: I_FP_y2
#   Actual: 444.9080212432368
#   Predicted: 196.0
# ------------------------------
# Column: I_FP_y3
#   Actual: 541.4956262324729
#   Predicted: 274.4
# ------------------------------
# Column: I_FP_y4
#   Actual: 597.1372688098263
#   Predicted: 384.15999999999997
# ------------------------------
# Column: I_FP_y5
#   Actual: 615.1370459614164
#   Predicted: 537.824
# ------------------------------
# ================================================== ROW 1 SUMMARY ==================================================
# Actual Values: [np.float64(258.6365826203977), np.float64(595.2982157853615), np.float64(1023.0093223230964), np.float64(1523.5924112874463), np.float64(2092.06398424076), np.float64(962.7598894318968), np.float64(1841.2460263384955), np.float64(2658.2615352125254), np.float64(3412.5762313852256), np.float64(4118.77867692811), np.float64(124.9067859536968), np.float64(255.7554589709948), np.float64(432.0084759957515), np.float64(576.8300252278146), np.float64(593.4035332266432), np.float64(998.4649876766276), np.float64(1880.802768400912), np.float64(2720.7670696096066), np.float64(3474.0769108654654), np.float64(4166.310922454353), np.float64(4824.527933613893), np.float64(80.36836579282868), np.float64(277.5454421935569), np.float64(449.3804508612132), np.float64(586.877792992273), np.float64(642.8493021946215), np.float64(633.7057065424772), np.float64(879.0793791161517), np.float64(1672.786868653253), np.float64(2402.464137831056), np.float64(3065.713997087114), np.float64(3628.310627750997), np.float64(9092.163822648605), np.float64(8191.362276638094), np.float64(7374.038155632688), np.float64(6597.795775455367), np.float64(5707.961612693662), np.float64(116.71972714983931), np.float64(268.7411622478383), np.float64(400.659907373152), np.float64(489.2393838469704), np.float64(567.1851499571176), np.float64(8699.206751587884), np.float64(8166.705819240891), np.float64(7315.588633367595), np.float64(6571.652568847845), np.float64(5824.088216143741), np.float64(4813.117292439619), np.float64(125.524040121968), np.float64(292.7799234878552), np.float64(444.9080212432368), np.float64(541.4956262324729), np.float64(597.1372688098263), np.float64(615.1370459614164)]
# Predicted Values: [np.float64(62.048897795075256), np.float64(113.90036851899602), np.float64(178.8092588528581), np.float64(264.17482216628406), np.float64(374.1111259868151), np.float64(71.92460456490025), np.float64(101.08128456316902), np.float64(144.73581794777647), np.float64(202.9026304875282), np.float64(284.17121679638365), np.float64(69.58938313248983), np.float64(133.23633304501018), np.float64(202.29275134509825), np.float64(292.3683314055428), np.float64(414.76992788374497), np.float64(67.73048242595804), np.float64(94.82267539634125), np.float64(132.75174555487774), np.float64(185.85244377682884), np.float64(260.19342128756034), np.float64(364.27078980258443), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824), np.float64(690.0996055875896), np.float64(1244.179200378631), np.float64(1702.5675161322602), np.float64(2090.546935524763), np.float64(2426.6436200446665), np.float64(8231.474261645195), np.float64(6686.121955321027), np.float64(5394.34815245214), np.float64(4336.780075623462), np.float64(3484.4121258921264), np.float64(69.91712173868306), np.float64(132.6667017321747), np.float64(202.3064307064511), np.float64(292.7815491344932), np.float64(415.3181172762701), np.float64(8031.967790466431), np.float64(6425.574232373146), np.float64(5140.459385898517), np.float64(4112.367508718814), np.float64(3289.8940069750515), np.float64(2631.9152055800414), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824)]
#
#
# Column: P_V1
#   Actual: 264.7218610578747
#   Predicted: 59.25924148452371
# ------------------------------
# Column: P_V2
#   Actual: 597.792868161768
#   Predicted: 97.77941222871075
# ------------------------------
# Column: P_V3
#   Actual: 1021.4971765846636
#   Predicted: 144.05476980861212
# ------------------------------
# Column: P_V4
#   Actual: 1527.6290400502362
#   Predicted: 203.45895496769876
# ------------------------------
# Column: P_V5
#   Actual: 2090.21184648746
#   Predicted: 276.95278626694454
# ------------------------------
# Column: P_IP_x1
#   Actual: 838.7616798242112
#   Predicted: -120.06033613456911
# ------------------------------
# Column: P_IP_x2
#   Actual: 1773.5018772362305
#   Predicted: -61.350857811866405
# ------------------------------
# Column: P_IP_x3
#   Actual: 2621.6858633043994
#   Predicted: -29.332271262929694
# ------------------------------
# Column: P_IP_x4
#   Actual: 3406.0997128038107
#   Predicted: -14.19656810657934
# ------------------------------
# Column: P_IP_x5
#   Actual: 4112.375400436008
#   Predicted: -6.4789592721611164
# ------------------------------
# Column: P_IP_y1
#   Actual: 134.08662105693085
#   Predicted: 69.58938313248983
# ------------------------------
# Column: P_IP_y2
#   Actual: 289.44665418715675
#   Predicted: 133.23633304501018
# ------------------------------
# Column: P_IP_y3
#   Actual: 440.67862038528193
#   Predicted: 202.29275134509825
# ------------------------------
# Column: P_IP_y4
#   Actual: 563.8927079207249
#   Predicted: 292.3683314055428
# ------------------------------
# Column: P_IP_y5
#   Actual: 622.3490696673398
#   Predicted: 414.76992788374497
# ------------------------------
# Column: P_FP_x0
#   Actual: 1006.8593328683568
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x1
#   Actual: 1926.115261605543
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x2
#   Actual: 2705.18930864762
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x3
#   Actual: 3467.023171059204
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x4
#   Actual: 4191.913860839831
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4819.136214960309
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 90.87004913739013
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 255.0817928119203
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 407.2506432733968
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 559.6150522465692
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 645.7192009389779
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 632.3660004195016
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 880.8971410320984
#   Predicted: 690.0235745470186
# ------------------------------
# Column: I_V2
#   Actual: 1676.3875656989746
#   Predicted: 1242.1210221223512
# ------------------------------
# Column: I_V3
#   Actual: 2402.8269570079533
#   Predicted: 1698.9189555480382
# ------------------------------
# Column: I_V4
#   Actual: 3067.412145792541
#   Predicted: 2085.629316458043
# ------------------------------
# Column: I_V5
#   Actual: 3630.558809047295
#   Predicted: 2420.7046512606294
# ------------------------------
# Column: I_IP_x1
#   Actual: 9118.11852779202
#   Predicted: 8199.623118683128
# ------------------------------
# Column: I_IP_x2
#   Actual: 8218.585207712218
#   Predicted: 6660.236429441463
# ------------------------------
# Column: I_IP_x3
#   Actual: 7380.889165881504
#   Predicted: 5373.439464241451
# ------------------------------
# Column: I_IP_x4
#   Actual: 6602.09021916827
#   Predicted: 4319.931854157489
# ------------------------------
# Column: I_IP_x5
#   Actual: 5701.219482408089
#   Predicted: 3470.901094223248
# ------------------------------
# Column: I_IP_y1
#   Actual: 137.68353733075554
#   Predicted: 69.91712173868306
# ------------------------------
# Column: I_IP_y2
#   Actual: 292.93484351933904
#   Predicted: 132.6667017321747
# ------------------------------
# Column: I_IP_y3
#   Actual: 383.87139184361325
#   Predicted: 202.3064307064511
# ------------------------------
# Column: I_IP_y4
#   Actual: 467.83498711554574
#   Predicted: 292.7815491344932
# ------------------------------
# Column: I_IP_y5
#   Actual: 541.6854522358245
#   Predicted: 415.3181172762701
# ------------------------------
# Column: I_FP_x0
#   Actual: 9132.979818120744
#   Predicted: 8000.9216975412455
# ------------------------------
# Column: I_FP_x1
#   Actual: 8216.260073065885
#   Predicted: 6400.737358032997
# ------------------------------
# Column: I_FP_x2
#   Actual: 7335.857026379778
#   Predicted: 5120.589886426398
# ------------------------------
# Column: I_FP_x3
#   Actual: 6540.182678755594
#   Predicted: 4096.471909141119
# ------------------------------
# Column: I_FP_x4
#   Actual: 5843.816372224777
#   Predicted: 3277.177527312895
# ------------------------------
# Column: I_FP_x5
#   Actual: 4831.788233645472
#   Predicted: 2621.742021850316
# ------------------------------
# Column: I_FP_y0
#   Actual: 129.66161589859777
#   Predicted: 100
# ------------------------------
# Column: I_FP_y1
#   Actual: 258.80217748382563
#   Predicted: 140.0
# ------------------------------
# Column: I_FP_y2
#   Actual: 424.0187798980869
#   Predicted: 196.0
# ------------------------------
# Column: I_FP_y3
#   Actual: 526.6046480696817
#   Predicted: 274.4
# ------------------------------
# Column: I_FP_y4
#   Actual: 609.1222011050435
#   Predicted: 384.15999999999997
# ------------------------------
# Column: I_FP_y5
#   Actual: 623.0863596719145
#   Predicted: 537.824
# ------------------------------
# ================================================== ROW 2 SUMMARY ==================================================
# Actual Values: [np.float64(264.7218610578747), np.float64(597.792868161768), np.float64(1021.4971765846636), np.float64(1527.6290400502362), np.float64(2090.21184648746), np.float64(838.7616798242112), np.float64(1773.5018772362305), np.float64(2621.6858633043994), np.float64(3406.0997128038107), np.float64(4112.375400436008), np.float64(134.08662105693085), np.float64(289.44665418715675), np.float64(440.67862038528193), np.float64(563.8927079207249), np.float64(622.3490696673398), np.float64(1006.8593328683568), np.float64(1926.115261605543), np.float64(2705.18930864762), np.float64(3467.023171059204), np.float64(4191.913860839831), np.float64(4819.136214960309), np.float64(90.87004913739013), np.float64(255.0817928119203), np.float64(407.2506432733968), np.float64(559.6150522465692), np.float64(645.7192009389779), np.float64(632.3660004195016), np.float64(880.8971410320984), np.float64(1676.3875656989746), np.float64(2402.8269570079533), np.float64(3067.412145792541), np.float64(3630.558809047295), np.float64(9118.11852779202), np.float64(8218.585207712218), np.float64(7380.889165881504), np.float64(6602.09021916827), np.float64(5701.219482408089), np.float64(137.68353733075554), np.float64(292.93484351933904), np.float64(383.87139184361325), np.float64(467.83498711554574), np.float64(541.6854522358245), np.float64(9132.979818120744), np.float64(8216.260073065885), np.float64(7335.857026379778), np.float64(6540.182678755594), np.float64(5843.816372224777), np.float64(4831.788233645472), np.float64(129.66161589859777), np.float64(258.80217748382563), np.float64(424.0187798980869), np.float64(526.6046480696817), np.float64(609.1222011050435), np.float64(623.0863596719145)]
# Predicted Values: [np.float64(59.25924148452371), np.float64(97.77941222871075), np.float64(144.05476980861212), np.float64(203.45895496769876), np.float64(276.95278626694454), np.float64(-120.06033613456911), np.float64(-61.350857811866405), np.float64(-29.332271262929694), np.float64(-14.19656810657934), np.float64(-6.4789592721611164), np.float64(69.58938313248983), np.float64(133.23633304501018), np.float64(202.29275134509825), np.float64(292.3683314055428), np.float64(414.76992788374497), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824), np.float64(690.0235745470186), np.float64(1242.1210221223512), np.float64(1698.9189555480382), np.float64(2085.629316458043), np.float64(2420.7046512606294), np.float64(8199.623118683128), np.float64(6660.236429441463), np.float64(5373.439464241451), np.float64(4319.931854157489), np.float64(3470.901094223248), np.float64(69.91712173868306), np.float64(132.6667017321747), np.float64(202.3064307064511), np.float64(292.7815491344932), np.float64(415.3181172762701), np.float64(8000.9216975412455), np.float64(6400.737358032997), np.float64(5120.589886426398), np.float64(4096.471909141119), np.float64(3277.177527312895), np.float64(2621.742021850316), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824)]
#
#
# Column: P_V1
#   Actual: 265.7982489952779
#   Predicted: 73.37695157637404
# ------------------------------
# Column: P_V2
#   Actual: 606.9866628659862
#   Predicted: 135.89105958141818
# ------------------------------
# Column: P_V3
#   Actual: 1029.8005453571948
#   Predicted: 215.71503843828103
# ------------------------------
# Column: P_V4
#   Actual: 1533.026173043862
#   Predicted: 321.8456934954223
# ------------------------------
# Column: P_V5
#   Actual: 2107.419485379545
#   Predicted: 460.9313849863131
# ------------------------------
# Column: P_IP_x1
#   Actual: 1013.5008425777232
#   Predicted: 129.1803349368255
# ------------------------------
# Column: P_IP_x2
#   Actual: 1883.129699623822
#   Predicted: 182.85044680028136
# ------------------------------
# Column: P_IP_x3
#   Actual: 2692.351342724233
#   Predicted: 259.88850972537756
# ------------------------------
# Column: P_IP_x4
#   Actual: 3460.5328193240725
#   Predicted: 364.5182423855357
# ------------------------------
# Column: P_IP_x5
#   Actual: 4179.976874791498
#   Predicted: 510.63328497738416
# ------------------------------
# Column: P_IP_y1
#   Actual: 140.10458102948826
#   Predicted: 69.58938313248983
# ------------------------------
# Column: P_IP_y2
#   Actual: 304.4430093936382
#   Predicted: 133.23633304501018
# ------------------------------
# Column: P_IP_y3
#   Actual: 463.7697958376053
#   Predicted: 202.29275134509825
# ------------------------------
# Column: P_IP_y4
#   Actual: 558.989152762064
#   Predicted: 292.3683314055428
# ------------------------------
# Column: P_IP_y5
#   Actual: 597.6794114452451
#   Predicted: 414.76992788374497
# ------------------------------
# Column: P_FP_x0
#   Actual: 1017.5183847900508
#   Predicted: 121.9037741252869
# ------------------------------
# Column: P_FP_x1
#   Actual: 1939.118996007954
#   Predicted: 170.66528377540166
# ------------------------------
# Column: P_FP_x2
#   Actual: 2746.90832135308
#   Predicted: 238.9313972855623
# ------------------------------
# Column: P_FP_x3
#   Actual: 3501.2055129846067
#   Predicted: 334.5039561997872
# ------------------------------
# Column: P_FP_x4
#   Actual: 4226.014830024095
#   Predicted: 468.305538679702
# ------------------------------
# Column: P_FP_x5
#   Actual: 4897.7206652876885
#   Predicted: 655.6277541515827
# ------------------------------
# Column: P_FP_y0
#   Actual: 135.9006464930713
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 274.7663093683672
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 450.10385333960784
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 568.8874440740078
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 620.283915683784
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 628.985751070963
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 881.9280926253949
#   Predicted: 690.6123830735935
# ------------------------------
# Column: I_V2
#   Actual: 1677.4763458014395
#   Predicted: 1240.7821818497055
# ------------------------------
# Column: I_V3
#   Actual: 2399.372562027314
#   Predicted: 1696.0338309441288
# ------------------------------
# Column: I_V4
#   Actual: 3057.205703305422
#   Predicted: 2081.510286713938
# ------------------------------
# Column: I_V5
#   Actual: 3622.914768751813
#   Predicted: 2415.5922525384135
# ------------------------------
# Column: I_IP_x1
#   Actual: 9058.31035595345
#   Predicted: 8168.643414632122
# ------------------------------
# Column: I_IP_x2
#   Actual: 8206.820152777356
#   Predicted: 6635.059124755456
# ------------------------------
# Column: I_IP_x3
#   Actual: 7334.271092365834
#   Predicted: 5353.1028322520315
# ------------------------------
# Column: I_IP_x4
#   Actual: 6509.345713946673
#   Predicted: 4303.544595608455
# ------------------------------
# Column: I_IP_x5
#   Actual: 5710.678875895397
#   Predicted: 3457.759720834416
# ------------------------------
# Column: I_IP_y1
#   Actual: 152.05712273855625
#   Predicted: 69.91712173868306
# ------------------------------
# Column: I_IP_y2
#   Actual: 308.2367544415739
#   Predicted: 132.6667017321747
# ------------------------------
# Column: I_IP_y3
#   Actual: 407.6794774954851
#   Predicted: 202.3064307064511
# ------------------------------
# Column: I_IP_y4
#   Actual: 535.6466547439979
#   Predicted: 292.7815491344932
# ------------------------------
# Column: I_IP_y5
#   Actual: 578.6649119381683
#   Predicted: 415.3181172762701
# ------------------------------
# Column: I_FP_x0
#   Actual: 9199.228180019683
#   Predicted: 7970.725017569424
# ------------------------------
# Column: I_FP_x1
#   Actual: 8147.78228496951
#   Predicted: 6376.58001405554
# ------------------------------
# Column: I_FP_x2
#   Actual: 7320.353533653149
#   Predicted: 5101.264011244432
# ------------------------------
# Column: I_FP_x3
#   Actual: 6511.513218587287
#   Predicted: 4081.011208995546
# ------------------------------
# Column: I_FP_x4
#   Actual: 5755.386645731217
#   Predicted: 3264.808967196437
# ------------------------------
# Column: I_FP_x5
#   Actual: 4883.607736474831
#   Predicted: 2611.84717375715
# ------------------------------
# Column: I_FP_y0
#   Actual: 168.88186604657682
#   Predicted: 100
# ------------------------------
# Column: I_FP_y1
#   Actual: 289.8896417476867
#   Predicted: 140.0
# ------------------------------
# Column: I_FP_y2
#   Actual: 442.4198132541895
#   Predicted: 196.0
# ------------------------------
# Column: I_FP_y3
#   Actual: 525.614130281149
#   Predicted: 274.4
# ------------------------------
# Column: I_FP_y4
#   Actual: 634.2557143374305
#   Predicted: 384.15999999999997
# ------------------------------
# Column: I_FP_y5
#   Actual: 606.4765315681188
#   Predicted: 537.824
# ------------------------------
# ================================================== ROW 3 SUMMARY ==================================================
# Actual Values: [np.float64(265.7982489952779), np.float64(606.9866628659862), np.float64(1029.8005453571948), np.float64(1533.026173043862), np.float64(2107.419485379545), np.float64(1013.5008425777232), np.float64(1883.129699623822), np.float64(2692.351342724233), np.float64(3460.5328193240725), np.float64(4179.976874791498), np.float64(140.10458102948826), np.float64(304.4430093936382), np.float64(463.7697958376053), np.float64(558.989152762064), np.float64(597.6794114452451), np.float64(1017.5183847900508), np.float64(1939.118996007954), np.float64(2746.90832135308), np.float64(3501.2055129846067), np.float64(4226.014830024095), np.float64(4897.7206652876885), np.float64(135.9006464930713), np.float64(274.7663093683672), np.float64(450.10385333960784), np.float64(568.8874440740078), np.float64(620.283915683784), np.float64(628.985751070963), np.float64(881.9280926253949), np.float64(1677.4763458014395), np.float64(2399.372562027314), np.float64(3057.205703305422), np.float64(3622.914768751813), np.float64(9058.31035595345), np.float64(8206.820152777356), np.float64(7334.271092365834), np.float64(6509.345713946673), np.float64(5710.678875895397), np.float64(152.05712273855625), np.float64(308.2367544415739), np.float64(407.6794774954851), np.float64(535.6466547439979), np.float64(578.6649119381683), np.float64(9199.228180019683), np.float64(8147.78228496951), np.float64(7320.353533653149), np.float64(6511.513218587287), np.float64(5755.386645731217), np.float64(4883.607736474831), np.float64(168.88186604657682), np.float64(289.8896417476867), np.float64(442.4198132541895), np.float64(525.614130281149), np.float64(634.2557143374305), np.float64(606.4765315681188)]
# Predicted Values: [np.float64(73.37695157637404), np.float64(135.89105958141818), np.float64(215.71503843828103), np.float64(321.8456934954223), np.float64(460.9313849863131), np.float64(129.1803349368255), np.float64(182.85044680028136), np.float64(259.88850972537756), np.float64(364.5182423855357), np.float64(510.63328497738416), np.float64(69.58938313248983), np.float64(133.23633304501018), np.float64(202.29275134509825), np.float64(292.3683314055428), np.float64(414.76992788374497), np.float64(121.9037741252869), np.float64(170.66528377540166), np.float64(238.9313972855623), np.float64(334.5039561997872), np.float64(468.305538679702), np.float64(655.6277541515827), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824), np.float64(690.6123830735935), np.float64(1240.7821818497055), np.float64(1696.0338309441288), np.float64(2081.510286713938), np.float64(2415.5922525384135), np.float64(8168.643414632122), np.float64(6635.059124755456), np.float64(5353.1028322520315), np.float64(4303.544595608455), np.float64(3457.759720834416), np.float64(69.91712173868306), np.float64(132.6667017321747), np.float64(202.3064307064511), np.float64(292.7815491344932), np.float64(415.3181172762701), np.float64(7970.725017569424), np.float64(6376.58001405554), np.float64(5101.264011244432), np.float64(4081.011208995546), np.float64(3264.808967196437), np.float64(2611.84717375715), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824)]
#
#
# Column: P_V1
#   Actual: 258.2853675378795
#   Predicted: 107.64026261620137
# ------------------------------
# Column: P_V2
#   Actual: 591.6342516789953
#   Predicted: 220.7976865704997
# ------------------------------
# Column: P_V3
#   Actual: 1010.6057978923576
#   Predicted: 371.43748354504766
# ------------------------------
# Column: P_V4
#   Actual: 1511.8399364492716
#   Predicted: 576.1926879294549
# ------------------------------
# Column: P_V5
#   Actual: 2070.0266278998643
#   Predicted: 853.7222103270934
# ------------------------------
# Column: P_IP_x1
#   Actual: 1089.9564197329776
#   Predicted: 401.1199149977269
# ------------------------------
# Column: P_IP_x2
#   Actual: 1906.3551648415105
#   Predicted: 571.2180651373166
# ------------------------------
# Column: P_IP_x3
#   Actual: 2677.068459365264
#   Predicted: 806.8132357129455
# ------------------------------
# Column: P_IP_x4
#   Actual: 3410.132958001618
#   Predicted: 1132.1214385257088
# ------------------------------
# Column: P_IP_x5
#   Actual: 4098.93526787734
#   Predicted: 1586.2286764049925
# ------------------------------
# Column: P_IP_y1
#   Actual: 142.13420402202442
#   Predicted: 69.58938313248983
# ------------------------------
# Column: P_IP_y2
#   Actual: 269.5637272917242
#   Predicted: 133.23633304501018
# ------------------------------
# Column: P_IP_y3
#   Actual: 401.1319069515524
#   Predicted: 202.29275134509825
# ------------------------------
# Column: P_IP_y4
#   Actual: 501.4437950911243
#   Predicted: 292.3683314055428
# ------------------------------
# Column: P_IP_y5
#   Actual: 565.2089753963181
#   Predicted: 414.76992788374497
# ------------------------------
# Column: P_FP_x0
#   Actual: 1016.0072912622452
#   Predicted: 379.2031238940539
# ------------------------------
# Column: P_FP_x1
#   Actual: 1910.9784568522543
#   Predicted: 530.8843734516754
# ------------------------------
# Column: P_FP_x2
#   Actual: 2721.135157711423
#   Predicted: 743.2381228323455
# ------------------------------
# Column: P_FP_x3
#   Actual: 3441.588650347025
#   Predicted: 1040.5333719652838
# ------------------------------
# Column: P_FP_x4
#   Actual: 4138.279154341289
#   Predicted: 1456.746720751397
# ------------------------------
# Column: P_FP_x5
#   Actual: 4788.491096391818
#   Predicted: 2039.4454090519557
# ------------------------------
# Column: P_FP_y0
#   Actual: 104.79612262797464
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 282.16545368710536
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 425.29323793812574
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 547.9691629556477
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 625.5572656693998
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 610.8430184332364
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 890.0784366823411
#   Predicted: 701.4171486519189
# ------------------------------
# Column: I_V2
#   Actual: 1691.6554829843665
#   Predicted: 1256.0836810342023
# ------------------------------
# Column: I_V3
#   Actual: 2425.158492261846
#   Predicted: 1714.9492511560932
# ------------------------------
# Column: I_V4
#   Actual: 3097.2808999163826
#   Predicted: 2103.3089028462364
# ------------------------------
# Column: I_V5
#   Actual: 3650.73283601874
#   Predicted: 2439.7063016795987
# ------------------------------
# Column: I_IP_x1
#   Actual: 9089.6544872491
#   Predicted: 8240.832540609515
# ------------------------------
# Column: I_IP_x2
#   Actual: 8206.48595486537
#   Predicted: 6693.727458602575
# ------------------------------
# Column: I_IP_x3
#   Actual: 7415.336800915241
#   Predicted: 5400.491396268747
# ------------------------------
# Column: I_IP_x4
#   Actual: 6673.145014301791
#   Predicted: 4341.7303016394935
# ------------------------------
# Column: I_IP_x5
#   Actual: 5697.406533267443
#   Predicted: 3488.3818422568943
# ------------------------------
# Column: I_IP_y1
#   Actual: 131.57023299459476
#   Predicted: 69.91712173868306
# ------------------------------
# Column: I_IP_y2
#   Actual: 284.03299052272604
#   Predicted: 132.6667017321747
# ------------------------------
# Column: I_IP_y3
#   Actual: 375.9740355132899
#   Predicted: 202.3064307064511
# ------------------------------
# Column: I_IP_y4
#   Actual: 472.7206912705872
#   Predicted: 292.7815491344932
# ------------------------------
# Column: I_IP_y5
#   Actual: 541.7492598236674
#   Predicted: 415.3181172762701
# ------------------------------
# Column: I_FP_x0
#   Actual: 9203.08252002865
#   Predicted: 8041.089535287083
# ------------------------------
# Column: I_FP_x1
#   Actual: 8204.414855862688
#   Predicted: 6432.871628229666
# ------------------------------
# Column: I_FP_x2
#   Actual: 7364.228871998627
#   Predicted: 5146.297302583734
# ------------------------------
# Column: I_FP_x3
#   Actual: 6601.350350229342
#   Predicted: 4117.037842066987
# ------------------------------
# Column: I_FP_x4
#   Actual: 5896.702327064533
#   Predicted: 3293.6302736535895
# ------------------------------
# Column: I_FP_x5
#   Actual: 4757.979350415257
#   Predicted: 2634.9042189228717
# ------------------------------
# Column: I_FP_y0
#   Actual: 129.1869997702123
#   Predicted: 100
# ------------------------------
# Column: I_FP_y1
#   Actual: 273.0996840815719
#   Predicted: 140.0
# ------------------------------
# Column: I_FP_y2
#   Actual: 433.6597771146319
#   Predicted: 196.0
# ------------------------------
# Column: I_FP_y3
#   Actual: 513.81343076362
#   Predicted: 274.4
# ------------------------------
# Column: I_FP_y4
#   Actual: 589.38067369094
#   Predicted: 384.15999999999997
# ------------------------------
# Column: I_FP_y5
#   Actual: 606.8000280306459
#   Predicted: 537.824
# ------------------------------
# ================================================== ROW 4 SUMMARY ==================================================
# Actual Values: [np.float64(258.2853675378795), np.float64(591.6342516789953), np.float64(1010.6057978923576), np.float64(1511.8399364492716), np.float64(2070.0266278998643), np.float64(1089.9564197329776), np.float64(1906.3551648415105), np.float64(2677.068459365264), np.float64(3410.132958001618), np.float64(4098.93526787734), np.float64(142.13420402202442), np.float64(269.5637272917242), np.float64(401.1319069515524), np.float64(501.4437950911243), np.float64(565.2089753963181), np.float64(1016.0072912622452), np.float64(1910.9784568522543), np.float64(2721.135157711423), np.float64(3441.588650347025), np.float64(4138.279154341289), np.float64(4788.491096391818), np.float64(104.79612262797464), np.float64(282.16545368710536), np.float64(425.29323793812574), np.float64(547.9691629556477), np.float64(625.5572656693998), np.float64(610.8430184332364), np.float64(890.0784366823411), np.float64(1691.6554829843665), np.float64(2425.158492261846), np.float64(3097.2808999163826), np.float64(3650.73283601874), np.float64(9089.6544872491), np.float64(8206.48595486537), np.float64(7415.336800915241), np.float64(6673.145014301791), np.float64(5697.406533267443), np.float64(131.57023299459476), np.float64(284.03299052272604), np.float64(375.9740355132899), np.float64(472.7206912705872), np.float64(541.7492598236674), np.float64(9203.08252002865), np.float64(8204.414855862688), np.float64(7364.228871998627), np.float64(6601.350350229342), np.float64(5896.702327064533), np.float64(4757.979350415257), np.float64(129.1869997702123), np.float64(273.0996840815719), np.float64(433.6597771146319), np.float64(513.81343076362), np.float64(589.38067369094), np.float64(606.8000280306459)]
# Predicted Values: [np.float64(107.64026261620137), np.float64(220.7976865704997), np.float64(371.43748354504766), np.float64(576.1926879294549), np.float64(853.7222103270934), np.float64(401.1199149977269), np.float64(571.2180651373166), np.float64(806.8132357129455), np.float64(1132.1214385257088), np.float64(1586.2286764049925), np.float64(69.58938313248983), np.float64(133.23633304501018), np.float64(202.29275134509825), np.float64(292.3683314055428), np.float64(414.76992788374497), np.float64(379.2031238940539), np.float64(530.8843734516754), np.float64(743.2381228323455), np.float64(1040.5333719652838), np.float64(1456.746720751397), np.float64(2039.4454090519557), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824), np.float64(701.4171486519189), np.float64(1256.0836810342023), np.float64(1714.9492511560932), np.float64(2103.3089028462364), np.float64(2439.7063016795987), np.float64(8240.832540609515), np.float64(6693.727458602575), np.float64(5400.491396268747), np.float64(4341.7303016394935), np.float64(3488.3818422568943), np.float64(69.91712173868306), np.float64(132.6667017321747), np.float64(202.3064307064511), np.float64(292.7815491344932), np.float64(415.3181172762701), np.float64(8041.089535287083), np.float64(6432.871628229666), np.float64(5146.297302583734), np.float64(4117.037842066987), np.float64(3293.6302736535895), np.float64(2634.9042189228717), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824)]
#
#
# Column: P_V1
#   Actual: 253.6989958356449
#   Predicted: 102.04674931235647
# ------------------------------
# Column: P_V2
#   Actual: 588.5519134352307
#   Predicted: 205.76608605043148
# ------------------------------
# Column: P_V3
#   Actual: 1015.0907189026094
#   Predicted: 343.20938073980403
# ------------------------------
# Column: P_V4
#   Actual: 1517.642615087542
#   Predicted: 529.5845850272001
# ------------------------------
# Column: P_V5
#   Actual: 2087.3575137077723
#   Predicted: 781.3133436529511
# ------------------------------
# Column: P_IP_x1
#   Actual: 1066.3178491563842
#   Predicted: 350.4402894514705
# ------------------------------
# Column: P_IP_x2
#   Actual: 1897.4166320914164
#   Predicted: 498.8404970495653
# ------------------------------
# Column: P_IP_x3
#   Actual: 2682.4831173123694
#   Predicted: 704.886402153699
# ------------------------------
# Column: P_IP_x4
#   Actual: 3446.2017703294364
#   Predicted: 989.068181843539
# ------------------------------
# Column: P_IP_x5
#   Actual: 4153.198705327464
#   Predicted: 1385.7769008134348
# ------------------------------
# Column: P_IP_y1
#   Actual: 101.30096259030655
#   Predicted: 69.58938313248983
# ------------------------------
# Column: P_IP_y2
#   Actual: 238.8440295800389
#   Predicted: 133.23633304501018
# ------------------------------
# Column: P_IP_y3
#   Actual: 402.5801836968499
#   Predicted: 202.29275134509825
# ------------------------------
# Column: P_IP_y4
#   Actual: 570.868392359372
#   Predicted: 292.3683314055428
# ------------------------------
# Column: P_IP_y5
#   Actual: 619.9779417025082
#   Predicted: 414.76992788374497
# ------------------------------
# Column: P_FP_x0
#   Actual: 985.2474909346356
#   Predicted: 331.2519036389661
# ------------------------------
# Column: P_FP_x1
#   Actual: 1894.3158455457403
#   Predicted: 463.7526650945525
# ------------------------------
# Column: P_FP_x2
#   Actual: 2725.694871621964
#   Predicted: 649.2537311323734
# ------------------------------
# Column: P_FP_x3
#   Actual: 3466.2980832739363
#   Predicted: 908.9552235853228
# ------------------------------
# Column: P_FP_x4
#   Actual: 4207.548908808975
#   Predicted: 1272.5373130194519
# ------------------------------
# Column: P_FP_x5
#   Actual: 4856.816316921744
#   Predicted: 1781.5522382272325
# ------------------------------
# Column: P_FP_y0
#   Actual: 100.50941965920632
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 254.38316769087783
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 424.20377109818367
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 568.7243535592887
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 646.6277489927716
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 625.678378624519
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 889.795816684719
#   Predicted: 691.6793857002767
# ------------------------------
# Column: I_V2
#   Actual: 1687.8798490253307
#   Predicted: 1240.476184147415
# ------------------------------
# Column: I_V3
#   Actual: 2419.5193049573554
#   Predicted: 1694.6268287197065
# ------------------------------
# Column: I_V4
#   Actual: 3078.662373939452
# ...
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4869.325001048081
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 92.09264800096756
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 270.2005118013791
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 435.0606955375637
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 554.1325454458536
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 599.7281790099366
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 584.2422841924147
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 873.1815223487647
#   Predicted: 678.4684588202372
# ------------------------------
# Column: I_V2
#   Actual: 1661.3149521641594
#   Predicted: 1223.7034424059443
# ------------------------------
# Column: I_V3
#   Actual: 2383.741333108357
#   Predicted: 1674.988934008392
# ------------------------------
# Column: I_V4
#   Actual: 3034.834813253128
#   Predicted: 2057.3011937708925
# ------------------------------
# Column: I_V5
#   Actual: 3599.8008792187384
#   Predicted: 2388.842195681736
# ------------------------------
# Column: I_IP_x1
#   Actual: 9013.493230615351
#   Predicted: 8089.4233243721765
# ------------------------------
# Column: I_IP_x2
#   Actual: 8159.160457186026
#   Predicted: 6570.6767037212285
# ------------------------------
# Column: I_IP_x3
#   Actual: 7336.558262359807
#   Predicted: 5301.098790537091
# ------------------------------
# Column: I_IP_x4
#   Actual: 6592.811172735148
#   Predicted: 4261.639737536535
# ------------------------------
# Column: I_IP_x5
#   Actual: 5753.5597459346845
#   Predicted: 3424.155113628069
# ------------------------------
# Column: I_IP_y1
#   Actual: 139.12841178229417
#   Predicted: 69.91712173868306
# ------------------------------
# Column: I_IP_y2
#   Actual: 279.72492245206075
#   Predicted: 132.6667017321747
# ------------------------------
# Column: I_IP_y3
#   Actual: 409.49041566763066
#   Predicted: 202.3064307064511
# ------------------------------
# Column: I_IP_y4
#   Actual: 486.0108951342218
#   Predicted: 292.7815491344932
# ------------------------------
# Column: I_IP_y5
#   Actual: 546.23648070863
#   Predicted: 415.3181172762701
# ------------------------------
# Column: I_FP_x0
#   Actual: 8718.91367851097
#   Predicted: 7893.507245928359
# ------------------------------
# Column: I_FP_x1
#   Actual: 8116.391378862772
#   Predicted: 6314.805796742688
# ------------------------------
# Column: I_FP_x2
#   Actual: 7315.100303735386
#   Predicted: 5051.844637394151
# ------------------------------
# Column: I_FP_x3
#   Actual: 6518.579734949059
#   Predicted: 4041.4757099153207
# ------------------------------
# Column: I_FP_x4
#   Actual: 5766.468113139748
#   Predicted: 3233.180567932257
# ------------------------------
# Column: I_FP_x5
#   Actual: 4854.046856688083
#   Predicted: 2586.5444543458057
# ------------------------------
# Column: I_FP_y0
#   Actual: 126.6282695790054
#   Predicted: 100
# ------------------------------
# Column: I_FP_y1
#   Actual: 279.96895661242627
#   Predicted: 140.0
# ------------------------------
# Column: I_FP_y2
#   Actual: 405.2595117070142
#   Predicted: 196.0
# ------------------------------
# Column: I_FP_y3
#   Actual: 500.8597863013061
#   Predicted: 274.4
# ------------------------------
# Column: I_FP_y4
#   Actual: 551.9913001775261
#   Predicted: 384.15999999999997
# ------------------------------
# Column: I_FP_y5
#   Actual: 610.2681145455623
#   Predicted: 537.824
# ------------------------------
# ================================================== ROW 98 SUMMARY ==================================================
# Actual Values: [np.float64(262.95558098077686), np.float64(599.1826877447821), np.float64(1022.4280238628476), np.float64(1521.1049087005997), np.float64(2089.3066845155563), np.float64(947.0660929014952), np.float64(1841.9861162245008), np.float64(2664.9786256377724), np.float64(3428.8078571477186), np.float64(4146.665296592995), np.float64(131.07769353258468), np.float64(286.90644602337767), np.float64(407.5955756533716), np.float64(495.99699988806265), np.float64(518.0811964539731), np.float64(1009.4616842819572), np.float64(1938.5445858119697), np.float64(2735.1295555026586), np.float64(3486.5952389480767), np.float64(4194.047910660666), np.float64(4869.325001048081), np.float64(92.09264800096756), np.float64(270.2005118013791), np.float64(435.0606955375637), np.float64(554.1325454458536), np.float64(599.7281790099366), np.float64(584.2422841924147), np.float64(873.1815223487647), np.float64(1661.3149521641594), np.float64(2383.741333108357), np.float64(3034.834813253128), np.float64(3599.8008792187384), np.float64(9013.493230615351), np.float64(8159.160457186026), np.float64(7336.558262359807), np.float64(6592.811172735148), np.float64(5753.5597459346845), np.float64(139.12841178229417), np.float64(279.72492245206075), np.float64(409.49041566763066), np.float64(486.0108951342218), np.float64(546.23648070863), np.float64(8718.91367851097), np.float64(8116.391378862772), np.float64(7315.100303735386), np.float64(6518.579734949059), np.float64(5766.468113139748), np.float64(4854.046856688083), np.float64(126.6282695790054), np.float64(279.96895661242627), np.float64(405.2595117070142), np.float64(500.8597863013061), np.float64(551.9913001775261), np.float64(610.2681145455623)]
# Predicted Values: [np.float64(56.089254513560576), np.float64(94.60950158664583), np.float64(140.88091636906177), np.float64(200.28501730579367), np.float64(273.77836808680166), np.float64(-21.98822133120028), np.float64(-12.315250782451491), np.float64(-4.816204501946658), np.float64(-1.947137575531068), np.float64(-0.35793961335756763), np.float64(69.58938313248983), np.float64(133.23633304501018), np.float64(202.29275134509825), np.float64(292.3683314055428), np.float64(414.76992788374497), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824), np.float64(678.4684588202372), np.float64(1223.7034424059443), np.float64(1674.988934008392), np.float64(2057.3011937708925), np.float64(2388.842195681736), np.float64(8089.4233243721765), np.float64(6570.6767037212285), np.float64(5301.098790537091), np.float64(4261.639737536535), np.float64(3424.155113628069), np.float64(69.91712173868306), np.float64(132.6667017321747), np.float64(202.3064307064511), np.float64(292.7815491344932), np.float64(415.3181172762701), np.float64(7893.507245928359), np.float64(6314.805796742688), np.float64(5051.844637394151), np.float64(4041.4757099153207), np.float64(3233.180567932257), np.float64(2586.5444543458057), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824)]
#
#
# Column: P_V1
#   Actual: 257.6241762753771
#   Predicted: 64.22542527235049
# ------------------------------
# Column: P_V2
#   Actual: 585.453676336625
#   Predicted: 122.38792129799924
# ------------------------------
# Column: P_V3
#   Actual: 1007.9925353237676
#   Predicted: 196.11900248133162
# ------------------------------
# Column: P_V4
#   Actual: 1514.2481726669391
#   Predicted: 293.7747215066379
# ------------------------------
# Column: P_V5
#   Actual: 2092.2454424853527
#   Predicted: 420.9630447959167
# ------------------------------
# Column: P_IP_x1
#   Actual: 1004.9308529846998
#   Predicted: 105.81266722012397
# ------------------------------
# Column: P_IP_x2
#   Actual: 1858.485340687361
#   Predicted: 149.4781607388181
# ------------------------------
# Column: P_IP_x3
#   Actual: 2663.044880833452
#   Predicted: 212.8914699415281
# ------------------------------
# Column: P_IP_x4
#   Actual: 3409.0808248173603
#   Predicted: 298.55838313421026
# ------------------------------
# Column: P_IP_x5
#   Actual: 4132.196086838643
#   Predicted: 418.20777009328026
# ------------------------------
# Column: P_IP_y1
#   Actual: 130.1941343852409
#   Predicted: 69.58938313248983
# ------------------------------
# Column: P_IP_y2
#   Actual: 248.19472973449916
#   Predicted: 133.23633304501018
# ------------------------------
# Column: P_IP_y3
#   Actual: 412.91383445792246
#   Predicted: 202.29275134509825
# ------------------------------
# Column: P_IP_y4
#   Actual: 606.878228614831
#   Predicted: 292.3683314055428
# ------------------------------
# Column: P_IP_y5
#   Actual: 653.4168714979659
#   Predicted: 414.76992788374497
# ------------------------------
# Column: P_FP_x0
#   Actual: 1022.495512258016
#   Predicted: 99.79413599253182
# ------------------------------
# Column: P_FP_x1
#   Actual: 1935.716942537468
#   Predicted: 139.71179038954455
# ------------------------------
# Column: P_FP_x2
#   Actual: 2714.5282949151724
#   Predicted: 195.59650654536236
# ------------------------------
# Column: P_FP_x3
#   Actual: 3466.9728904202207
#   Predicted: 273.8351091635073
# ------------------------------
# Column: P_FP_x4
#   Actual: 4162.099518518652
#   Predicted: 383.3691528289102
# ------------------------------
# Column: P_FP_x5
#   Actual: 4855.573418707787
#   Predicted: 536.7168139604743
# ------------------------------
# Column: P_FP_y0
#   Actual: 79.37602427907558
#   Predicted: 100
# ------------------------------
# Column: P_FP_y1
#   Actual: 250.72796336513315
#   Predicted: 140.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 415.7283006210283
#   Predicted: 196.0
# ------------------------------
# Column: P_FP_y3
#   Actual: 588.6452353007907
#   Predicted: 274.4
# ------------------------------
# Column: P_FP_y4
#   Actual: 698.6781915138574
#   Predicted: 384.15999999999997
# ------------------------------
# Column: P_FP_y5
#   Actual: 695.9974634518406
#   Predicted: 537.824
# ------------------------------
# Column: I_V1
#   Actual: 880.4134680016621
#   Predicted: 692.759308128651
# ------------------------------
# Column: I_V2
#   Actual: 1676.3877259123826
#   Predicted: 1244.30956837374
# ------------------------------
# Column: I_V3
#   Actual: 2412.8862318676674
#   Predicted: 1700.6700074874213
# ------------------------------
# Column: I_V4
#   Actual: 3078.600604603654
#   Predicted: 2087.0311206283372
# ------------------------------
# Column: I_V5
#   Actual: 3653.7150862917606
#   Predicted: 2421.8240841128595
# ------------------------------
# Column: I_IP_x1
#   Actual: 9075.166535359302
#   Predicted: 8190.812487994885
# ------------------------------
# Column: I_IP_x2
#   Actual: 8193.072597891665
#   Predicted: 6653.076001667571
# ------------------------------
# Column: I_IP_x3
#   Actual: 7402.23612754802
#   Predicted: 5367.655724228748
# ------------------------------
# Column: I_IP_x4
#   Actual: 6589.762899684264
#   Predicted: 4315.27131631534
# ------------------------------
# Column: I_IP_x5
#   Actual: 5713.257036941762
#   Predicted: 3467.163686419911
# ------------------------------
# Column: I_IP_y1
#   Actual: 135.74298091716742
#   Predicted: 69.91712173868306
# ------------------------------
# Column: I_IP_y2
#   Actual: 287.7067857845421
#   Predicted: 132.6667017321747
# ------------------------------
# Column: I_IP_y3
#   Actual: 403.9954337066508
#   Predicted: 202.3064307064511
# ------------------------------
# Column: I_IP_y4
#   Actual: 548.3311542166209
#   Predicted: 292.7815491344932
# ------------------------------
# Column: I_IP_y5
#   Actual: 622.6482852546093
#   Predicted: 415.3181172762701
# ------------------------------
# Column: I_FP_x0
#   Actual: 8870.873435114045
#   Predicted: 7992.333758973312
# ------------------------------
# Column: I_FP_x1
#   Actual: 8160.559126986444
#   Predicted: 6393.86700717865
# ------------------------------
# Column: I_FP_x2
#   Actual: 7337.008243768058
#   Predicted: 5115.093605742921
# ------------------------------
# Column: I_FP_x3
#   Actual: 6604.281322903217
#   Predicted: 4092.0748845943367
# ------------------------------
# Column: I_FP_x4
#   Actual: 5792.565787328567
#   Predicted: 3273.6599076754696
# ------------------------------
# Column: I_FP_x5
#   Actual: 4857.657450267193
#   Predicted: 2618.927926140376
# ------------------------------
# Column: I_FP_y0
#   Actual: 142.4918970669314
#   Predicted: 100
# ------------------------------
# Column: I_FP_y1
#   Actual: 276.5445848262805
#   Predicted: 140.0
# ------------------------------
# Column: I_FP_y2
#   Actual: 439.5833148167961
#   Predicted: 196.0
# ------------------------------
# Column: I_FP_y3
#   Actual: 544.1411299922696
#   Predicted: 274.4
# ------------------------------
# Column: I_FP_y4
#   Actual: 680.5377854898074
#   Predicted: 384.15999999999997
# ------------------------------
# Column: I_FP_y5
#   Actual: 691.4464271733847
#   Predicted: 537.824
# ------------------------------
# ================================================== ROW 99 SUMMARY ==================================================
# Actual Values: [np.float64(257.6241762753771), np.float64(585.453676336625), np.float64(1007.9925353237676), np.float64(1514.2481726669391), np.float64(2092.2454424853527), np.float64(1004.9308529846998), np.float64(1858.485340687361), np.float64(2663.044880833452), np.float64(3409.0808248173603), np.float64(4132.196086838643), np.float64(130.1941343852409), np.float64(248.19472973449916), np.float64(412.91383445792246), np.float64(606.878228614831), np.float64(653.4168714979659), np.float64(1022.495512258016), np.float64(1935.716942537468), np.float64(2714.5282949151724), np.float64(3466.9728904202207), np.float64(4162.099518518652), np.float64(4855.573418707787), np.float64(79.37602427907558), np.float64(250.72796336513315), np.float64(415.7283006210283), np.float64(588.6452353007907), np.float64(698.6781915138574), np.float64(695.9974634518406), np.float64(880.4134680016621), np.float64(1676.3877259123826), np.float64(2412.8862318676674), np.float64(3078.600604603654), np.float64(3653.7150862917606), np.float64(9075.166535359302), np.float64(8193.072597891665), np.float64(7402.23612754802), np.float64(6589.762899684264), np.float64(5713.257036941762), np.float64(135.74298091716742), np.float64(287.7067857845421), np.float64(403.9954337066508), np.float64(548.3311542166209), np.float64(622.6482852546093), np.float64(8870.873435114045), np.float64(8160.559126986444), np.float64(7337.008243768058), np.float64(6604.281322903217), np.float64(5792.565787328567), np.float64(4857.657450267193), np.float64(142.4918970669314), np.float64(276.5445848262805), np.float64(439.5833148167961), np.float64(544.1411299922696), np.float64(680.5377854898074), np.float64(691.4464271733847)]
# Predicted Values: [np.float64(64.22542527235049), np.float64(122.38792129799924), np.float64(196.11900248133162), np.float64(293.7747215066379), np.float64(420.9630447959167), np.float64(105.81266722012397), np.float64(149.4781607388181), np.float64(212.8914699415281), np.float64(298.55838313421026), np.float64(418.20777009328026), np.float64(69.58938313248983), np.float64(133.23633304501018), np.float64(202.29275134509825), np.float64(292.3683314055428), np.float64(414.76992788374497), np.float64(99.79413599253182), np.float64(139.71179038954455), np.float64(195.59650654536236), np.float64(273.8351091635073), np.float64(383.3691528289102), np.float64(536.7168139604743), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824), np.float64(692.759308128651), np.float64(1244.30956837374), np.float64(1700.6700074874213), np.float64(2087.0311206283372), np.float64(2421.8240841128595), np.float64(8190.812487994885), np.float64(6653.076001667571), np.float64(5367.655724228748), np.float64(4315.27131631534), np.float64(3467.163686419911), np.float64(69.91712173868306), np.float64(132.6667017321747), np.float64(202.3064307064511), np.float64(292.7815491344932), np.float64(415.3181172762701), np.float64(7992.333758973312), np.float64(6393.86700717865), np.float64(5115.093605742921), np.float64(4092.0748845943367), np.float64(3273.6599076754696), np.float64(2618.927926140376), np.int64(100), np.float64(140.0), np.float64(196.0), np.float64(274.4), np.float64(384.15999999999997), np.float64(537.824)]
#
#
# Mean Absolute Error (MAE): 1136.1434098699397
# Mean Squared Error (MSE): 2651702.649049014
# Root Mean Squared Error (RMSE): 1628.4049401328325

# %%
import matplotlib.pyplot as plt

# Initialize lists to store true and predicted final positions
true_fp_x = []
true_fp_y = []
pred_fp_x = []
pred_fp_y = []

# Extract true and predicted final positions for projectile
for i in range(len(test_data)):
    for t in range(1, 6):  # Time steps 1 to 5, since predictions start from t=1
        true_fp_x.append(test_data.loc[i, f'P_FP_x{t}'])
        true_fp_y.append(test_data.loc[i, f'P_FP_y{t}'])
        pred_fp_x.append(predictions[i][f'P_FP_x{t}'])
        pred_fp_y.append(predictions[i][f'P_FP_y{t}'])

# Plot predicted vs true final positions for projectile (x)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(true_fp_x, pred_fp_x, c='blue', label='Projectile FP_x')
plt.plot([min(true_fp_x), max(true_fp_x)], [min(true_fp_x), max(true_fp_x)], 'k--', lw=2)
plt.xlabel('True Final Position (x)')
plt.ylabel('Predicted Final Position (x)')
plt.title('Projectile Final Position (x)')
plt.legend()

# Plot predicted vs true final positions for projectile (y)
plt.subplot(1, 2, 2)
plt.scatter(true_fp_y, pred_fp_y, c='green', label='Projectile FP_y')
plt.plot([min(true_fp_y), max(true_fp_y)], [min(true_fp_y), max(true_fp_y)], 'k--', lw=2)
plt.xlabel('True Final Position (y)')
plt.ylabel('Predicted Final Position (y)')
plt.title('Projectile Final Position (y)')
plt.legend()

plt.tight_layout()
plt.show()

# Repeat the same for the interceptor
true_I_fp_x = []
true_I_fp_y = []
pred_I_fp_x = []
pred_I_fp_y = []

for i in range(len(test_data)):
    for t in range(1, 6):  # Time steps 1 to 5
        true_I_fp_x.append(test_data.loc[i, f'I_FP_x{t}'])
        true_I_fp_y.append(test_data.loc[i, f'I_FP_y{t}'])
        pred_I_fp_x.append(predictions[i][f'I_FP_x{t}'])
        pred_I_fp_y.append(predictions[i][f'I_FP_y{t}'])

# Plot predicted vs true final positions for interceptor (x)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(true_I_fp_x, pred_I_fp_x, c='blue', label='Interceptor FP_x')
plt.plot([min(true_I_fp_x), max(true_I_fp_x)], [min(true_I_fp_x), max(true_I_fp_x)], 'k--', lw=2)
plt.xlabel('True Final Position (x)')
plt.ylabel('Predicted Final Position (x)')
plt.title('Interceptor Final Position (x)')
plt.legend()

# Plot predicted vs true final positions for interceptor (y)
plt.subplot(1, 2, 2)
plt.scatter(true_I_fp_y, pred_I_fp_y, c='green', label='Interceptor FP_y')
plt.plot([min(true_I_fp_y), max(true_I_fp_y)], [min(true_I_fp_y), max(true_I_fp_y)], 'k--', lw=2)
plt.xlabel('True Final Position (y)')
plt.ylabel('Predicted Final Position (y)')
plt.title('Interceptor Final Position (y)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Function to plot 2D trajectories (X and Y positions over time)
def plot_2d_trajectories(data, x_columns, y_columns, label, color, mean=False):
    if mean:
        # Extract the mean values for X and Y positions over time slices
        x_values = data[x_columns].mean(axis=0)
        y_values = data[y_columns].mean(axis=0)
        
        # Plot the mean trajectory
        plt.plot(x_values, y_values, marker='o', color=color, label=label)
        
        # Annotate each point with the corresponding time slice
        for i, time_slice in enumerate(x_columns):
            plt.text(x_values[i], y_values[i], f'{i}', fontsize=12)
    else:
        # Plot all individual trajectories
        for i in range(len(data)):
            x_values = data.loc[i, x_columns]
            y_values = data.loc[i, y_columns]
            plt.plot(x_values, y_values, marker='o', color=color, alpha=0.3)  # Use alpha for transparency


# Function to handle predicted data (from the predictions list)
def plot_predicted_trajectories(predictions, x_columns, y_columns, label, color):
    for i in range(len(predictions)):
        x_values = [predictions[i][col] for col in x_columns]
        y_values = [predictions[i][col] for col in y_columns]
        plt.plot(x_values, y_values, marker='o', color=color, alpha=0.3)  # Use alpha for transparency
        # Optionally annotate each point with the corresponding time slice
        for j in range(len(x_values)):
            plt.text(x_values[j], y_values[j], f'{j}', fontsize=8, color=color)


# Define the columns for FPS and IPS (both X and Y positions) for projectiles and interceptors
projectile_fps_x = [f'P_FP_x{i}' for i in range(1, 6)]  # Time slices 1 to 5
projectile_fps_y = [f'P_FP_y{i}' for i in range(1, 6)]
interceptor_fps_x = [f'I_FP_x{i}' for i in range(1, 6)]
interceptor_fps_y = [f'I_FP_y{i}' for i in range(1, 6)]

projectile_ips_x = [f'P_IP_x{i}' for i in range(6)]  # Time slices 0 to 5
projectile_ips_y = [f'P_IP_y{i}' for i in range(6)]
interceptor_ips_x = [f'I_IP_x{i}' for i in range(6)]
interceptor_ips_y = [f'I_IP_y{i}' for i in range(6)]

# Plot the X and Y 2D trajectory for both projectile and interceptor
plt.figure(figsize=(10, 8))
plt.title('2D Trajectories of Projectile and Interceptor Over Time')
plt.xlabel('X Position')
plt.ylabel('Y Position')

# Plot true projectile trajectory (FPS)
plot_2d_trajectories(test_data, projectile_fps_x, projectile_fps_y, "Projectile (FPS)", "blue")

# Plot predicted projectile trajectory (FPS)
plot_predicted_trajectories(predictions, projectile_fps_x, projectile_fps_y, "Predicted Projectile (FPS)", "cyan")

# Plot true interceptor trajectory (FPS)
plot_2d_trajectories(test_data, interceptor_fps_x, interceptor_fps_y, "Interceptor (FPS)", "red")

# Plot predicted interceptor trajectory (FPS)
plot_predicted_trajectories(predictions, interceptor_fps_x, interceptor_fps_y, "Predicted Interceptor (FPS)", "orange")

# # Plot true projectile trajectory (IPS)
# plot_2d_trajectories(test_data, projectile_ips_x, projectile_ips_y, "Projectile (IPS)", "#add8e6", mean=True)

# # Plot true interceptor trajectory (IPS)
# plot_2d_trajectories(test_data, interceptor_ips_x, interceptor_ips_y, "Interceptor (IPS)", "#FF7F7F", mean=True)

plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\suvar\AppData\Local\Temp\ipykernel_2728\2130091946.py:70: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt

# Function to plot 2D trajectories (X and Y positions over time)
def plot_2d_trajectories(data, x_columns, y_columns, label, color, mean=False):
    if mean:
        # Extract the mean values for X and Y positions over time slices
        x_values = data[x_columns].mean(axis=0)
        y_values = data[y_columns].mean(axis=0)
        
        # Plot the mean trajectory
        plt.plot(x_values, y_values, marker='o', color=color, label=label)
        
        # Annotate each point with the corresponding time slice
        for i, time_slice in enumerate(x_columns):
            plt.text(x_values[i], y_values[i], f'{i}', fontsize=12)
    else:
        # Plot all individual trajectories
        for i in range(len(data)):
            x_values = data.loc[i, x_columns]
            y_values = data.loc[i, y_columns]
            plt.plot(x_values, y_values, marker='o', color=color, alpha=0.3)  # Use alpha for transparency


# Function to handle predicted data (from the predictions list)
def plot_predicted_trajectories(predictions, x_columns, y_columns, label, color):
    for i in range(len(predictions)):
        x_values = [predictions[i][col] for col in x_columns]
        y_values = [predictions[i][col] for col in y_columns]
        plt.plot(x_values, y_values, marker='o', color=color, alpha=0.3)  # Use alpha for transparency
        # Optionally annotate each point with the corresponding time slice
        for j in range(len(x_values)):
            plt.text(x_values[j], y_values[j], f'{j}', fontsize=8, color=color)


# Define the columns for FPS and IPS (both X and Y positions) for projectiles and interceptors
projectile_fps_x = [f'P_FP_x{i}' for i in range(1, 6)]  # Time slices 1 to 5
projectile_fps_y = [f'P_FP_y{i}' for i in range(1, 6)]
interceptor_fps_x = [f'I_FP_x{i}' for i in range(1, 6)]
interceptor_fps_y = [f'I_FP_y{i}' for i in range(1, 6)]

projectile_ips_x = [f'P_IP_x{i}' for i in range(1, 6)]  # Time slices 0 to 5
projectile_ips_y = [f'P_IP_y{i}' for i in range(1, 6)]
interceptor_ips_x = [f'I_IP_x{i}' for i in range(1, 6)]
interceptor_ips_y = [f'I_IP_y{i}' for i in range(1, 6)]

# Plot the X and Y 2D trajectory for both projectile and interceptor
plt.figure(figsize=(10, 8))
plt.title('2D Trajectories of Projectile and Interceptor Over Time')
plt.xlabel('X Position')
plt.ylabel('Y Position')

# # Plot true projectile trajectory (FPS)
# plot_2d_trajectories(test_data, projectile_fps_x, projectile_fps_y, "Projectile (FPS)", "blue")

# Plot true projectile trajectory (IPS)
plot_2d_trajectories(test_data, projectile_ips_x, projectile_ips_y, "Projectile (IPS)", "#add8e6", mean=True)

# Plot true interceptor trajectory (IPS)
plot_2d_trajectories(test_data, interceptor_ips_x, interceptor_ips_y, "Interceptor (IPS)", "#FF7F7F", mean=True)

# Plot predicted projectile trajectory (FPS)
plot_predicted_trajectories(predictions, projectile_ips_x, projectile_ips_y, "Predicted Projectile (FPS)", "cyan")

# Plot predicted interceptor trajectory (FPS)
plot_predicted_trajectories(predictions, interceptor_ips_x, interceptor_ips_y, "Predicted Interceptor (FPS)", "orange")

plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\suvar\AppData\Local\Temp\ipykernel_2728\1597418198.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x_values[i], y_values[i], f'{i}', fontsize=12)
# C:\Users\suvar\AppData\Local\Temp\ipykernel_2728\1597418198.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x_values[i], y_values[i], f'{i}', fontsize=12)
