# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pgmpy.models import BayesianNetwork, LinearGaussianBayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator, ExpectationMaximization, BayesianEstimator
from pgmpy.estimators import HillClimbSearch, BicScore, K2Score, BDsScore
import matplotlib.pyplot as plt
from pgmpy.inference import VariableElimination
import networkx as nx

# %%
def visualise(model, pos, projectile_color="skyblue", interceptor_color="lightcoral"):
    edges = model.edges()

    # Create separate lists for intra-time slice and inter-time slice edges
    intra_time_slice_edges = []
    inter_time_slice_edges = []

    for edge in edges:
        if abs(int(edge[0][-1]) - int(edge[1][-1])) == 0:
            intra_time_slice_edges.append(edge)
        else:
            inter_time_slice_edges.append(edge)

    # Create a directed graph object
    G = nx.DiGraph()

    # Add edges to the graph
    G.add_edges_from(edges)

    # Create a color map based on node type
    color_map = []
    for node in G.nodes():
        if "FP" in node:
            color_map.append("gray")
        elif "P" == node[0]:
            color_map.append(projectile_color)
        elif "I_" in node:
            color_map.append(interceptor_color)
        else:
            color_map.append("gray")  # Default color for any other nodes

    # Plot the graph with custom positions and colors
    plt.figure(figsize=(20, 12))

    # Draw edges first to ensure arrowheads are not covered
    nx.draw_networkx_edges(
        G, pos, edgelist=intra_time_slice_edges, arrows=True,
        edge_color='black', style='solid', arrowsize=15, arrowstyle='-|>',
        min_source_margin=10, min_target_margin=15  # Increase margins to make arrows shorter
    )

    nx.draw_networkx_edges(
        G, pos, edgelist=inter_time_slice_edges, arrows=True,
        edge_color='black', style=(0, (5, 10)), arrowsize=15, arrowstyle='-|>',
        min_source_margin=10, min_target_margin=15  # Increase margins to make arrows shorter
    )

    # Draw nodes after edges
    nx.draw_networkx_nodes(G, pos, node_size=1000, node_color=color_map)

    nx.draw_networkx_labels(G, pos, font_size=8, font_weight="bold")

    plt.title("Bayesian Network Graph")
    plt.show()

# %%
# Define positions manually for x and y positions
pos = {}

for i in range(6):
    if i % 2 == 0:
        # Projectile nodes positions (lower row)
        pos[f'P_FP_x{i}'] = (i * 3 - 1 - 1, 0)          # Final position x
        pos[f'P_FP_y{i}'] = (i * 3 - 1, 0)              # Final position y
        pos[f'P_V{i}'] = (i * 3 + 1 - 1, -1)            # Velocity
        pos[f'P_IP_x{i}'] = (i * 3 - 1 - 1, -1)         # Initial position x
        pos[f'P_IP_y{i}'] = (i * 3 - 1, -1)             # Initial position y

        # Interceptor nodes positions (upper row)
        pos[f'I_FP_x{i}'] = (i * 3 - 1, 3)          # Final position x
        pos[f'I_FP_y{i}'] = (i * 3, 3)              # Final position y
        pos[f'I_V{i}'] = (i * 3 + 1, 2)             # Velocity
        pos[f'I_IP_x{i}'] = (i * 3 - 1, 2)          # Initial position x
        pos[f'I_IP_y{i}'] = (i * 3, 2)              # Initial position y
    else:
        # Projectile nodes positions (lower row)
        pos[f'P_FP_x{i}'] = (i * 3 - 1 - 1, -1)         # Final position x
        pos[f'P_FP_y{i}'] = (i * 3 - 1, -1)             # Final position y
        pos[f'P_V{i}'] = (i * 3 + 1 - 1, -2)            # Velocity
        pos[f'P_IP_x{i}'] = (i * 3 - 1 - 1, -2)         # Initial position x
        pos[f'P_IP_y{i}'] = (i * 3 - 1, -2)             # Initial position y

        # Interceptor nodes positions (upper row)
        pos[f'I_FP_x{i}'] = (i * 3 - 1, 4)          # Final position x
        pos[f'I_FP_y{i}'] = (i * 3, 4)              # Final position y
        pos[f'I_V{i}'] = (i * 3 + 1, 3)             # Velocity
        pos[f'I_IP_x{i}'] = (i * 3 - 1, 3)          # Initial position x
        pos[f'I_IP_y{i}'] = (i * 3, 3)              # Initial position y

# %%
from pgmpy.factors.continuous import LinearGaussianCPD
from pgmpy.models import LinearGaussianBayesianNetwork

# Initialize the Bayesian Network model
GT = LinearGaussianBayesianNetwork()

for i in range(6):
    # Add nodes for final position (FP), velocity (V), and initial position (IP)
    GT.add_nodes_from([
        f'P_FP_x{i}', f'P_FP_y{i}', f'P_V{i}', f'P_IP_x{i}', f'P_IP_y{i}',  # Projectile nodes
        f'I_FP_x{i}', f'I_FP_y{i}', f'I_V{i}', f'I_IP_x{i}', f'I_IP_y{i}'   # Interceptor nodes
    ])
    
    # Add edges within each time slice for both x and y positions
    GT.add_edges_from([
        (f'P_FP_x{i}' , f'P_IP_x{i}'),  # Initial position (x) influences final position (x)
        (f'P_FP_x{i}' , f'P_V{i}'),     # Velocity influences final position (x)
        (f'P_FP_y{i}' , f'P_IP_y{i}'),  # Initial position (y) influences final position (y)
        (f'P_FP_y{i}', f'P_V{i}'),     # Velocity influences final position (y)
        
        (f'I_FP_x{i}' , f'I_IP_x{i}'),  # Interceptor: Initial position (x) influences final position (x)
        (f'I_FP_x{i}' , f'I_V{i}'),     # Velocity influences final position (x)
        (f'I_FP_y{i}' , f'I_IP_y{i}'),  # Initial position (y) influences final position (y)
        (f'I_FP_y{i}' , f'I_V{i}')      # Velocity influences final position (y)
    ])

    if i < 5:
        # Connect corresponding nodes between time slices for projectile and interceptor
        GT.add_edges_from([
            # Projectile time slice connections for x and y positions
            (f'P_FP_x{i}', f'P_FP_x{i + 1}'),
            (f'P_IP_x{i}', f'P_IP_x{i + 1}'),
            (f'P_FP_y{i}', f'P_FP_y{i + 1}'),
            (f'P_IP_y{i}', f'P_IP_y{i + 1}'),
            (f'P_V{i}', f'P_V{i + 1}'),

            # Interceptor time slice connections for x and y positions
            (f'I_FP_x{i}', f'I_FP_x{i + 1}'),
            (f'I_IP_x{i}', f'I_IP_x{i + 1}'),
            (f'I_FP_y{i}', f'I_FP_y{i + 1}'),
            (f'I_IP_y{i}', f'I_IP_y{i + 1}'),
            (f'I_V{i}', f'I_V{i + 1}')
        ])
        
        # Edge between projectile and interceptor across time slices
        GT.add_edges_from([
            (f'P_FP_x{i + 1}', f'I_FP_x{i}'),
            (f'P_FP_y{i + 1}', f'I_FP_y{i}')
        ])

# Final edges to ensure convergence at the last time slice
GT.add_edges_from([
    (f'P_FP_x{5}', f'I_FP_x{5}'),
    (f'P_FP_y{5}', f'I_FP_y{5}')
])


visualise(GT, pos)

# %%
def fit_cpd_for_node(node, parents, data):
    required_columns = [node] + parents

    # Ensure all required columns are in the data
    missing_columns = [col for col in required_columns if col not in data.columns]
    if missing_columns:
        raise KeyError(f"Missing columns in data: {missing_columns}")
    
    # Creating the correct column names and structure for fitting
    node_data_before = data[required_columns].copy()
    node_data_before.columns = ["(Y|X)" if col == node else col for col in node_data_before.columns]

    # Add noise to all 0.0 values in the DataFrame
    noise_std = 1e-5 
    node_data = node_data_before.map(lambda x: x + np.random.normal(0, noise_std) if x == 0.0 else x)

    print("Fitting CPD for node:", node)
    print("Parents:", parents)
    print("Data being used for fit:")
    print(node_data.head())  # Print the first few rows of node_data

    if parents:
        # Initialize a Linear Gaussian CPD object
        cpd = LinearGaussianCPD(
            variable=node,
            evidence_mean=[0] * (len(parents) + 1),  # Initial guess for betas
            evidence_variance=1,  # Initial variance guess
            evidence=parents
        )
        
        node = "(Y|X)"
        print(f"Node: {node} \n")
        print("-"*50)
        # Fit the CPD using MLE
        beta, variance = cpd.fit(node_data, states=[node] + parents, estimator="MLE")
        return cpd
    else:
        # If no parents, fit a univariate Gaussian
        mean = data[node].mean()
        variance = data[node].var()
        return LinearGaussianCPD(variable=node, evidence_mean=[mean], evidence_variance=variance)




data = pd.read_csv('trajectory_data.csv')

# Assuming you have a pandas DataFrame `data` with all necessary columns.
for i in range(6):
    if i == 0:
        # Fit Projectile CPDs for x and y positions
        # cpd_P_FP_x = fit_cpd_for_node(f'P_FP_x{i}', [], data)
        # cpd_P_FP_y = fit_cpd_for_node(f'P_FP_y{i}', [], data)
        cpd_P_V = fit_cpd_for_node(f'P_V{i}', [f'P_FP_x{i}', f'P_FP_y{i}'], data)
        cpd_P_IP_x = fit_cpd_for_node(f'P_IP_x{i}', [f'P_FP_x{i}'], data)
        cpd_P_IP_y = fit_cpd_for_node(f'P_IP_y{i}', [f'P_FP_y{i}'], data)
    else:
        # Fit Projectile CPDs for x and y positions
        # cpd_P_FP_x = fit_cpd_for_node(f'P_FP_x{i}', [f'P_FP_x{i - 1}'], data)
        # cpd_P_FP_y = fit_cpd_for_node(f'P_FP_y{i}', [f'P_FP_y{i - 1}'], data)
        cpd_P_V = fit_cpd_for_node(f'P_V{i}', [f'P_V{i - 1}',f'P_FP_x{i}', f'P_FP_y{i}'], data)
        cpd_P_IP_x = fit_cpd_for_node(f'P_IP_x{i}', [f'P_FP_x{i}', f'P_IP_x{i - 1}'], data)
        cpd_P_IP_y = fit_cpd_for_node(f'P_IP_y{i}', [f'P_FP_y{i}', f'P_IP_y{i - 1}'], data)

    # Add fitted CPDs to the network
    # GT.add_cpds(cpd_P_FP_x, cpd_P_FP_y, cpd_P_V, cpd_P_IP_x, cpd_P_IP_y)
    GT.add_cpds(cpd_P_V, cpd_P_IP_x, cpd_P_IP_y)

# Fit and add Interceptor CPDs
for i in range(6):
    if i == 0:
        # cpd_I_FP_x = fit_cpd_for_node(f'I_FP_x{i}', [f'P_FP_x{i+1}'], data)
        # cpd_I_FP_y = fit_cpd_for_node(f'I_FP_y{i}', [f'P_FP_y{i+1}'], data)
        cpd_I_V = fit_cpd_for_node(f'I_V{i}', [f'I_FP_x{i}', f'I_FP_y{i}'], data)
        cpd_I_IP_x = fit_cpd_for_node(f'I_IP_x{i}', [f'I_FP_x{i}'], data)
        cpd_I_IP_y = fit_cpd_for_node(f'I_IP_y{i}', [f'I_FP_y{i}'], data)
    else:
        # if i < 5:
            # cpd_I_FP_x = fit_cpd_for_node(f'I_FP_x{i}', [f'P_FP_x{i+1}', f'I_FP_x{i - 1}'], data)
            # cpd_I_FP_y = fit_cpd_for_node(f'I_FP_y{i}', [f'P_FP_y{i+1}', f'I_FP_y{i - 1}'], data)
        # else:
            # cpd_I_FP_x = fit_cpd_for_node(f'I_FP_x{i}', [f'I_FP_x{i - 1}', f'P_FP_x{i}'], data)
            # cpd_I_FP_y = fit_cpd_for_node(f'I_FP_y{i}', [f'I_FP_y{i - 1}', f'P_FP_y{i}'], data)

        cpd_I_V = fit_cpd_for_node(f'I_V{i}', [f'I_V{i - 1}',f'I_FP_x{i}',  f'I_FP_y{i}'], data)
        cpd_I_IP_x = fit_cpd_for_node(f'I_IP_x{i}', [f'I_FP_x{i}', f'I_IP_x{i - 1}'], data)
        cpd_I_IP_y = fit_cpd_for_node(f'I_IP_y{i}', [f'I_FP_y{i}', f'I_IP_y{i - 1}'], data)

    # Add fitted CPDs to the network
    # GT.add_cpds(cpd_I_FP_x, cpd_I_FP_y, cpd_I_V, cpd_I_IP_x, cpd_I_IP_y)
    GT.add_cpds(cpd_I_V, cpd_I_IP_x, cpd_I_IP_y)
# Out:
# Fitting CPD for node: P_V0
# Parents: ['P_FP_x0', 'P_FP_y0']
# Data being used for fit:
#        (Y|X)      P_FP_x0     P_FP_y0
# 0  20.979374  1000.941726   95.846704
# 1  19.919984  1017.268754  107.814632
# 2  26.127626   994.646441   99.398389
# 3  15.826436  1000.957566   71.935585
# 4  19.996524   996.697403  124.554524
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x0
# Parents: ['P_FP_x0']
# Data being used for fit:
#         (Y|X)      P_FP_x0
# 0  192.037133  1000.941726
# 1    9.955551  1017.268754
# 2  -37.470197   994.646441
# 3  -18.325740  1000.957566
# 4   33.987401   996.697403
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y0
# Parents: ['P_FP_y0']
# Data being used for fit:
#       (Y|X)     P_FP_y0
# 0  0.000016   95.846704
# 1 -0.000013  107.814632
# 2  0.000002   99.398389
# 3  0.000018   71.935585
# 4  0.000001  124.554524
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V1
# Parents: ['P_V0', 'P_FP_x1', 'P_FP_y1']
# Data being used for fit:
#         (Y|X)       P_V0      P_FP_x1     P_FP_y1
# 0  259.123594  20.979374  1930.292449  264.911972
# 1  261.953825  19.919984  1934.871092  283.710752
# 2  259.811298  26.127626  1900.187638  250.686453
# 3  251.465300  15.826436  1894.381529  258.451895
# 4  262.819416  19.996524  1891.446868  277.374819
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x1
# Parents: ['P_FP_x1', 'P_IP_x0']
# Data being used for fit:
#          (Y|X)      P_FP_x1     P_IP_x0
# 0  1061.672554  1930.292449  192.037133
# 1   972.725049  1934.871092    9.955551
# 2   931.751915  1900.187638  -37.470197
# 3   936.731090  1894.381529  -18.325740
# 4   964.545092  1891.446868   33.987401
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y1
# Parents: ['P_FP_y1', 'P_IP_y0']
# Data being used for fit:
#         (Y|X)     P_FP_y1   P_IP_y0
# 0  135.882648  264.911972  0.000006
# 1  122.421930  283.710752 -0.000015
# 2  116.936333  250.686453  0.000003
# 3  159.485242  258.451895  0.000017
# 4  119.831561  277.374819 -0.000003
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V2
# Parents: ['P_V1', 'P_FP_x2', 'P_FP_y2']
# Data being used for fit:
#         (Y|X)        P_V1      P_FP_x2     P_FP_y2
# 0  592.624166  259.123594  2711.389457  412.131625
# 1  598.315713  261.953825  2741.710511  437.334667
# 2  591.888129  259.811298  2721.711275  428.898597
# 3  583.497052  251.465300  2702.949774  428.236029
# 4  598.975057  262.819416  2714.793130  443.928123
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x2
# Parents: ['P_FP_x2', 'P_IP_x1']
# Data being used for fit:
#          (Y|X)      P_FP_x2      P_IP_x1
# 0  1883.526415  2711.389457  1061.672554
# 1  1857.577317  2741.710511   972.725049
# 2  1824.922770  2721.711275   931.751915
# 3  1819.415025  2702.949774   936.731090
# 4  1840.400893  2714.793130   964.545092
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y2
# Parents: ['P_FP_y2', 'P_IP_y1']
# Data being used for fit:
#         (Y|X)     P_FP_y2     P_IP_y1
# 0  256.504953  412.131625  135.882648
# 1  296.375802  437.334667  122.421930
# 2  286.380805  428.898597  116.936333
# 3  296.521643  428.236029  159.485242
# 4  309.647492  443.928123  119.831561
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V3
# Parents: ['P_V2', 'P_FP_x3', 'P_FP_y3']
# Data being used for fit:
#          (Y|X)        P_V2      P_FP_x3     P_FP_y3
# 0  1012.325516  592.624166  3436.377032  548.930286
# 1  1027.197022  598.315713  3486.041348  570.577672
# 2  1012.509791  591.888129  3496.368146  508.577446
# 3  1003.892389  583.497052  3451.732969  556.677406
# 4  1023.229732  598.975057  3447.534763  564.510845
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x3
# Parents: ['P_FP_x3', 'P_IP_x2']
# Data being used for fit:
#          (Y|X)      P_FP_x3      P_IP_x2
# 0  2660.414361  3436.377032  1883.526415
# 1  2672.903890  3486.041348  1857.577317
# 2  2662.117193  3496.368146  1824.922770
# 3  2631.911690  3451.732969  1819.415025
# 4  2642.103311  3447.534763  1840.400893
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y3
# Parents: ['P_FP_y3', 'P_IP_y2']
# Data being used for fit:
#         (Y|X)     P_FP_y3     P_IP_y2
# 0  383.950746  548.930286  256.504953
# 1  375.341279  570.577672  296.375802
# 2  354.878057  508.577446  286.380805
# 3  428.838041  556.677406  296.521643
# 4  441.744368  564.510845  309.647492
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V4
# Parents: ['P_V3', 'P_FP_x4', 'P_FP_y4']
# Data being used for fit:
#          (Y|X)         P_V3      P_FP_x4     P_FP_y4
# 0  1511.255827  1012.325516  4146.035879  618.154392
# 1  1529.322751  1027.197022  4159.894072  650.226220
# 2  1507.499745  1012.509791  4184.572353  592.849248
# 3  1501.526570  1003.892389  4173.981537  616.743785
# 4  1520.505716  1023.229732  4159.192703  621.291654
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x4
# Parents: ['P_FP_x4', 'P_IP_x3']
# Data being used for fit:
#          (Y|X)      P_FP_x4      P_IP_x3
# 0  3402.129356  4146.035879  2660.414361
# 1  3416.515431  4159.894072  2672.903890
# 2  3423.360659  4184.572353  2662.117193
# 3  3403.364593  4173.981537  2631.911690
# 4  3400.278693  4159.192703  2642.103311
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y4
# Parents: ['P_FP_y4', 'P_IP_y3']
# Data being used for fit:
#         (Y|X)     P_FP_y4     P_IP_y3
# 0  522.881429  618.154392  383.950746
# 1  516.955889  650.226220  375.341279
# 2  473.092955  592.849248  354.878057
# 3  524.011992  616.743785  428.838041
# 4  554.346574  621.291654  441.744368
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_V5
# Parents: ['P_V4', 'P_FP_x5', 'P_FP_y5']
# Data being used for fit:
#          (Y|X)         P_V4      P_FP_x5     P_FP_y5
# 0  2070.620157  1511.255827  4810.346737  595.443339
# 1  2093.699984  1529.322751  4814.464040  631.002111
# 2  2071.542497  1507.499745  4844.928530  594.809998
# 3  2066.314174  1501.526570  4867.725493  594.665725
# 4  2082.250911  1520.505716  4808.059695  593.542020
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_x5
# Parents: ['P_FP_x5', 'P_IP_x4']
# Data being used for fit:
#          (Y|X)      P_FP_x5      P_IP_x4
# 0  4106.805367  4810.346737  3402.129356
# 1  4113.633896  4814.464040  3416.515431
# 2  4132.817169  4844.928530  3423.360659
# 3  4137.232724  4867.725493  3403.364593
# 4  4104.955338  4808.059695  3400.278693
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: P_IP_y5
# Parents: ['P_FP_y5', 'P_IP_y4']
# Data being used for fit:
#         (Y|X)     P_FP_y5     P_IP_y4
# 0  567.151800  595.443339  522.881429
# 1  548.977824  631.002111  516.955889
# 2  555.608107  594.809998  473.092955
# 3  581.418595  594.665725  524.011992
# 4  576.521203  593.542020  554.346574
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V0
# Parents: ['I_FP_x0', 'I_FP_y0']
# Data being used for fit:
#        (Y|X)      I_FP_x0     I_FP_y0
# 0  20.829579  9110.232779  150.910130
# 1  17.641360  9245.663170  131.933768
# 2  17.787680  9024.139040  122.027817
# 3  21.033292  9084.852079  111.391866
# 4  16.782130  8736.138747  114.728754
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x0
# Parents: ['I_FP_x0']
# Data being used for fit:
#           (Y|X)      I_FP_x0
# 0  10075.163743  9110.232779
# 1   9976.090829  9245.663170
# 2  10050.814859  9024.139040
# 3   9903.179529  9084.852079
# 4   9904.215970  8736.138747
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y0
# Parents: ['I_FP_y0']
# Data being used for fit:
#           (Y|X)     I_FP_y0
# 0 -6.637581e-06  150.910130
# 1  3.728687e-06  131.933768
# 2  5.497661e-06  122.027817
# 3 -6.560091e-06  111.391866
# 4 -3.989555e-07  114.728754
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V1
# Parents: ['I_V0', 'I_FP_x1', 'I_FP_y1']
# Data being used for fit:
#         (Y|X)       I_V0      I_FP_x1     I_FP_y1
# 0  886.581396  20.829579  8204.362766  271.143491
# 1  880.420913  17.641360  8188.941328  258.107394
# 2  889.265804  17.787680  8179.036758  304.212687
# 3  882.691726  21.033292  8160.521815  263.781405
# 4  882.122887  16.782130  8141.341151  309.977286
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x1
# Parents: ['I_FP_x1', 'I_IP_x0']
# Data being used for fit:
#          (Y|X)      I_FP_x1       I_IP_x0
# 0  9132.315048  8204.362766  10075.163743
# 1  9057.728351  8188.941328   9976.090829
# 2  9102.440071  8179.036758  10050.814859
# 3  9033.047747  8160.521815   9903.179529
# 4  8996.287061  8141.341151   9904.215970
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y1
# Parents: ['I_FP_y1', 'I_IP_y0']
# Data being used for fit:
#         (Y|X)     I_FP_y1       I_IP_y0
# 0  136.187698  271.143491 -1.620766e-05
# 1  128.305934  258.107394  2.537690e-06
# 2  160.205633  304.212687 -6.866970e-06
# 3  122.601513  263.781405  3.720501e-06
# 4  164.044462  309.977286  1.705781e-07
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V2
# Parents: ['I_V1', 'I_FP_x2', 'I_FP_y2']
# Data being used for fit:
#          (Y|X)        I_V1      I_FP_x2     I_FP_y2
# 0  1689.623635  886.581396  7382.305354  441.880331
# 1  1683.497287  880.420913  7357.220763  434.585415
# 2  1678.185503  889.265804  7312.363605  391.379094
# 3  1682.200015  882.691726  7350.548237  435.849755
# 4  1679.258318  882.122887  7366.289907  440.641870
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x2
# Parents: ['I_FP_x2', 'I_IP_x1']
# Data being used for fit:
#          (Y|X)      I_FP_x2      I_IP_x1
# 0  8259.881633  7382.305354  9132.315048
# 1  8216.069140  7357.220763  9057.728351
# 2  8211.833378  7312.363605  9102.440071
# 3  8202.844561  7350.548237  9033.047747
# 4  8161.426714  7366.289907  8996.287061
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y2
# Parents: ['I_FP_y2', 'I_IP_y1']
# Data being used for fit:
#         (Y|X)     I_FP_y2     I_IP_y1
# 0  285.295189  441.880331  136.187698
# 1  277.541520  434.585415  128.305934
# 2  279.412604  391.379094  160.205633
# 3  295.327838  435.849755  122.601513
# 4  275.301130  440.641870  164.044462
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V3
# Parents: ['I_V2', 'I_FP_x3', 'I_FP_y3']
# Data being used for fit:
#          (Y|X)         I_V2      I_FP_x3     I_FP_y3
# 0  2421.532977  1689.623635  6580.683949  551.487334
# 1  2411.501581  1683.497287  6571.654959  548.801339
# 2  2406.173736  1678.185503  6548.700412  530.127015
# 3  2409.937571  1682.200015  6545.502155  525.343128
# 4  2411.264365  1679.258318  6568.076473  531.678295
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x3
# Parents: ['I_FP_x3', 'I_IP_x2']
# Data being used for fit:
#          (Y|X)      I_FP_x3      I_IP_x2
# 0  7438.248645  6580.683949  8259.881633
# 1  7381.636477  6571.654959  8216.069140
# 2  7372.129006  6548.700412  8211.833378
# 3  7363.541634  6545.502155  8202.844561
# 4  7338.183456  6568.076473  8161.426714
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y3
# Parents: ['I_FP_y3', 'I_IP_y2']
# Data being used for fit:
#         (Y|X)     I_FP_y3     I_IP_y2
# 0  409.917896  551.487334  285.295189
# 1  394.793437  548.801339  277.541520
# 2  403.883858  530.127015  279.412604
# 3  429.981890  525.343128  295.327838
# 4  416.526921  531.678295  275.301130
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V4
# Parents: ['I_V3', 'I_FP_x4', 'I_FP_y4']
# Data being used for fit:
#          (Y|X)         I_V3      I_FP_x4     I_FP_y4
# 0  3088.662308  2421.532977  5869.492673  581.324411
# 1  3077.446970  2411.501581  5839.289453  611.589094
# 2  3065.364882  2406.173736  5804.860269  597.120894
# 3  3064.033433  2409.937571  5790.115004  558.036199
# 4  3078.094331  2411.264365  5861.567541  598.132196
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x4
# Parents: ['I_FP_x4', 'I_IP_x3']
# Data being used for fit:
#          (Y|X)      I_FP_x4      I_IP_x3
# 0  6618.797838  5869.492673  7438.248645
# 1  6620.604336  5839.289453  7381.636477
# 2  6617.660516  5804.860269  7372.129006
# 3  6597.036506  5790.115004  7363.541634
# 4  6574.040674  5861.567541  7338.183456
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y4
# Parents: ['I_FP_y4', 'I_IP_y3']
# Data being used for fit:
#         (Y|X)     I_FP_y4     I_IP_y3
# 0  491.977220  581.324411  409.917896
# 1  493.837794  611.589094  394.793437
# 2  531.299297  597.120894  403.883858
# 3  495.429000  558.036199  429.981890
# 4  487.937322  598.132196  416.526921
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_V5
# Parents: ['I_V4', 'I_FP_x5', 'I_FP_y5']
# Data being used for fit:
#          (Y|X)         I_V4      I_FP_x5     I_FP_y5
# 0  3653.492987  3088.662308  4825.221707  594.206711
# 1  3645.478965  3077.446970  4846.468643  639.087297
# 2  3634.004469  3065.364882  4850.252383  630.332934
# 3  3624.598494  3064.033433  4852.533469  591.850815
# 4  3636.516479  3078.094331  4820.147953  572.290064
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_x5
# Parents: ['I_FP_x5', 'I_IP_x4']
# Data being used for fit:
#          (Y|X)      I_FP_x5      I_IP_x4
# 0  5725.016758  4825.221707  6618.797838
# 1  5720.446605  4846.468643  6620.604336
# 2  5743.496912  4850.252383  6617.660516
# 3  5706.138587  4852.533469  6597.036506
# 4  5679.661788  4820.147953  6574.040674
# Node: (Y|X)
#
# --------------------------------------------------
# Fitting CPD for node: I_IP_y5
# Parents: ['I_FP_y5', 'I_IP_y4']
# Data being used for fit:
#         (Y|X)     I_FP_y5     I_IP_y4
# 0  528.964782  594.206711  491.977220
# 1  548.293862  639.087297  493.837794
# 2  576.975244  630.332934  531.299297
# 3  551.072385  591.850815  495.429000
# 4  533.146404  572.290064  487.937322
# Node: (Y|X)
#
# --------------------------------------------------

# %%
# Validation
if GT.check_model():
    print("The model is valid!")
else:
    print("The model is not valid. Please check the CPDs and network structure.")
# Out:
# The model is valid!

# %%
import pandas as pd
import numpy as np

# Load the test data
test_data = pd.read_csv("trajectory_test_data.csv")

def predict_with_linear_gaussian_cpd(evidence, cpd, current_node):
    """
    Predict values using a Linear Gaussian CPD.
    
    Parameters
    ----------
    evidence: dict
        Dictionary with observed values.
    cpd: LinearGaussianCPD
        The CPD object to use for prediction.
    
    Returns
    -------
    float
        Predicted value for the query variable.
    """
    print(cpd)

    if cpd is None:
        # If the CPD is None and the node is an FP node, estimate using IP and velocity
        if current_node.startswith('P_FP') or current_node.startswith('I_FP'):
            # Extract the relevant time slice from the node name
            time_slice = int(current_node.split('x')[-1]) if 'x' in current_node else int(current_node.split('y')[-1])

            if time_slice == 0:

                # Use the initial position and velocity to estimate final position
                ip_x = evidence.get(f'P_IP_x{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_x{time_slice}', 0)
                ip_y = evidence.get(f'P_IP_y{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_y{time_slice}', 0)
                velocity = evidence.get(f'P_V{time_slice}', 0) if current_node.startswith('P') else evidence.get(f'I_V{time_slice}', 0)

                # Estimate the final position (this estimation can be modified based on the motion model)
                predicted_value = ip_x + velocity if 'x' in current_node else ip_y + velocity
            else:
                # Use the initial position and velocity to estimate final position
                ip_x = evidence.get(f'P_IP_x{ - 1}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_x{time_slice - 1}', 0)
                ip_y = evidence.get(f'P_IP_y{time_slice - 1}', 0) if current_node.startswith('P') else evidence.get(f'I_IP_y{time_slice - 1}', 0)
                velocity = evidence.get(f'P_V{time_slice - 1}', 0) if current_node.startswith('P') else evidence.get(f'I_V{time_slice - 1}', 0)
                fp_x = evidence.get(f'P_FP_x{ - 1}', 0) if current_node.startswith('P') else evidence.get(f'I_FP_x{time_slice - 1}', 0)
                fp_y = evidence.get(f'P_FP_y{ - 1}', 0) if current_node.startswith('P') else evidence.get(f'I_FP_y{time_slice - 1}', 0)

                # Estimate the final position (this estimation can be modified based on the motion model)
                predicted_value = 0.5*ip_x + 0.3*fp_x if 'x' in current_node else 0.5*ip_y + 0.3*fp_y 


            return predicted_value
        else:
            # Return a fallback value if CPD is not fitted
            print(f"CPD not fitted for node. Returning default value.")
            return 0.0  # Replace with domain-specific default if needed

    if not hasattr(cpd, 'beta') or cpd.beta is None:
        # The node has no parents, return its mean value
        print(f"Node has no parents. Using mean for prediction.")
        return cpd.mean
    
    beta = cpd.beta
    mean_vector = cpd.mean
    variance = cpd.variance
    print(f"Beta values: {beta}")
    print(f"Mean vals: {mean_vector}")
    print(f"Variance: {variance}")
    print(f"Evidence required: {cpd.evidence}")
    evidence_vals = [evidence[var] for var in cpd.evidence]
    evidence_vals_array = np.array([val.flatten() if isinstance(val, np.ndarray) else [val] for val in evidence_vals])
    print(f"Evidence vals: {evidence_vals_array}")
    print(f"Coeffecients to be used: {beta[1:]}")
    predicted_mean = beta[0] + np.dot(
        evidence_vals_array.flatten(),
        beta[1:]
    )
    return predicted_mean

# List to store predictions for each row in test_data
predictions = []

# Iterate through each row in the test_data DataFrame
for index, row in test_data.iterrows():
    # Define initial evidence (time slice 0)
    evidence = {
        'P_IP_x0' : row['P_IP_x0'],   
        'P_IP_y0' : row['P_IP_y0'],   
        'P_V0'  : row['P_V0'],
        'I_IP_x0' : row['I_IP_x0'],    
        'I_IP_y0' : row['I_IP_y0'],
        'I_V0':  row['I_V0'],
    }
    
    # Empty dict to store predictions for this row
    row_predictions = {}

    # COMPLETING PREDICTION FOR FIRST TREE
 
    cpd_x = GT.get_cpds(f'P_FP_x0')
    cpd_y = GT.get_cpds(f'P_FP_y0')
    
    prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'P_FP_x0')
    evidence[f'P_FP_x0'] = prediction_x

    prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'P_FP_y0')
    evidence[f'P_FP_y0'] = prediction_y
    
    row_predictions[f'P_FP_x0'] = prediction_x
    row_predictions[f'P_FP_y0'] = prediction_y
    
    # Propagate predictions for multiple time slices
    for t in range(1,6):
        # Predict for time slice t using evidence from time slice t-1
        cpd_v = GT.get_cpds(f'P_V{t}')
        cpd_I_x = GT.get_cpds(f'P_IP_x{t}')
        cpd_I_y = GT.get_cpds(f'P_IP_y{t}')
        cpd_x = GT.get_cpds(f'P_FP_x{t}')
        cpd_y = GT.get_cpds(f'P_FP_y{t}')

        prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'P_FP_x{t}')
        evidence[f'P_FP_x{t}'] = prediction_x

        prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'P_FP_y{t}')
        evidence[f'P_FP_y{t}'] = prediction_y
        
        prediction_v = predict_with_linear_gaussian_cpd(evidence, cpd_v, f'P_V{t}')
        evidence[f'P_V{t}'] = prediction_v

        prediction_I_x = predict_with_linear_gaussian_cpd(evidence, cpd_I_x, f'P_IP_x{t}')
        evidence[f'P_IP_x{t}'] = prediction_I_x

        prediction_I_y = predict_with_linear_gaussian_cpd(evidence, cpd_I_y, f'P_IP_y{t}')
        evidence[f'P_IP_y{t}'] = prediction_I_y

        
        # Store the predictions for this time slice
        row_predictions[f'P_V{t}'] = prediction_v
        row_predictions[f'P_IP_x{t}'] = prediction_I_x
        row_predictions[f'P_IP_y{t}'] = prediction_I_y
        row_predictions[f'P_FP_x{t}'] = prediction_x
        row_predictions[f'P_FP_y{t}'] = prediction_y

        #INTERCEPTOR NODES
        if t == 1:
            prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'I_FP_x{t - 1}')
            evidence[f'I_FP_x{t - 1}'] = prediction_x

            prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'I_FP_y{t - 1}')
            evidence[f'I_FP_y{t - 1}'] = prediction_y

            row_predictions[f'I_FP_x{t - 1}'] = prediction_x
            row_predictions[f'I_FP_y{t - 1}'] = prediction_y
        elif t > 1 and t < 5:

            # Predict for time slice t using evidence from time slice t-1
            cpd_v = GT.get_cpds(f'I_V{t - 1}')
            cpd_I_x = GT.get_cpds(f'I_IP_x{t - 1}')
            cpd_I_y = GT.get_cpds(f'I_IP_y{t - 1}')
            cpd_x = GT.get_cpds(f'I_FP_x{t - 1}')
            cpd_y = GT.get_cpds(f'I_FP_y{t - 1}')

            prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'I_FP_x{t - 1}')
            evidence[f'I_FP_x{t - 1}'] = prediction_x

            prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'I_FP_y{t - 1}')
            evidence[f'I_FP_y{t - 1}'] = prediction_y

            
            prediction_v = predict_with_linear_gaussian_cpd(evidence, cpd_v, f'I_V{t - 1}')
            evidence[f'I_V{t - 1}'] = prediction_v

            prediction_I_x = predict_with_linear_gaussian_cpd(evidence, cpd_I_x, f'I_IP_x{t - 1}')
            evidence[f'I_IP_x{t - 1}'] = prediction_I_x

            prediction_I_y = predict_with_linear_gaussian_cpd(evidence, cpd_I_y, f'I_IP_y{t - 1}')
            evidence[f'I_IP_y{t - 1}'] = prediction_I_y

            
            
            
            # Store the predictions for this time slice
            row_predictions[f'I_V{t - 1}'] = prediction_v
            row_predictions[f'I_IP_x{t - 1}'] = prediction_I_x
            row_predictions[f'I_IP_y{t - 1}'] = prediction_I_y
            row_predictions[f'I_FP_x{t - 1}'] = prediction_x
            row_predictions[f'I_FP_y{t - 1}'] = prediction_y
        
        else:
            # for the last set of interceptor nodes, when t = 5 then 4 is calculated since I've been using t-1, so for the last t, we do 2 sets of predictions for 4 and then 5
            for i in range (5, 7):
                cpd_v = GT.get_cpds(f'I_V{i - 1}')
                cpd_I_x = GT.get_cpds(f'I_IP_x{i - 1}')
                cpd_I_y = GT.get_cpds(f'I_IP_y{i - 1}')
                cpd_x = GT.get_cpds(f'I_FP_x{i - 1}')
                cpd_y = GT.get_cpds(f'I_FP_y{i - 1}')

                
                prediction_x = predict_with_linear_gaussian_cpd(evidence, cpd_x, f'I_FP_x{i - 1}')
                evidence[f'I_FP_x{i - 1}'] = prediction_x

                prediction_y = predict_with_linear_gaussian_cpd(evidence, cpd_y, f'I_FP_y{i - 1}')
                evidence[f'I_FP_y{i - 1}'] = prediction_y
                
                prediction_v = predict_with_linear_gaussian_cpd(evidence, cpd_v, f'I_V{i - 1}')
                evidence[f'I_V{i - 1}'] = prediction_v

                prediction_I_x = predict_with_linear_gaussian_cpd(evidence, cpd_I_x, f'I_IP_x{i - 1}')
                evidence[f'I_IP_x{i - 1}'] = prediction_I_x

                prediction_I_y = predict_with_linear_gaussian_cpd(evidence, cpd_I_y, f'I_IP_y{i - 1}')
                evidence[f'I_IP_y{i - 1}'] = prediction_I_y


                
                
                # Store the predictions for this time slice
                row_predictions[f'I_V{i - 1}'] = prediction_v
                row_predictions[f'I_IP_x{i - 1}'] = prediction_I_x
                row_predictions[f'I_IP_y{i - 1}'] = prediction_I_y
                row_predictions[f'I_FP_x{i - 1}'] = prediction_x
                row_predictions[f'I_FP_y{i - 1}'] = prediction_y

    # Append predictions for this row
    predictions.append(row_predictions)

# Convert predictions to a DataFrame for easier analysis
predictions_df = pd.DataFrame(predictions)

# Print the prediction results
print(predictions_df)
# Out:
# None
# None
# None
# None
# P(P_V1 | P_V0, P_FP_x1, P_FP_y1) = N(0*P_V0 + 0*P_FP_x1 + 0*P_FP_y1 + 0; 1)
# Beta values: [19.05672338  1.00066702  0.10051876  0.09981963]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V0', 'P_FP_x1', 'P_FP_y1']
# Evidence vals: [[19.88108029]
#  [ 0.        ]
#  [ 0.        ]]
# Coeffecients to be used: [1.00066702 0.10051876 0.09981963]
# P(P_IP_x1 | P_FP_x1, P_IP_x0) = N(0*P_FP_x1 + 0*P_IP_x0 + 0; 1)
# Beta values: [0.07498426 0.49996011 0.49999931]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x1', 'P_IP_x0']
# Evidence vals: [[  0.        ]
#  [-24.91831537]]
# Coeffecients to be used: [0.49996011 0.49999931]
# P(P_IP_y1 | P_FP_y1, P_IP_y0) = N(0*P_FP_y1 + 0*P_IP_y0 + 0; 1)
# Beta values: [-1.07155802e-01  5.00179305e-01  1.60632075e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y1', 'P_IP_y0']
# Evidence vals: [[0.]
#  [0.]]
# Coeffecients to be used: [5.00179305e-01 1.60632075e+03]
# None
# None
# None
# None
# P(P_V2 | P_V1, P_FP_x2, P_FP_y2) = N(0*P_V1 + 0*P_FP_x2 + 0*P_FP_y2 + 0; 1)
# Beta values: [20.59949115  1.00043572  0.09969861  0.10024644]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V1', 'P_FP_x2', 'P_FP_y2']
# Evidence vals: [[38.9510647]
#  [ 0.       ]
#  [-0.0535779]]
# Coeffecients to be used: [1.00043572 0.09969861 0.10024644]
# P(P_IP_x2 | P_FP_x2, P_IP_x1) = N(0*P_FP_x2 + 0*P_IP_x1 + 0; 1)
# Beta values: [0.63935943 0.49974912 0.50003792]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x2', 'P_IP_x1']
# Evidence vals: [[  0.        ]
#  [-12.38415618]]
# Coeffecients to be used: [0.49974912 0.50003792]
# P(P_IP_y2 | P_FP_y2, P_IP_y1) = N(0*P_FP_y2 + 0*P_IP_y1 + 0; 1)
# Beta values: [-0.33176278  0.50061543  0.50051603]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y2', 'P_IP_y1']
# Evidence vals: [[-0.0535779]
#  [-0.1071558]]
# Coeffecients to be used: [0.50061543 0.50051603]
# None
# None
# P(I_V1 | I_V0, I_FP_x1, I_FP_y1) = N(0*I_V0 + 0*I_FP_x1 + 0*I_FP_y1 + 0; 1)
# Beta values: [22.77618356  0.99846163  0.09969386  0.09912079]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V0', 'I_FP_x1', 'I_FP_y1']
# Evidence vals: [[1.76353071e+01]
#  [7.98675948e+03]
#  [5.29059213e+00]]
# Coeffecients to be used: [0.99846163 0.09969386 0.09912079]
# P(I_IP_x1 | I_FP_x1, I_IP_x0) = N(0*I_FP_x1 + 0*I_IP_x0 + 0; 1)
# Beta values: [-17.81821818   0.50059306   0.50130077]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x1', 'I_IP_x0']
# Evidence vals: [[7986.75948364]
#  [9976.8361144 ]]
# Coeffecients to be used: [0.50059306 0.50130077]
# P(I_IP_y1 | I_FP_y1, I_IP_y0) = N(0*I_FP_y1 + 0*I_IP_y0 + 0; 1)
# Beta values: [ 2.18874929e-01  4.98891595e-01 -4.63963807e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y1', 'I_IP_y0']
# Evidence vals: [[5.29059213]
#  [0.        ]]
# Coeffecients to be used: [ 4.98891595e-01 -4.63963807e+03]
# None
# None
# P(P_V3 | P_V2, P_FP_x3, P_FP_y3) = N(0*P_V2 + 0*P_FP_x3 + 0*P_FP_y3 + 0; 1)
# Beta values: [19.70808061  0.99855796  0.10022297  0.10064681]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V2', 'P_FP_x3', 'P_FP_y3']
# Evidence vals: [[59.56215657]
#  [ 0.        ]
#  [-0.20610895]]
# Coeffecients to be used: [0.99855796 0.10022297 0.10064681]
# P(P_IP_x3 | P_FP_x3, P_IP_x2) = N(0*P_FP_x3 + 0*P_IP_x2 + 0; 1)
# Beta values: [-0.08666834  0.50000428  0.50004204]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x3', 'P_IP_x2']
# Evidence vals: [[ 0.        ]
#  [-5.55318828]]
# Coeffecients to be used: [0.50000428 0.50004204]
# P(P_IP_y3 | P_FP_y3, P_IP_y2) = N(0*P_FP_y3 + 0*P_IP_y2 + 0; 1)
# Beta values: [2.21355991 0.49564635 0.50069886]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y3', 'P_IP_y2']
# Evidence vals: [[-0.20610895]
#  [-0.4122179 ]]
# Coeffecients to be used: [0.49564635 0.50069886]
# None
# None
# P(I_V2 | I_V1, I_FP_x2, I_FP_y2) = N(0*I_V1 + 0*I_FP_x2 + 0*I_FP_y2 + 0; 1)
# Beta values: [18.84340226  1.00024886  0.10014887  0.09966202]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V1', 'I_FP_x2', 'I_FP_y2']
# Evidence vals: [[8.37139620e+02]
#  [6.88687473e+03]
#  [3.01633108e+00]]
# Coeffecients to be used: [1.00024886 0.10014887 0.09966202]
# P(I_IP_x2 | I_FP_x2, I_IP_x1) = N(0*I_FP_x2 + 0*I_IP_x1 + 0; 1)
# Beta values: [0.2799627  0.49909027 0.50070078]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x2', 'I_IP_x1']
# Evidence vals: [[6886.87473123]
#  [8981.69377227]]
# Coeffecients to be used: [0.49909027 0.50070078]
# P(I_IP_y2 | I_FP_y2, I_IP_y1) = N(0*I_FP_y2 + 0*I_IP_y1 + 0; 1)
# Beta values: [2.41968779 0.49514295 0.49782294]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y2', 'I_IP_y1']
# Evidence vals: [[3.01633108]
#  [2.85830688]]
# Coeffecients to be used: [0.49514295 0.49782294]
# None
# None
# P(P_V4 | P_V3, P_FP_x4, P_FP_y4) = N(0*P_V3 + 0*P_FP_x4 + 0*P_FP_y4 + 0; 1)
# Beta values: [19.93815046  0.99992599  0.10005906  0.09983259]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V3', 'P_FP_x4', 'P_FP_y4']
# Evidence vals: [[79.16360182]
#  [ 0.        ]
#  [ 0.95250286]]
# Coeffecients to be used: [0.99992599 0.10005906 0.09983259]
# P(P_IP_x4 | P_FP_x4, P_IP_x3) = N(0*P_FP_x4 + 0*P_IP_x3 + 0; 1)
# Beta values: [-0.36614527  0.50020303  0.49981929]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x4', 'P_IP_x3']
# Evidence vals: [[ 0.        ]
#  [-2.86349593]]
# Coeffecients to be used: [0.50020303 0.49981929]
# P(P_IP_y4 | P_FP_y4, P_IP_y3) = N(0*P_FP_y4 + 0*P_IP_y3 + 0; 1)
# Beta values: [0.41026682 0.49844129 0.5013454 ]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y4', 'P_IP_y3']
# Evidence vals: [[0.95250286]
#  [1.90500573]]
# Coeffecients to be used: [0.49844129 0.5013454 ]
# None
# None
# P(I_V3 | I_V2, I_FP_x3, I_FP_y3) = N(0*I_V2 + 0*I_FP_x3 + 0*I_FP_y3 + 0; 1)
# Beta values: [18.67620413  0.99967876  0.10023602  0.10059694]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V2', 'I_FP_x3', 'I_FP_y3']
# Evidence vals: [[1.54620471e+03]
#  [6.03335902e+03]
#  [3.57296612e+00]]
# Coeffecients to be used: [0.99967876 0.10023602 0.10059694]
# P(I_IP_x3 | I_FP_x3, I_IP_x2) = N(0*I_FP_x3 + 0*I_IP_x2 + 0; 1)
# Beta values: [-10.93345931   0.50073023   0.50074048]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x3', 'I_IP_x2']
# Evidence vals: [[6033.3590223 ]
#  [7934.59320585]]
# Coeffecients to be used: [0.50073023 0.50074048]
# P(I_IP_y3 | I_FP_y3, I_IP_y2) = N(0*I_FP_y3 + 0*I_IP_y2 + 0; 1)
# Beta values: [1.01717    0.49877047 0.49868642]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y3', 'I_IP_y2']
# Evidence vals: [[3.57296612]
#  [5.3361336 ]]
# Coeffecients to be used: [0.49877047 0.49868642]
# None
# None
# P(P_V5 | P_V4, P_FP_x5, P_FP_y5) = N(0*P_V4 + 0*P_FP_x5 + 0*P_FP_y5 + 0; 1)
# Beta values: [17.79291706  1.0007145   0.10020754  0.10018756]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V4', 'P_FP_x5', 'P_FP_y5']
# Evidence vals: [[99.19098384]
#  [ 0.        ]
#  [ 0.92004972]]
# Coeffecients to be used: [1.0007145  0.10020754 0.10018756]
# P(P_IP_x5 | P_FP_x5, P_IP_x4) = N(0*P_FP_x5 + 0*P_IP_x4 + 0; 1)
# Beta values: [0.09352567 0.4999458  0.50005163]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x5', 'P_IP_x4']
# Evidence vals: [[ 0.        ]
#  [-1.79737578]]
# Coeffecients to be used: [0.4999458  0.50005163]
# P(P_IP_y5 | P_FP_y5, P_IP_y4) = N(0*P_FP_y5 + 0*P_IP_y4 + 0; 1)
# Beta values: [0.95766041 0.49556477 0.50325021]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y5', 'P_IP_y4']
# Evidence vals: [[0.92004972]
#  [1.84009943]]
# Coeffecients to be used: [0.49556477 0.50325021]
# None
# None
# P(I_V4 | I_V3, I_FP_x4, I_FP_y4) = N(0*I_V3 + 0*I_FP_x4 + 0*I_FP_y4 + 0; 1)
# Beta values: [19.15073252  1.00010947  0.10009013  0.10009519]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V3', 'I_FP_x4', 'I_FP_y4']
# Evidence vals: [[2.16950356e+03]
#  [5.30166961e+03]
#  [3.80204852e+00]]
# Coeffecients to be used: [1.00010947 0.10009013 0.10009519]
# P(I_IP_x4 | I_FP_x4, I_IP_x3) = N(0*I_FP_x4 + 0*I_IP_x3 + 0; 1)
# Beta values: [23.14274752  0.49837257  0.49815342]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x4', 'I_IP_x3']
# Evidence vals: [[5301.66960981]
#  [6983.32380623]]
# Coeffecients to be used: [0.49837257 0.49815342]
# P(I_IP_y4 | I_FP_y4, I_IP_y3) = N(0*I_FP_y4 + 0*I_IP_y3 + 0; 1)
# Beta values: [0.93090509 0.50100358 0.49638989]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y4', 'I_IP_y3']
# Evidence vals: [[3.80204852]
#  [5.46031737]]
# Coeffecients to be used: [0.50100358 0.49638989]
# None
# None
# P(I_V5 | I_V4, I_FP_x5, I_FP_y5) = N(0*I_V4 + 0*I_FP_x5 + 0*I_FP_y5 + 0; 1)
# Beta values: [22.42533094  0.99964387  0.09971577  0.10007905]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V4', 'I_FP_x5', 'I_FP_y5']
# Evidence vals: [[2.71991714e+03]
#  [4.66255891e+03]
#  [3.91371024e+00]]
# Coeffecients to be used: [0.99964387 0.09971577 0.10007905]
# P(I_IP_x5 | I_FP_x5, I_IP_x4) = N(0*I_FP_x5 + 0*I_IP_x4 + 0; 1)
# Beta values: [4.43761222 0.50212775 0.49777351]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x5', 'I_IP_x4']
# Evidence vals: [[4662.55890688]
#  [6144.11604788]]
# Coeffecients to be used: [0.50212775 0.49777351]
# P(I_IP_y5 | I_FP_y5, I_IP_y4) = N(0*I_FP_y5 + 0*I_IP_y4 + 0; 1)
# Beta values: [-1.02514688  0.50430989  0.49669748]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y5', 'I_IP_y4']
# Evidence vals: [[3.91371024]
#  [5.54619136]]
# Coeffecients to be used: [0.50430989 0.49669748]
# None
# None
# None
# None
# P(P_V1 | P_V0, P_FP_x1, P_FP_y1) = N(0*P_V0 + 0*P_FP_x1 + 0*P_FP_y1 + 0; 1)
# Beta values: [19.05672338  1.00066702  0.10051876  0.09981963]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V0', 'P_FP_x1', 'P_FP_y1']
# Evidence vals: [[18.56593719]
#  [ 0.        ]
#  [ 0.        ]]
# Coeffecients to be used: [1.00066702 0.10051876 0.09981963]
# P(P_IP_x1 | P_FP_x1, P_IP_x0) = N(0*P_FP_x1 + 0*P_IP_x0 + 0; 1)
# Beta values: [0.07498426 0.49996011 0.49999931]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x1', 'P_IP_x0']
# Evidence vals: [[  0.        ]
#  [149.41621767]]
# Coeffecients to be used: [0.49996011 0.49999931]
# P(P_IP_y1 | P_FP_y1, P_IP_y0) = N(0*P_FP_y1 + 0*P_IP_y0 + 0; 1)
# Beta values: [-1.07155802e-01  5.00179305e-01  1.60632075e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y1', 'P_IP_y0']
# Evidence vals: [[0.]
#  [0.]]
# Coeffecients to be used: [5.00179305e-01 1.60632075e+03]
# None
# None
# None
# None
# P(P_V2 | P_V1, P_FP_x2, P_FP_y2) = N(0*P_V1 + 0*P_FP_x2 + 0*P_FP_y2 + 0; 1)
# Beta values: [20.59949115  1.00043572  0.09969861  0.10024644]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V1', 'P_FP_x2', 'P_FP_y2']
# Evidence vals: [[37.63504437]
#  [ 0.        ]
#  [-0.0535779 ]]
# Coeffecients to be used: [1.00043572 0.09969861 0.10024644]
# P(P_IP_x2 | P_FP_x2, P_IP_x1) = N(0*P_FP_x2 + 0*P_IP_x1 + 0; 1)
# Beta values: [0.63935943 0.49974912 0.50003792]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x2', 'P_IP_x1']
# Evidence vals: [[ 0.        ]
#  [74.78298971]]
# Coeffecients to be used: [0.49974912 0.50003792]
# P(P_IP_y2 | P_FP_y2, P_IP_y1) = N(0*P_FP_y2 + 0*P_IP_y1 + 0; 1)
# Beta values: [-0.33176278  0.50061543  0.50051603]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y2', 'P_IP_y1']
# Evidence vals: [[-0.0535779]
#  [-0.1071558]]
# Coeffecients to be used: [0.50061543 0.50051603]
# None
# None
# P(I_V1 | I_V0, I_FP_x1, I_FP_y1) = N(0*I_V0 + 0*I_FP_x1 + 0*I_FP_y1 + 0; 1)
# Beta values: [22.77618356  0.99846163  0.09969386  0.09912079]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V0', 'I_FP_x1', 'I_FP_y1']
# Evidence vals: [[2.31810932e+01]
#  [8.00390588e+03]
#  [6.95432796e+00]]
# Coeffecients to be used: [0.99846163 0.09969386 0.09912079]
# P(I_IP_x1 | I_FP_x1, I_IP_x0) = N(0*I_FP_x1 + 0*I_IP_x0 + 0; 1)
# Beta values: [-17.81821818   0.50059306   0.50130077]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x1', 'I_IP_x0']
# Evidence vals: [[8003.9058758 ]
#  [9996.18943479]]
# Coeffecients to be used: [0.50059306 0.50130077]
# P(I_IP_y1 | I_FP_y1, I_IP_y0) = N(0*I_FP_y1 + 0*I_IP_y0 + 0; 1)
# Beta values: [ 2.18874929e-01  4.98891595e-01 -4.63963807e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y1', 'I_IP_y0']
# Evidence vals: [[6.95432796]
#  [0.        ]]
# Coeffecients to be used: [ 4.98891595e-01 -4.63963807e+03]
# None
# None
# P(P_V3 | P_V2, P_FP_x3, P_FP_y3) = N(0*P_V2 + 0*P_FP_x3 + 0*P_FP_y3 + 0; 1)
# Beta values: [19.70808061  0.99855796  0.10022297  0.10064681]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V2', 'P_FP_x3', 'P_FP_y3']
# Evidence vals: [[58.24556284]
#  [ 0.        ]
#  [-0.20610895]]
# Coeffecients to be used: [0.99855796 0.10022297 0.10064681]
# P(P_IP_x3 | P_FP_x3, P_IP_x2) = N(0*P_FP_x3 + 0*P_IP_x2 + 0; 1)
# Beta values: [-0.08666834  0.50000428  0.50004204]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x3', 'P_IP_x2']
# Evidence vals: [[ 0.        ]
#  [38.03369014]]
# Coeffecients to be used: [0.50000428 0.50004204]
# P(P_IP_y3 | P_FP_y3, P_IP_y2) = N(0*P_FP_y3 + 0*P_IP_y2 + 0; 1)
# Beta values: [2.21355991 0.49564635 0.50069886]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y3', 'P_IP_y2']
# Evidence vals: [[-0.20610895]
#  [-0.4122179 ]]
# Coeffecients to be used: [0.49564635 0.50069886]
# None
# None
# P(I_V2 | I_V1, I_FP_x2, I_FP_y2) = N(0*I_V1 + 0*I_FP_x2 + 0*I_FP_y2 + 0; 1)
# Beta values: [18.84340226  1.00024886  0.10014887  0.09966202]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V1', 'I_FP_x2', 'I_FP_y2']
# Evidence vals: [[8.44551176e+02]
#  [6.90116125e+03]
#  [3.93046374e+00]]
# Coeffecients to be used: [1.00024886 0.10014887 0.09966202]
# P(I_IP_x2 | I_FP_x2, I_IP_x1) = N(0*I_FP_x2 + 0*I_IP_x1 + 0; 1)
# Beta values: [0.2799627  0.49909027 0.50070078]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x2', 'I_IP_x1']
# Evidence vals: [[6901.16124853]
#  [8999.97897159]]
# Coeffecients to be used: [0.49909027 0.50070078]
# P(I_IP_y2 | I_FP_y2, I_IP_y1) = N(0*I_FP_y2 + 0*I_IP_y1 + 0; 1)
# Beta values: [2.41968779 0.49514295 0.49782294]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y2', 'I_IP_y1']
# Evidence vals: [[3.93046374]
#  [3.6883307 ]]
# Coeffecients to be used: [0.49514295 0.49782294]
# None
# None
# P(P_V4 | P_V3, P_FP_x4, P_FP_y4) = N(0*P_V3 + 0*P_FP_x4 + 0*P_FP_y4 + 0; 1)
# Beta values: [19.93815046  0.99992599  0.10005906  0.09983259]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V3', 'P_FP_x4', 'P_FP_y4']
# Evidence vals: [[77.84890666]
#  [ 0.        ]
#  [ 0.95250286]]
# Coeffecients to be used: [0.99992599 0.10005906 0.09983259]
# P(P_IP_x4 | P_FP_x4, P_IP_x3) = N(0*P_FP_x4 + 0*P_IP_x3 + 0; 1)
# Beta values: [-0.36614527  0.50020303  0.49981929]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x4', 'P_IP_x3']
# Evidence vals: [[ 0.        ]
#  [18.93177563]]
# Coeffecients to be used: [0.50020303 0.49981929]
# P(P_IP_y4 | P_FP_y4, P_IP_y3) = N(0*P_FP_y4 + 0*P_IP_y3 + 0; 1)
# Beta values: [0.41026682 0.49844129 0.5013454 ]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y4', 'P_IP_y3']
# Evidence vals: [[0.95250286]
#  [1.90500573]]
# Coeffecients to be used: [0.49844129 0.5013454 ]
# None
# None
# P(I_V3 | I_V2, I_FP_x3, I_FP_y3) = N(0*I_V2 + 0*I_FP_x3 + 0*I_FP_y3 + 0; 1)
# Beta values: [18.67620413  0.99967876  0.10023602  0.10059694]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V2', 'I_FP_x3', 'I_FP_y3']
# Evidence vals: [[1.55513999e+03]
#  [6.04578782e+03]
#  [4.28012155e+00]]
# Coeffecients to be used: [0.99967876 0.10023602 0.10059694]
# P(I_IP_x3 | I_FP_x3, I_IP_x2) = N(0*I_FP_x3 + 0*I_IP_x2 + 0; 1)
# Beta values: [-10.93345931   0.50073023   0.50074048]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x3', 'I_IP_x2']
# Evidence vals: [[6045.78781515]
#  [7950.87888118]]
# Coeffecients to be used: [0.50073023 0.50074048]
# P(I_IP_y3 | I_FP_y3, I_IP_y2) = N(0*I_FP_y3 + 0*I_IP_y2 + 0; 1)
# Beta values: [1.01717    0.49877047 0.49868642]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y3', 'I_IP_y2']
# Evidence vals: [[4.28012155]
#  [6.20196485]]
# Coeffecients to be used: [0.49877047 0.49868642]
# None
# None
# P(P_V5 | P_V4, P_FP_x5, P_FP_y5) = N(0*P_V4 + 0*P_FP_x5 + 0*P_FP_y5 + 0; 1)
# Beta values: [17.79291706  1.0007145   0.10020754  0.10018756]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V4', 'P_FP_x5', 'P_FP_y5']
# Evidence vals: [[97.87638599]
#  [ 0.        ]
#  [ 0.92004972]]
# Coeffecients to be used: [1.0007145  0.10020754 0.10018756]
# P(P_IP_x5 | P_FP_x5, P_IP_x4) = N(0*P_FP_x5 + 0*P_IP_x4 + 0; 1)
# Beta values: [0.09352567 0.4999458  0.50005163]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x5', 'P_IP_x4']
# Evidence vals: [[0.        ]
#  [9.09632144]]
# Coeffecients to be used: [0.4999458  0.50005163]
# P(P_IP_y5 | P_FP_y5, P_IP_y4) = N(0*P_FP_y5 + 0*P_IP_y4 + 0; 1)
# Beta values: [0.95766041 0.49556477 0.50325021]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y5', 'P_IP_y4']
# Evidence vals: [[0.92004972]
#  [1.84009943]]
# Coeffecients to be used: [0.49556477 0.50325021]
# None
# None
# P(I_V4 | I_V3, I_FP_x4, I_FP_y4) = N(0*I_V3 + 0*I_FP_x4 + 0*I_FP_y4 + 0; 1)
# Beta values: [19.15073252  1.00010947  0.10009013  0.10009519]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V3', 'I_FP_x4', 'I_FP_y4']
# Evidence vals: [[2.17975292e+03]
#  [5.31258743e+03]
#  [4.40643841e+00]]
# Coeffecients to be used: [1.00010947 0.10009013 0.10009519]
# P(I_IP_x4 | I_FP_x4, I_IP_x3) = N(0*I_FP_x4 + 0*I_IP_x3 + 0; 1)
# Beta values: [23.14274752  0.49837257  0.49815342]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x4', 'I_IP_x3']
# Evidence vals: [[5312.58743226]
#  [6997.70217543]]
# Coeffecients to be used: [0.49837257 0.49815342]
# P(I_IP_y4 | I_FP_y4, I_IP_y3) = N(0*I_FP_y4 + 0*I_IP_y3 + 0; 1)
# Beta values: [0.93090509 0.50100358 0.49638989]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y4', 'I_IP_y3']
# Evidence vals: [[4.40643841]
#  [6.2448039 ]]
# Coeffecients to be used: [0.50100358 0.49638989]
# None
# None
# P(I_V5 | I_V4, I_FP_x5, I_FP_y5) = N(0*I_V4 + 0*I_FP_x5 + 0*I_FP_y5 + 0; 1)
# Beta values: [22.42533094  0.99964387  0.09971577  0.10007905]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V4', 'I_FP_x5', 'I_FP_y5']
# Evidence vals: [[2.73132088e+03]
#  [4.67213614e+03]
#  [4.44113355e+00]]
# Coeffecients to be used: [0.99964387 0.09971577 0.10007905]
# P(I_IP_x5 | I_FP_x5, I_IP_x4) = N(0*I_FP_x5 + 0*I_IP_x4 + 0; 1)
# Beta values: [4.43761222 0.50212775 0.49777351]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x5', 'I_IP_x4']
# Evidence vals: [[4672.13614209]
#  [6156.71982482]]
# Coeffecients to be used: [0.50212775 0.49777351]
# P(I_IP_y5 | I_FP_y5, I_IP_y4) = N(0*I_FP_y5 + 0*I_IP_y4 + 0; 1)
# Beta values: [-1.02514688  0.50430989  0.49669748]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y5', 'I_IP_y4']
# Evidence vals: [[4.44113355]
#  [6.23840404]]
# Coeffecients to be used: [0.50430989 0.49669748]
# None
# None
# None
# None
# P(P_V1 | P_V0, P_FP_x1, P_FP_y1) = N(0*P_V0 + 0*P_FP_x1 + 0*P_FP_y1 + 0; 1)
# Beta values: [19.05672338  1.00066702  0.10051876  0.09981963]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V0', 'P_FP_x1', 'P_FP_y1']
# Evidence vals: [[25.85852107]
#  [ 0.        ]
#  [ 0.        ]]
# Coeffecients to be used: [1.00066702 0.10051876 0.09981963]
# P(P_IP_x1 | P_FP_x1, P_IP_x0) = N(0*P_FP_x1 + 0*P_IP_x0 + 0; 1)
# Beta values: [0.07498426 0.49996011 0.49999931]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x1', 'P_IP_x0']
# Evidence vals: [[   0.        ]
#  [-115.89006312]]
# Coeffecients to be used: [0.49996011 0.49999931]
# P(P_IP_y1 | P_FP_y1, P_IP_y0) = N(0*P_FP_y1 + 0*P_IP_y0 + 0; 1)
# Beta values: [-1.07155802e-01  5.00179305e-01  1.60632075e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y1', 'P_IP_y0']
# Evidence vals: [[0.]
#  [0.]]
# Coeffecients to be used: [5.00179305e-01 1.60632075e+03]
# None
# None
# None
# None
# P(P_V2 | P_V1, P_FP_x2, P_FP_y2) = N(0*P_V1 + 0*P_FP_x2 + 0*P_FP_y2 + 0; 1)
# Beta values: [20.59949115  1.00043572  0.09969861  0.10024644]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V1', 'P_FP_x2', 'P_FP_y2']
# Evidence vals: [[44.93249254]
#  [ 0.        ]
#  [-0.0535779 ]]
# Coeffecients to be used: [1.00043572 0.09969861 0.10024644]
# P(P_IP_x2 | P_FP_x2, P_IP_x1) = N(0*P_FP_x2 + 0*P_IP_x1 + 0; 1)
# Beta values: [0.63935943 0.49974912 0.50003792]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x2', 'P_IP_x1']
# Evidence vals: [[  0.        ]
#  [-57.86996711]]
# Coeffecients to be used: [0.49974912 0.50003792]
# P(P_IP_y2 | P_FP_y2, P_IP_y1) = N(0*P_FP_y2 + 0*P_IP_y1 + 0; 1)
# Beta values: [-0.33176278  0.50061543  0.50051603]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y2', 'P_IP_y1']
# Evidence vals: [[-0.0535779]
#  [-0.1071558]]
# Coeffecients to be used: [0.50061543 0.50051603]
# None
# None
# P(I_V1 | I_V0, I_FP_x1, I_FP_y1) = N(0*I_V0 + 0*I_FP_x1 + 0*I_FP_y1 + 0; 1)
# Beta values: [22.77618356  0.99846163  0.09969386  0.09912079]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V0', 'I_FP_x1', 'I_FP_y1']
# Evidence vals: [[1.84595576e+01]
#  [8.02253404e+03]
#  [5.53786727e+00]]
# Coeffecients to be used: [0.99846163 0.09969386 0.09912079]
# P(I_IP_x1 | I_FP_x1, I_IP_x0) = N(0*I_FP_x1 + 0*I_IP_x0 + 0; 1)
# Beta values: [-17.81821818   0.50059306   0.50130077]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x1', 'I_IP_x0']
# Evidence vals: [[ 8022.53404421]
#  [10021.24522119]]
# Coeffecients to be used: [0.50059306 0.50130077]
# P(I_IP_y1 | I_FP_y1, I_IP_y0) = N(0*I_FP_y1 + 0*I_IP_y0 + 0; 1)
# Beta values: [ 2.18874929e-01  4.98891595e-01 -4.63963807e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y1', 'I_IP_y0']
# Evidence vals: [[5.53786727]
#  [0.        ]]
# Coeffecients to be used: [ 4.98891595e-01 -4.63963807e+03]
# None
# None
# P(P_V3 | P_V2, P_FP_x3, P_FP_y3) = N(0*P_V2 + 0*P_FP_x3 + 0*P_FP_y3 + 0; 1)
# Beta values: [19.70808061  0.99855796  0.10022297  0.10064681]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V2', 'P_FP_x3', 'P_FP_y3']
# Evidence vals: [[65.54619064]
#  [ 0.        ]
#  [-0.20610895]]
# Coeffecients to be used: [0.99855796 0.10022297 0.10064681]
# P(P_IP_x3 | P_FP_x3, P_IP_x2) = N(0*P_FP_x3 + 0*P_IP_x2 + 0; 1)
# Beta values: [-0.08666834  0.50000428  0.50004204]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x3', 'P_IP_x2']
# Evidence vals: [[  0.        ]
#  [-28.29781861]]
# Coeffecients to be used: [0.50000428 0.50004204]
# P(P_IP_y3 | P_FP_y3, P_IP_y2) = N(0*P_FP_y3 + 0*P_IP_y2 + 0; 1)
# Beta values: [2.21355991 0.49564635 0.50069886]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y3', 'P_IP_y2']
# Evidence vals: [[-0.20610895]
#  [-0.4122179 ]]
# Coeffecients to be used: [0.49564635 0.50069886]
# None
# None
# P(I_V2 | I_V1, I_FP_x2, I_FP_y2) = N(0*I_V1 + 0*I_FP_x2 + 0*I_FP_y2 + 0; 1)
# Beta values: [18.84340226  1.00024886  0.10014887  0.09966202]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V1', 'I_FP_x2', 'I_FP_y2']
# Evidence vals: [[8.41553617e+02]
#  [6.91769251e+03]
#  [3.15219536e+00]]
# Coeffecients to be used: [1.00024886 0.10014887 0.09966202]
# P(I_IP_x2 | I_FP_x2, I_IP_x1) = N(0*I_FP_x2 + 0*I_IP_x1 + 0; 1)
# Beta values: [0.2799627  0.49909027 0.50070078]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x2', 'I_IP_x1']
# Evidence vals: [[6917.69250748]
#  [9021.86458842]]
# Coeffecients to be used: [0.49909027 0.50070078]
# P(I_IP_y2 | I_FP_y2, I_IP_y1) = N(0*I_FP_y2 + 0*I_IP_y1 + 0; 1)
# Beta values: [2.41968779 0.49514295 0.49782294]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y2', 'I_IP_y1']
# Evidence vals: [[3.15219536]
#  [2.98167036]]
# Coeffecients to be used: [0.49514295 0.49782294]
# None
# None
# P(P_V4 | P_V3, P_FP_x4, P_FP_y4) = N(0*P_V3 + 0*P_FP_x4 + 0*P_FP_y4 + 0; 1)
# Beta values: [19.93815046  0.99992599  0.10005906  0.09983259]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V3', 'P_FP_x4', 'P_FP_y4']
# Evidence vals: [[85.13900665]
#  [ 0.        ]
#  [ 0.95250286]]
# Coeffecients to be used: [0.99992599 0.10005906 0.09983259]
# P(P_IP_x4 | P_FP_x4, P_IP_x3) = N(0*P_FP_x4 + 0*P_IP_x3 + 0; 1)
# Beta values: [-0.36614527  0.50020303  0.49981929]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x4', 'P_IP_x3']
# Evidence vals: [[  0.        ]
#  [-14.23676725]]
# Coeffecients to be used: [0.50020303 0.49981929]
# P(P_IP_y4 | P_FP_y4, P_IP_y3) = N(0*P_FP_y4 + 0*P_IP_y3 + 0; 1)
# Beta values: [0.41026682 0.49844129 0.5013454 ]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y4', 'P_IP_y3']
# Evidence vals: [[0.95250286]
#  [1.90500573]]
# Coeffecients to be used: [0.49844129 0.5013454 ]
# None
# None
# P(I_V3 | I_V2, I_FP_x3, I_FP_y3) = N(0*I_V2 + 0*I_FP_x3 + 0*I_FP_y3 + 0; 1)
# Beta values: [18.67620413  0.99967876  0.10023602  0.10059694]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V2', 'I_FP_x3', 'I_FP_y3']
# Evidence vals: [[1.55371971e+03]
#  [6.06035156e+03]
#  [3.67806812e+00]]
# Coeffecients to be used: [0.99967876 0.10023602 0.10059694]
# P(I_IP_x3 | I_FP_x3, I_IP_x2) = N(0*I_FP_x3 + 0*I_IP_x2 + 0; 1)
# Beta values: [-10.93345931   0.50073023   0.50074048]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x3', 'I_IP_x2']
# Evidence vals: [[
]
# Coeffecients to be used: [0.50100358 0.49638989]
# None
# None
# P(I_V5 | I_V4, I_FP_x5, I_FP_y5) = N(0*I_V4 + 0*I_FP_x5 + 0*I_FP_y5 + 0; 1)
# Beta values: [22.42533094  0.99964387  0.09971577  0.10007905]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V4', 'I_FP_x5', 'I_FP_y5']
# Evidence vals: [[2.73089071e+03]
#  [4.68096891e+03]
#  [3.96766334e+00]]
# Coeffecients to be used: [0.99964387 0.09971577 0.10007905]
# P(I_IP_x5 | I_FP_x5, I_IP_x4) = N(0*I_FP_x5 + 0*I_IP_x4 + 0; 1)
# Beta values: [4.43761222 0.50212775 0.49777351]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x5', 'I_IP_x4']
# Evidence vals: [[4680.9689066 ]
#  [6168.34715382]]
# Coeffecients to be used: [0.50212775 0.49777351]
# P(I_IP_y5 | I_FP_y5, I_IP_y4) = N(0*I_FP_y5 + 0*I_IP_y4 + 0; 1)
# Beta values: [-1.02514688  0.50430989  0.49669748]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y5', 'I_IP_y4']
# Evidence vals: [[3.96766334]
#  [5.6170017 ]]
# Coeffecients to be used: [0.50430989 0.49669748]
# None
# None
# None
# None
# P(P_V1 | P_V0, P_FP_x1, P_FP_y1) = N(0*P_V0 + 0*P_FP_x1 + 0*P_FP_y1 + 0; 1)
# Beta values: [19.05672338  1.00066702  0.10051876  0.09981963]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V0', 'P_FP_x1', 'P_FP_y1']
# Evidence vals: [[20.9927627]
#  [ 0.       ]
#  [ 0.       ]]
# Coeffecients to be used: [1.00066702 0.10051876 0.09981963]
# P(P_IP_x1 | P_FP_x1, P_IP_x0) = N(0*P_FP_x1 + 0*P_IP_x0 + 0; 1)
# Beta values: [0.07498426 0.49996011 0.49999931]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x1', 'P_IP_x0']
# Evidence vals: [[  0.        ]
#  [-24.15997032]]
# Coeffecients to be used: [0.49996011 0.49999931]
# P(P_IP_y1 | P_FP_y1, P_IP_y0) = N(0*P_FP_y1 + 0*P_IP_y0 + 0; 1)
# Beta values: [-1.07155802e-01  5.00179305e-01  1.60632075e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y1', 'P_IP_y0']
# Evidence vals: [[0.]
#  [0.]]
# Coeffecients to be used: [5.00179305e-01 1.60632075e+03]
# None
# None
# None
# None
# P(P_V2 | P_V1, P_FP_x2, P_FP_y2) = N(0*P_V1 + 0*P_FP_x2 + 0*P_FP_y2 + 0; 1)
# Beta values: [20.59949115  1.00043572  0.09969861  0.10024644]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V1', 'P_FP_x2', 'P_FP_y2']
# Evidence vals: [[40.06348862]
#  [ 0.        ]
#  [-0.0535779 ]]
# Coeffecients to be used: [1.00043572 0.09969861 0.10024644]
# P(P_IP_x2 | P_FP_x2, P_IP_x1) = N(0*P_FP_x2 + 0*P_IP_x1 + 0; 1)
# Beta values: [0.63935943 0.49974912 0.50003792]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x2', 'P_IP_x1']
# Evidence vals: [[  0.        ]
#  [-12.00498418]]
# Coeffecients to be used: [0.49974912 0.50003792]
# P(P_IP_y2 | P_FP_y2, P_IP_y1) = N(0*P_FP_y2 + 0*P_IP_y1 + 0; 1)
# Beta values: [-0.33176278  0.50061543  0.50051603]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y2', 'P_IP_y1']
# Evidence vals: [[-0.0535779]
#  [-0.1071558]]
# Coeffecients to be used: [0.50061543 0.50051603]
# None
# None
# P(I_V1 | I_V0, I_FP_x1, I_FP_y1) = N(0*I_V0 + 0*I_FP_x1 + 0*I_FP_y1 + 0; 1)
# Beta values: [22.77618356  0.99846163  0.09969386  0.09912079]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V0', 'I_FP_x1', 'I_FP_y1']
# Evidence vals: [[1.71551383e+01]
#  [8.01903141e+03]
#  [5.14654149e+00]]
# Coeffecients to be used: [0.99846163 0.09969386 0.09912079]
# P(I_IP_x1 | I_FP_x1, I_IP_x0) = N(0*I_FP_x1 + 0*I_IP_x0 + 0; 1)
# Beta values: [-17.81821818   0.50059306   0.50130077]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x1', 'I_IP_x0']
# Evidence vals: [[ 8019.03141023]
#  [10017.35608593]]
# Coeffecients to be used: [0.50059306 0.50130077]
# P(I_IP_y1 | I_FP_y1, I_IP_y0) = N(0*I_FP_y1 + 0*I_IP_y0 + 0; 1)
# Beta values: [ 2.18874929e-01  4.98891595e-01 -4.63963807e+03]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y1', 'I_IP_y0']
# Evidence vals: [[5.14654149]
#  [0.        ]]
# Coeffecients to be used: [ 4.98891595e-01 -4.63963807e+03]
# None
# None
# P(P_V3 | P_V2, P_FP_x3, P_FP_y3) = N(0*P_V2 + 0*P_FP_x3 + 0*P_FP_y3 + 0; 1)
# Beta values: [19.70808061  0.99855796  0.10022297  0.10064681]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V2', 'P_FP_x3', 'P_FP_y3']
# Evidence vals: [[60.6750652 ]
#  [ 0.        ]
#  [-0.20610895]]
# Coeffecients to be used: [0.99855796 0.10022297 0.10064681]
# P(P_IP_x3 | P_FP_x3, P_IP_x2) = N(0*P_FP_x3 + 0*P_IP_x2 + 0; 1)
# Beta values: [-0.08666834  0.50000428  0.50004204]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x3', 'P_IP_x2']
# Evidence vals: [[ 0.       ]
#  [-5.3635879]]
# Coeffecients to be used: [0.50000428 0.50004204]
# P(P_IP_y3 | P_FP_y3, P_IP_y2) = N(0*P_FP_y3 + 0*P_IP_y2 + 0; 1)
# Beta values: [2.21355991 0.49564635 0.50069886]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y3', 'P_IP_y2']
# Evidence vals: [[-0.20610895]
#  [-0.4122179 ]]
# Coeffecients to be used: [0.49564635 0.50069886]
# None
# None
# P(I_V2 | I_V1, I_FP_x2, I_FP_y2) = N(0*I_V1 + 0*I_FP_x2 + 0*I_FP_y2 + 0; 1)
# Beta values: [18.84340226  1.00024886  0.10014887  0.09966202]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V1', 'I_FP_x2', 'I_FP_y2']
# Evidence vals: [[8.39863224e+02]
#  [6.91479021e+03]
#  [2.93718306e+00]]
# Coeffecients to be used: [1.00024886 0.10014887 0.09966202]
# P(I_IP_x2 | I_FP_x2, I_IP_x1) = N(0*I_FP_x2 + 0*I_IP_x1 + 0; 1)
# Beta values: [0.2799627  0.49909027 0.50070078]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x2', 'I_IP_x1']
# Evidence vals: [[6914.7902069 ]
#  [9018.16156767]]
# Coeffecients to be used: [0.49909027 0.50070078]
# P(I_IP_y2 | I_FP_y2, I_IP_y1) = N(0*I_FP_y2 + 0*I_IP_y1 + 0; 1)
# Beta values: [2.41968779 0.49514295 0.49782294]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y2', 'I_IP_y1']
# Evidence vals: [[2.93718306]
#  [2.78644122]]
# Coeffecients to be used: [0.49514295 0.49782294]
# None
# None
# P(P_V4 | P_V3, P_FP_x4, P_FP_y4) = N(0*P_V3 + 0*P_FP_x4 + 0*P_FP_y4 + 0; 1)
# Beta values: [19.93815046  0.99992599  0.10005906  0.09983259]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V3', 'P_FP_x4', 'P_FP_y4']
# Evidence vals: [[80.27490558]
#  [ 0.        ]
#  [ 0.95250286]]
# Coeffecients to be used: [0.99992599 0.10005906 0.09983259]
# P(P_IP_x4 | P_FP_x4, P_IP_x3) = N(0*P_FP_x4 + 0*P_IP_x3 + 0; 1)
# Beta values: [-0.36614527  0.50020303  0.49981929]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x4', 'P_IP_x3']
# Evidence vals: [[ 0.        ]
#  [-2.76868777]]
# Coeffecients to be used: [0.50020303 0.49981929]
# P(P_IP_y4 | P_FP_y4, P_IP_y3) = N(0*P_FP_y4 + 0*P_IP_y3 + 0; 1)
# Beta values: [0.41026682 0.49844129 0.5013454 ]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y4', 'P_IP_y3']
# Evidence vals: [[0.95250286]
#  [1.90500573]]
# Coeffecients to be used: [0.49844129 0.5013454 ]
# None
# None
# P(I_V3 | I_V2, I_FP_x3, I_FP_y3) = N(0*I_V2 + 0*I_FP_x3 + 0*I_FP_y3 + 0; 1)
# Beta values: [18.67620413  0.99967876  0.10023602  0.10059694]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V2', 'I_FP_x3', 'I_FP_y3']
# Evidence vals: [[1.55171681e+03]
#  [6.05782956e+03]
#  [3.51173874e+00]]
# Coeffecients to be used: [0.99967876 0.10023602 0.10059694]
# P(I_IP_x3 | I_FP_x3, I_IP_x2) = N(0*I_FP_x3 + 0*I_IP_x2 + 0; 1)
# Beta values: [-10.93345931   0.50073023   0.50074048]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x3', 'I_IP_x2']
# Evidence vals: [[6057.82956294]
#  [7966.78500173]]
# Coeffecients to be used: [0.50073023 0.50074048]
# P(I_IP_y3 | I_FP_y3, I_IP_y2) = N(0*I_FP_y3 + 0*I_IP_y2 + 0; 1)
# Beta values: [1.01717    0.49877047 0.49868642]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y3', 'I_IP_y2']
# Evidence vals: [[3.51173874]
#  [5.26116765]]
# Coeffecients to be used: [0.49877047 0.49868642]
# None
# None
# P(P_V5 | P_V4, P_FP_x5, P_FP_y5) = N(0*P_V4 + 0*P_FP_x5 + 0*P_FP_y5 + 0; 1)
# Beta values: [17.79291706  1.0007145   0.10020754  0.10018756]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['P_V4', 'P_FP_x5', 'P_FP_y5']
# Evidence vals: [[100.30220535]
#  [  0.        ]
#  [  0.92004972]]
# Coeffecients to be used: [1.0007145  0.10020754 0.10018756]
# P(P_IP_x5 | P_FP_x5, P_IP_x4) = N(0*P_FP_x5 + 0*P_IP_x4 + 0; 1)
# Beta values: [0.09352567 0.4999458  0.50005163]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_x5', 'P_IP_x4']
# Evidence vals: [[ 0.        ]
#  [-1.74998883]]
# Coeffecients to be used: [0.4999458  0.50005163]
# P(P_IP_y5 | P_FP_y5, P_IP_y4) = N(0*P_FP_y5 + 0*P_IP_y4 + 0; 1)
# Beta values: [0.95766041 0.49556477 0.50325021]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['P_FP_y5', 'P_IP_y4']
# Evidence vals: [[0.92004972]
#  [1.84009943]]
# Coeffecients to be used: [0.49556477 0.50325021]
# None
# None
# P(I_V4 | I_V3, I_FP_x4, I_FP_y4) = N(0*I_V3 + 0*I_FP_x4 + 0*I_FP_y4 + 0; 1)
# Beta values: [19.15073252  1.00010947  0.10009013  0.10009519]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V3', 'I_FP_x4', 'I_FP_y4']
# Evidence vals: [[2.17746055e+03]
#  [5.32319721e+03]
#  [3.74971885e+00]]
# Coeffecients to be used: [1.00010947 0.10009013 0.10009519]
# P(I_IP_x4 | I_FP_x4, I_IP_x3) = N(0*I_FP_x4 + 0*I_IP_x3 + 0; 1)
# Beta values: [23.14274752  0.49837257  0.49815342]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x4', 'I_IP_x3']
# Evidence vals: [[5323.19720939]
#  [7011.69668101]]
# Coeffecients to be used: [0.49837257 0.49815342]
# P(I_IP_y4 | I_FP_y4, I_IP_y3) = N(0*I_FP_y4 + 0*I_IP_y3 + 0; 1)
# Beta values: [0.93090509 0.50100358 0.49638989]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y4', 'I_IP_y3']
# Evidence vals: [[3.74971885]
#  [5.39239446]]
# Coeffecients to be used: [0.50100358 0.49638989]
# None
# None
# P(I_V5 | I_V4, I_FP_x5, I_FP_y5) = N(0*I_V4 + 0*I_FP_x5 + 0*I_FP_y5 + 0; 1)
# Beta values: [22.42533094  0.99964387  0.09971577  0.10007905]
# Mean vals: [0 0 0 0]
# Variance: 1
# Evidence required: ['I_V4', 'I_FP_x5', 'I_FP_y5']
# Evidence vals: [[2.73002447e+03]
#  [4.68144859e+03]
#  [3.86804453e+00]]
# Coeffecients to be used: [0.99964387 0.09971577 0.10007905]
# P(I_IP_x5 | I_FP_x5, I_IP_x4) = N(0*I_FP_x5 + 0*I_IP_x4 + 0; 1)
# Beta values: [4.43761222 0.50212775 0.49777351]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_x5', 'I_IP_x4']
# Evidence vals: [[4681.44859153]
#  [6168.97885743]]
# Coeffecients to be used: [0.50212775 0.49777351]
# P(I_IP_y5 | I_FP_y5, I_IP_y4) = N(0*I_FP_y5 + 0*I_IP_y4 + 0; 1)
# Beta values: [-1.02514688  0.50430989  0.49669748]
# Mean vals: [0 0 0]
# Variance: 1
# Evidence required: ['I_FP_y5', 'I_IP_y4']
# Evidence vals: [[3.86804453]
#  [5.48625776]]
# Coeffecients to be used: [0.50430989 0.49669748]
#        P_FP_x0    P_FP_y0       P_V1     P_IP_x1   P_IP_y1  P_FP_x1  P_FP_y1  \
# 0    -5.037235  19.881080  38.951065  -12.384156 -0.107156      0.0      0.0
# 1   167.982155  18.565937  37.635044   74.782990 -0.107156      0.0      0.0
# 2   -90.031542  25.858521  44.932493  -57.869967 -0.107156      0.0      0.0
# 3   156.465611  20.251395  39.321626   68.181998 -0.107156      0.0      0.0
# 4   145.798144  16.340647  35.408270   64.803643 -0.107156      0.0      0.0
# ..         ...        ...        ...         ...       ...      ...      ...
# 95  113.318325  20.654525  39.725026   46.406820 -0.107156      0.0      0.0
# 96 -189.774810  19.862185  38.932157 -104.743368 -0.107156      0.0      0.0
# 97   21.762640  23.143816  42.215977   -0.615603 -0.107156      0.0      0.0
# 98   17.999259  32.531028  51.609450   -7.190890 -0.107156      0.0      0.0
# 99   -3.167208  20.992763  40.063489  -12.004984 -0.107156      0.0      0.0
#
#          I_FP_x0    I_FP_y0       P_V2  ...         I_V4      I_IP_x4  \
# 0    9994.471421  17.635307  59.562157  ...  2719.917136  6144.116048
# 1   10019.370528  23.181093  58.245563  ...  2731.320883  6156.719825
# 2   10039.704779  18.459558  65.546191  ...  2732.532421  6171.535612
# 3   10022.774452  24.342399  59.932879  ...  2733.232946  6158.245766
# 4   10004.903702  22.794195  56.017818  ...  2727.178213  6148.010595
# ..           ...        ...        ...  ...          ...          ...
# 95  10020.681832  25.931765  60.336455  ...  2734.074664  6156.181560
# 96  10043.786402  23.610508  59.543241  ...  2738.116739  6171.527820
# 97  10075.158085  20.372979  62.828491  ...  2743.530069  6192.407065
# 98  10034.316813  18.202617  72.226058  ...  2730.890713  6168.347154
# 99  10034.511224  17.155138  60.675065  ...  2730.024466  6168.978857
#
#      I_IP_y4      I_FP_x4   I_FP_y4         I_V5      I_IP_x5   I_IP_y5  \
# 0   5.546191  5301.669610  3.802049  3206.696148  5404.016040  3.703355
# 1   6.238404  5312.587432  4.406438  3219.103620  5415.098862  4.313160
# 2   5.649072  5325.412106  3.891877  3221.392117  5428.125364  3.793988
# 3   6.383356  5313.909659  4.533000  3221.141689  5416.440722  4.440855
# 4   6.190112  5305.046041  4.364273  3214.298920  5407.441042  4.270618
# ..       ...          ...       ...          ...          ...       ...
# 95  6.581737  5312.123633  4.706212  3221.841889  5414.625923  4.615619
# 96  6.292003  5325.409606  4.453237  3227.023009  5428.119153  4.360378
# 97  5.887901  5343.485678  4.100405  3233.985333  5446.477261  4.004385
# 98  5.617002  5322.651099  3.863875  3219.506984  5425.321814  3.765736
# 99  5.486258  5323.197209  3.749719  3218.678908  5425.877123  3.650557
#
#         I_FP_x5   I_FP_y5
# 0   4662.558907  3.913710
# 1   4672.136142  4.441134
# 2   4683.391438  3.992099
# 3   4673.295781  4.551578
# 4   4665.519110  4.404338
# ..          ...       ...
# 95  4671.727870  4.702732
# 96  4683.386792  4.481972
# 97  4699.249236  4.174072
# 98  4680.968907  3.967663
# 99  4681.448592  3.868045
#
# [100 rows x 54 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Create lists to store the actual and predicted values for comparison
actual_values = []
predicted_values = []

# Define the list of columns that we are interested in for comparison
columns_to_compare = [f'P_V{t}' for t in range(1,6)] + \
                     [f'P_IP_x{t}' for t in range(1,6)] + \
                     [f'P_IP_y{t}' for t in range(1,6)] + \
                     [f'P_FP_x{t}' for t in range(6)] + \
                     [f'P_FP_y{t}' for t in range(6)] + \
                     [f'I_V{t}' for t in range(1,6)] + \
                     [f'I_IP_x{t}' for t in range(1,6)] + \
                     [f'I_IP_y{t}' for t in range(1,6)] + \
                     [f'I_FP_x{t}' for t in range(6)] + \
                     [f'I_FP_y{t}' for t in range(6)]

# Iterate over each row in the test data
for index, row in test_data.iterrows():
    actual_row = []
    predicted_row = []

    # Get actual values and predicted values for the current row
    for col in columns_to_compare:
        actual_value = row[col]
        predicted_value = predictions_df.loc[index, col]
        
        actual_row.append(actual_value)
        predicted_row.append(predicted_value)

        # Print the column name and the corresponding values
        print(f"Column: {col}")
        print(f"  Actual: {actual_value}")
        print(f"  Predicted: {predicted_value}")
        print("-" * 30)

    # Print the row-wise summary
    print("=" * 50 + f" ROW {index} SUMMARY " + "=" * 50)
    print(f"Actual Values: {actual_row}")
    print(f"Predicted Values: {predicted_row}")
    print("\n")

    actual_values.extend(actual_row)
    predicted_values.extend(predicted_row)

# Convert the lists to numpy arrays for metric calculation
actual_values = np.array(actual_values)
predicted_values = np.array([val.flatten() if isinstance(val, np.ndarray) else [val] for val in predicted_values])

# Calculate accuracy metrics
mae = mean_absolute_error(actual_values, predicted_values)
mse = mean_squared_error(actual_values, predicted_values)
rmse = np.sqrt(mse)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Column: P_V1
#   Actual: 256.182700606756
#   Predicted: 38.95106469603663
# ------------------------------
# Column: P_V2
#   Actual: 585.6663019290754
#   Predicted: 59.562156573897944
# ------------------------------
# Column: P_V3
#   Actual: 1005.9033707974248
#   Predicted: 79.16360181760365
# ------------------------------
# Column: P_V4
#   Actual: 1507.4379982502985
#   Predicted: 99.19098384005147
# ------------------------------
# Column: P_V5
#   Actual: 2072.250300196497
#   Predicted: 117.14695052091596
# ------------------------------
# Column: P_IP_x1
#   Actual: 928.4775895313994
#   Predicted: -12.384156183789308
# ------------------------------
# Column: P_IP_x2
#   Actual: 1824.337103668978
#   Predicted: -5.55318827835016
# ------------------------------
# Column: P_IP_x3
#   Actual: 2652.559586506074
#   Predicted: -2.86349592725797
# ------------------------------
# Column: P_IP_x4
#   Actual: 3433.0887467691887
#   Predicted: -1.7973757768123795
# ------------------------------
# Column: P_IP_x5
#   Actual: 4148.650237963309
#   Predicted: -0.8052550180830857
# ------------------------------
# Column: P_IP_y1
#   Actual: 126.023890750098
#   Predicted: -0.10715580212155706
# ------------------------------
# Column: P_IP_y2
#   Actual: 287.44167132367335
#   Predicted: -0.4122178967080594
# ------------------------------
# Column: P_IP_y3
#   Actual: 394.6032631589221
#   Predicted: 1.9050057254889985
# ------------------------------
# Column: P_IP_y4
#   Actual: 478.7001657000101
#   Predicted: 1.8400994304990326
# ------------------------------
# Column: P_IP_y5
#   Actual: 528.8818019963044
#   Predicted: 2.339635069483715
# ------------------------------
# Column: P_FP_x0
#   Actual: 1004.385794815344
#   Predicted: -5.037235080727164
# ------------------------------
# Column: P_FP_x1
#   Actual: 1884.3877721255628
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x2
#   Actual: 2719.8074743968155
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x3
#   Actual: 3477.4471092153367
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x4
#   Actual: 4214.389339629583
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4865.650207133206
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 96.35631602074646
#   Predicted: 19.88108029173256
# ------------------------------
# Column: P_FP_y1
#   Actual: 247.04275989066733
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 406.69796886657775
#   Predicted: -0.05357790106077853
# ------------------------------
# Column: P_FP_y3
#   Actual: 533.6388636721256
#   Predicted: -0.2061089483540297
# ------------------------------
# Column: P_FP_y4
#   Actual: 576.5581334149435
#   Predicted: 0.9525028627444992
# ------------------------------
# Column: P_FP_y5
#   Actual: 576.4861080183965
#   Predicted: 0.9200497152495163
# ------------------------------
# Column: I_V1
#   Actual: 886.3427777767764
#   Predicted: 837.1396201238408
# ------------------------------
# Column: I_V2
#   Actual: 1680.114867031183
#   Predicted: 1546.204711233373
# ------------------------------
# Column: I_V3
#   Actual: 2405.7985537711334
#   Predicted: 2169.5035563639303
# ------------------------------
# Column: I_V4
#   Actual: 3061.157189501288
#   Predicted: 2719.9171357314535
# ------------------------------
# Column: I_V5
#   Actual: 3624.32457493427
#   Predicted: 3206.696147900982
# ------------------------------
# Column: I_IP_x1
#   Actual: 9091.254909126958
#   Predicted: 8981.693772273857
# ------------------------------
# Column: I_IP_x2
#   Actual: 8203.951131217695
#   Predicted: 7934.593205853587
# ------------------------------
# Column: I_IP_x3
#   Actual: 7381.971938001735
#   Predicted: 6983.323806234063
# ------------------------------
# Column: I_IP_x4
#   Actual: 6604.085893355305
#   Predicted: 6144.116047883909
# ------------------------------
# Column: I_IP_x5
#   Actual: 5712.616831913098
#   Predicted: 5404.016039722937
# ------------------------------
# Column: I_IP_y1
#   Actual: 167.45546677694043
#   Predicted: 2.8583068755295136
# ------------------------------
# Column: I_IP_y2
#   Actual: 319.1575197970676
#   Predicted: 5.336133599709915
# ------------------------------
# Column: I_IP_y3
#   Actual: 457.5600720834847
#   Predicted: 5.460317367432184
# ------------------------------
# Column: I_IP_y4
#   Actual: 517.7172471339262
#   Predicted: 5.546191358205518
# ------------------------------
# Column: I_IP_y5
#   Actual: 545.2273461248786
np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(19.88108029173256), np.float64(0.0), np.float64(-0.05357790106077853), np.float64(-0.2061089483540297), np.float64(0.9525028627444992), np.float64(0.9200497152495163), np.float64(837.1396201238408), np.float64(1546.204711233373), np.float64(2169.5035563639303), np.float64(2719.9171357314535), np.float64(3206.696147900982), np.float64(8981.693772273857), np.float64(7934.593205853587), np.float64(6983.323806234063), np.float64(6144.116047883909), np.float64(5404.016039722937), np.float64(2.8583068755295136), np.float64(5.336133599709915), np.float64(5.460317367432184), np.float64(5.546191358205518), np.float64(3.7033551501620403), np.float64(9994.471421482887), np.float64(7986.759483643864), np.float64(6886.8747312300875), np.float64(6033.359022295819), np.float64(5301.669609805777), np.float64(4662.558906883688), np.float64(17.635307084891124), np.float64(5.290592125467337), np.float64(3.016331075404958), np.float64(3.5729661224764446), np.float64(3.8020485204590253), np.float64(3.9137102352404662)]
#
#
# Column: P_V1
#   Actual: 258.8337893921987
#   Predicted: 37.63504437237147
# ------------------------------
# Column: P_V2
#   Actual: 599.8524717803157
#   Predicted: 58.24556283512184
# ------------------------------
# Column: P_V3
#   Actual: 1031.0343135636936
#   Predicted: 77.84890666289843
# ------------------------------
# Column: P_V4
#   Actual: 1532.6032405390783
#   Predicted: 97.87638599210024
# ------------------------------
# Column: P_V5
#   Actual: 2102.016335947628
#   Predicted: 115.8314133910592
# ------------------------------
# Column: P_IP_x1
#   Actual: 1027.4155649599609
#   Predicted: 74.78298970599417
# ------------------------------
# Column: P_IP_x2
#   Actual: 1891.3784491628355
#   Predicted: 38.03369013525184
# ------------------------------
# Column: P_IP_x3
#   Actual: 2701.070621247108
#   Predicted: 18.931775625002917
# ------------------------------
# Column: P_IP_x4
#   Actual: 3452.844643668038
#   Predicted: 9.096321444657898
# ------------------------------
# Column: P_IP_x5
#   Actual: 4180.675052514738
#   Predicted: 4.642156054343827
# ------------------------------
# Column: P_IP_y1
#   Actual: 100.43892413717552
#   Predicted: -0.10715580212155706
# ------------------------------
# Column: P_IP_y2
#   Actual: 284.77942894446085
#   Predicted: -0.4122178967080594
# ------------------------------
# Column: P_IP_y3
#   Actual: 418.9548008404415
#   Predicted: 1.9050057254889985
# ------------------------------
# Column: P_IP_y4
#   Actual: 527.7110429045692
#   Predicted: 1.8400994304990326
# ------------------------------
# Column: P_IP_y5
#   Actual: 552.6183901631512
#   Predicted: 2.339635069483715
# ------------------------------
# Column: P_FP_x0
#   Actual: 991.239773750281
#   Predicted: 167.98215486038458
# ------------------------------
# Column: P_FP_x1
#   Actual: 1908.3186193516813
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x2
#   Actual: 2750.6819994873663
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x3
#   Actual: 3504.4010013557986
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x4
#   Actual: 4205.958600675069
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4908.995042017888
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 100.40698315716112
#   Predicted: 18.56593719125345
# ------------------------------
# Column: P_FP_y1
#   Actual: 282.42097025461305
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 447.6726352733816
#   Predicted: -0.05357790106077853
# ------------------------------
# Column: P_FP_y3
#   Actual: 595.679192710195
#   Predicted: -0.2061089483540297
# ------------------------------
# Column: P_FP_y4
#   Actual: 637.5454896911233
#   Predicted: 0.9525028627444992
# ------------------------------
# Column: P_FP_y5
#   Actual: 598.2767628569728
#   Predicted: 0.9200497152495163
# ------------------------------
# Column: I_V1
#   Actual: 888.5639561145448
#   Predicted: 844.551175553881
# ------------------------------
# Column: I_V2
#   Actual: 1684.2210927804929
#   Predicted: 1555.139994044474
# ------------------------------
# Column: I_V3
#   Actual: 2410.778361455876
#   Predicted: 2179.7529192448314
# ------------------------------
# Column: I_V4
#   Actual: 3065.8485441988564
#   Predicted: 2731.320883344592
# ------------------------------
# Column: I_V5
#   Actual: 3632.2522257687615
#   Predicted: 3219.103619687931
# ------------------------------
# Column: I_IP_x1
#   Actual: 9065.861746899232
#   Predicted: 8999.9789715904
# ------------------------------
# Column: I_IP_x2
#   Actual: 8185.44958611225
#   Predicted: 7950.8788811845125
# ------------------------------
# Column: I_IP_x3
#   Actual: 7353.397226000918
#   Predicted: 6997.702175430638
# ------------------------------
# Column: I_IP_x4
#   Actual: 6568.732452811432
#   Predicted: 0.9200497152495163
# ------------------------------
# Column: I_V1
#   Actual: 877.1629558106443
#   Predicted: 841.5536165939865
# ------------------------------
# Column: I_V2
#   Actual: 1672.0403352156306
#   Predicted: 1553.719712250086
# ------------------------------
# Column: I_V3
#   Actual: 2393.905017580387
#   Predicted: 2179.7323409125047
# ------------------------------
# Column: I_V4
#   Actual: 3047.766861689466
#   Predicted: 2732.5324208275074
# ------------------------------
# Column: I_V5
#   Actual: 3612.035295199116
#   Predicted: 3221.3921172427163
# ------------------------------
# Column: I_IP_x1
#   Actual: 9114.43448610514
#   Predicted: 9021.864588424523
# ------------------------------
# Column: I_IP_x2
#   Actual: 8214.250865505912
#   Predicted: 7970.087617085875
# ------------------------------
# Column: I_IP_x3
#   Actual: 7368.229894059647
#   Predicted: 7014.613274776774
# ------------------------------
# Column: I_IP_x4
#   Actual: 6548.815030028888
#   Predicted: 6171.535612104247
# ------------------------------
# Column: I_IP_x5
#   Actual: 5670.435701120381
#   Predicted: 5428.125364307941
# ------------------------------
# Column: I_IP_y1
#   Actual: 115.21109218545465
#   Predicted: 2.9816703647433944
# ------------------------------
# Column: I_IP_y2
#   Actual: 281.3226433272399
#   Predicted: 5.464819018809222
# ------------------------------
# Column: I_IP_y3
#   Actual: 396.81565408911104
#   Predicted: 5.576912810458421
# ------------------------------
# Column: I_IP_y4
#   Actual: 487.3455516315628
#   Predicted: 5.649072467508614
# ------------------------------
# Column: I_IP_y5
#   Actual: 483.43440886222027
#   Predicted: 3.79398831101118
# ------------------------------
# Column: I_FP_x0
#   Actual: 9005.434695278987
#   Predicted: 10039.704778738864
# ------------------------------
# Column: I_FP_x1
#   Actual: 8145.230103625445
#   Predicted: 8022.53404421498
# ------------------------------
# Column: I_FP_x2
#   Actual: 7306.785838059415
#   Predicted: 6917.692507476755
# ------------------------------
# Column: I_FP_x3
#   Actual: 6520.308275539322
#   Predicted: 6060.351560785964
# ------------------------------
# Column: I_FP_x4
#   Actual: 5772.65481353546
#   Predicted: 5325.412105624177
# ------------------------------
# Column: I_FP_x5
#   Actual: 4848.863260458726
#   Predicted: 4683.391437739377
# ------------------------------
# Column: I_FP_y0
#   Actual: 124.75096340418564
#   Predicted: 18.459557552220968
# ------------------------------
# Column: I_FP_y1
#   Actual: 250.9083986584856
#   Predicted: 5.53786726566629
# ------------------------------
# Column: I_FP_y2
#   Actual: 433.0419771621983
#   Predicted: 3.152195362071584
# ------------------------------
# Column: I_FP_y3
#   Actual: 519.9911358004183
#   Predicted: 3.6780681180260864
# ------------------------------
# Column: I_FP_y4
#   Actual: 547.5401483807813
#   Predicted: 3.8918768406370363
# ------------------------------
# Column: I_FP_y5
#   Actual: 560.1024230600469
#   Predicted: 3.992099285945418
# ------------------------------
# ================================================== ROW 2 SUMMARY ==================================================
# Actual Values: [np.float64(264.4007020426253), np.float64(603.1251696454458), np.float64(1030.1553861521409), np.float64(1532.345140332941), np.float64(2099.2284520998483), np.float64(905.3554733588672), np.float64(1830.9883683290705), np.float64(2675.0430735932164), np.float64(3442.739732292567), np.float64(4158.877938432193), np.float64(140.97724378588467), np.float64(298.6897910763534), np.float64(420.46332400728977), np.float64(521.6060905516604), np.float64(546.2873838609108), np.float64(1005.4523794810544), np.float64(1925.6560755406929), np.float64(2755.917701785003), np.float64(3520.9438255532814), np.float64(4214.153896578211), np
#   Predicted: 2.339635069483715
# ------------------------------
# Column: P_FP_x0
#   Actual: 1037.406677391785
#   Predicted: 156.4656107398267
# ------------------------------
# Column: P_FP_x1
#   Actual: 1941.4665590457123
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x2
#   Actual: 2744.8126057476807
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x3
#   Actual: 3507.474257162187
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x4
#   Actual: 4226.2364445430485
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4906.509490237057
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 118.93336202038176
#   Predicted: 20.25139468228301
# ------------------------------
# Column: P_FP_y1
#   Actual: 265.76449958027786
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 428.8821417071292
#   Predicted: -0.05357790106077853
# ------------------------------
# Column: P_FP_y3
#   Actual: 584.7401132512769
#   Predicted: -0.2061089483540297
# ------------------------------
# Column: P_FP_y4
#   Actual: 634.9404300576934
#   Predicted: 0.9525028627444992
# ------------------------------
# Column: P_FP_y5
#   Actual: 626.8917564614717
#   Predicted: 0.9200497152495163
# ------------------------------
# Column: I_V1
#   Actual: 881.0012486564865
#   Predicted: 845.9588206440086
# ------------------------------
# Column: I_V2
#   Actual: 1679.8610823237286
#   Predicted: 1556.74143774807
# ------------------------------
# Column: I_V3
#   Actual: 2407.4315322762154
#   Predicted: 2181.5197782147384
# ------------------------------
# Column: I_V4
#   Actual: 3059.444847383407
#   Predicted: 2733.2329457424003
# ------------------------------
# Column: I_V5
#   Actual: 3633.613512856748
#   Predicted: 3221.1416885714357
# ------------------------------
# Column: I_IP_x1
#   Actual: 9067.2800524696
#   Predicted: 9002.175711086295
# ------------------------------
# Column: I_IP_x2
#   Actual: 8189.887691080304
#   Predicted: 7952.847764175551
# ------------------------------
# Column: I_IP_x3
#   Actual: 7365.424193974099
#   Predicted: 6999.442563213988
# ------------------------------
# Column: I_IP_x4
#   Actual: 6524.866675084416
#   Predicted: 6158.24576646758
# ------------------------------
# Column: I_IP_x5
#   Actual: 5714.092326459306
#   Predicted: 5416.440721753871
# ------------------------------
# Column: I_IP_y1
#   Actual: 135.86110852681054
#   Predicted: 3.8621404520310247
# ------------------------------
# Column: I_IP_y2
#   Actual: 269.527007819109
#   Predicted: 6.383272792361077
# ------------------------------
# Column: I_IP_y3
#   Actual: 421.9787194317762
#   Predicted: 6.409077987958118
# ------------------------------
# Column: I_IP_y4
#   Actual: 543.8612263883169
#   Predicted: 6.383355681007029
# ------------------------------
# Column: I_IP_y5
#   Actual: 569.962765977751
#   Predicted: 4.440855447734615
# ------------------------------
# Column: I_FP_x0
#   Actual: 8840.68392065801
#   Predicted: 10022.774451658355
# ------------------------------
# Column: I_FP_x1
#   Actual: 8137.49618939761
#   Predicted: 8006.048361691203
# ------------------------------
# Column: I_FP_x2
#   Actual: 7306.2045427961875
#   Predicted: 6902.902364050508
# ------------------------------
# Column: I_FP_x3
#   Actual: 6547.969269330624
#   Predicted: 6047.294591302928
# ------------------------------
# Column: I_FP_x4
#   Actual: 5735.970315874453
#   Predicted: 5313.909658997873
# ------------------------------
# Column: I_FP_x5
#   Actual: 4912.441072450802
#   Predicted: 4673.295780933152
# ------------------------------
# Column: I_FP_y0
#   Actual: 131.04523470356202
#   Predicted: 24.34239927096119
# ------------------------------
# Column: I_FP_y1
#   Actual: 261.943271745169
#   Predicted: 7.302719781288357
# ------------------------------
# Column: I_FP_y2
#   Actual: 430.5399865140579
#   Predicted: 4.12188616040202
# ------------------------------
# Column: I_FP_y3
#   Actual: 566.3185351863273
#   Predicted: 4.428202244301144
# ------------------------------
# Column: I_FP_y4
#   Actual: 587.8682877227857
#   Predicted: 4.532999667269403
# ------------------------------
# Column: I_FP_y5
#   Actual: 595.9371403953177
#   Predicted: 4.551577740684335
# ------------------------------
# Column: P_IP_x2
#   Actual: 1843.304852715032
#   Predicted: 33.04363842219059
# ------------------------------
# Column: P_IP_x3
#   Actual: 2634.8547885365065
#   Predicted: 16.436539992068617
# ------------------------------
# Column: P_IP_x4
#   Actual: 3394.4544349448106
#   Predicted: 7.849154534338292
# ------------------------------
# Column: P_IP_x5
#   Actual: 4101.634359119689
#   Predicted: 4.0185082056548085
# ------------------------------
# Column: P_IP_y1
#   Actual: 140.2669343965175
#   Predicted: -0.10715580212155706
# ------------------------------
# Column: P_IP_y2
#   Actual: 322.01746455837616
#   Predicted: -0.4122178967080594
# ------------------------------
# Column: P_IP_y3
#   Actual: 473.0365013322991
#   Predicted: 1.9050057254889985
# ------------------------------
# Column: P_IP_y4
#   Actual: 579.0428919842456
#   Predicted: 1.8400994304990326
# ------------------------------
# Column: P_IP_y5
#   Actual: 594.5903002594747
#   Predicted: 2.339635069483715
# ------------------------------
# Column: P_FP_x0
#   Actual: 980.462983069387
#   Predicted: 145.79814389753892
# ------------------------------
# Column: P_FP_x1
#   Actual: 1880.699268548111
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x2
#   Actual: 2677.389187410809
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x3
#   Actual: 3421.726490743663
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x4
#   Actual: 4157.268259101263
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4820.540278004655
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 110.89508577396808
#   Predicted: 16.340646992830433
# ------------------------------
# Column: P_FP_y1
#   Actual: 300.68815735562254
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 456.6138601040462
#   Predicted: -0.05357790106077853
# ------------------------------
# Column: P_FP_y3
#   Actual: 563.6803372848724
#   Predicted: -0.2061089483540297
# ------------------------------
# Column: P_FP_y4
#   Actual: 648.3445255232772
#   Predicted: 0.9525028627444992
# ------------------------------
# Column: P_FP_y5
#   Actual: 626.6463692848585
#   Predicted: 0.9200497152495163
# ------------------------------
# Column: I_V1
#   Actual: 893.8076344843943
#   Predicted: 843.0188499663432
# ------------------------------
# Column: I_V2
#   Actual: 1701.3205555242212
#   Predicted: 1552.6203215638166
# ------------------------------
# Column: I_V3
#   Actual: 2433.694377859222
#   Predicted: 2176.3696586278743
# ------------------------------
# Column: I_V4
#   Actual: 3094.6719897862868
#   Predicted: 2727.1782130031584
# ------------------------------
# Column: I_V5
#   Actual: 3661.098852257528
#   Predicted: 3214.2989197674106
# ------------------------------
# Column: I_IP_x1
#   Actual: 9100.3562821696
#   Predicted: 8987.22393817237
# ------------------------------
# Column: I_IP_x2
#   Actual: 8300.46810242588
#   Predicted: 7939.605573541196
# ------------------------------
# Column: I_IP_x3
#   Actual: 7455.367906475893
#   Predicted: 6987.763857929206
# ------------------------------
# Column: I_IP_x4
#   Actual: 6655.680486349063
#   Predicted: 6148.0105952567155
# ------------------------------
# Column: I_IP_x5
#   Actual: 5743.724413669447
#   Predicted: 5407.441042266472
# ------------------------------
# Column: I_IP_y1
#   Actual: 163.95071585374478
#   Predicted: 3.630424561453572
# ------------------------------
# Column: I_IP_y2
#   Actual: 291.5381644687356
#   Predicted: 6.141560623866628
# ------------------------------
# Column: I_IP_y3
#   Actual: 433.41083970333335
#   Predicted: 6.190074641909299
# ------------------------------
# Column: I_IP_y4
#   Actual: 508.1337231654672
#   Predicted: 6.190112217988305
# ------------------------------
# Column: I_IP_y5
#   Actual: 585.2059288480411
#   Predicted: 4.270617529564213
# ------------------------------
# Column: I_FP_x0
#   Actual: 9034.450952593144
#   Predicted: 10004.903701766598
# ------------------------------
# Column: I_FP_x1
#   Actual: 8231.259514511728
#   Predicted: 7992.525864116801
# ------------------------------
# Column: I_FP_x2
#   Actual: 7420.125700077224
#   Predicted: 6891.369728321226
# ------------------------------
# Column: I_FP_x3
#   Actual: 6562.246870702965
#   Predicted: 6037.213705266966
# ------------------------------
# Column: I_FP_x4
#   Actual: 5830.235871048927
#   Predicted: 5305.046040544693
# ------------------------------
# Column: I_FP_x5
#   Actual: 4817.509594292909
#   Predicted: 4665.519109791766
# ------------------------------
# Column: I_FP_y0
#
#
# Column: P_V1
#   Actual: 252.67589796373343
#   Predicted: 32.59558850021779
# ------------------------------
# Column: P_V2
#   Actual: 586.9068030822413
#   Predicted: 53.20391117609765
# ------------------------------
# Column: P_V3
#   Actual: 1005.1259001690192
#   Predicted: 72.81452527962352
# ------------------------------
# Column: P_V4
#   Actual: 1503.2834021547253
#   Predicted: 92.84237722700146
# ------------------------------
# Column: P_V5
#   Actual: 2063.512930330729
#   Predicted: 110.79380782002266
# ------------------------------
# Column: P_IP_x1
#   Actual: 991.4074181077872
#   Predicted: 40.063569319376484
# ------------------------------
# Column: P_IP_x2
#   Actual: 1843.944215809049
#   Predicted: 20.672663345459828
# ------------------------------
# Column: P_IP_x3
#   Actual: 2657.5819275663985
#   Predicted: 10.250532391224773
# ------------------------------
# Column: P_IP_x4
#   Actual: 3406.2304017190067
#   Predicted: 4.75726858780526
# ------------------------------
# Column: P_IP_x5
#   Actual: 4116.027065827323
#   Predicted: 2.472405592610823
# ------------------------------
# Column: P_IP_y1
#   Actual: 133.59445602308926
#   Predicted: -0.10715580212155706
# ------------------------------
# Column: P_IP_y2
#   Actual: 283.7731063314721
#   Predicted: -0.4122178967080594
# ------------------------------
# Column: P_IP_y3
#   Actual: 420.7836823860795
#   Predicted: 1.9050057254889985
# ------------------------------
# Column: P_IP_y4
#   Actual: 510.1948636227725
#   Predicted: 1.8400994304990326
# ------------------------------
# Column: P_IP_y5
#   Actual: 558.6485030118167
#   Predicted: 2.339635069483715
# ------------------------------
# Column: P_FP_x0
#   Actual: 999.4132236778933
#   Predicted: 93.50712128184185
# ------------------------------
# Column: P_FP_x1
#   Actual: 1907.9152300482172
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x2
#   Actual: 2699.5852891856
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x3
#   Actual: 3470.0651572230217
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x4
#   Actual: 4157.100330502846
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4826.879437670782
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 98.31338619486802
#   Predicted: 13.529840482675493
# ------------------------------
# Column: P_FP_y1
#   Actual: 252.92707388518733
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 401.586458129646
#   Predicted: -0.05357790106077853
# ------------------------------
# Column: P_FP_y3
#   Actual: 551.982679467902
# ...
#   Actual: 461.91850612542953
#   Predicted: -0.05357790106077853
# ------------------------------
# Column: P_FP_y3
#   Actual: 625.8793291758279
#   Predicted: -0.2061089483540297
# ------------------------------
# Column: P_FP_y4
#   Actual: 687.5123353702318
#   Predicted: 0.9525028627444992
# ------------------------------
# Column: P_FP_y5
#   Actual: 684.2179913648085
#   Predicted: 0.9200497152495163
# ------------------------------
# Column: I_V1
#   Actual: 891.0046790922534
#   Predicted: 840.8725207525504
# ------------------------------
# Column: I_V2
#   Actual: 1697.1754926577014
#   Predicted: 1552.6749539559567
# ------------------------------
# Column: I_V3
#   Actual: 2437.66479722686
#   Predicted: 2178.3699347630227
# ------------------------------
# Column: I_V4
#   Actual: 3116.522119756563
#   Predicted: 2730.8907131767323
# ------------------------------
# Column: I_V5
#   Actual: 3682.134917196108
#   Predicted: 3219.5069841727495
# ------------------------------
# Column: I_IP_x1
#   Actual: 9140.577318322565
#   Predicted: 9017.198970588832
# ------------------------------
# Column: I_IP_x2
#   Actual: 8229.788630327248
#   Predicted: 7965.961112376543
# ------------------------------
# Column: I_IP_x3
#   Actual: 7434.254360152898
#   Predicted: 7010.974941185479
# ------------------------------
# Column: I_IP_x4
#   Actual: 6649.378740472021
#   Predicted: 6168.347153821185
# ------------------------------
# Column: I_IP_x5
#   Actual: 5701.843189851105
#   Predicted: 5425.321814124695
# ------------------------------
# Column: I_IP_y1
#   Actual: 118.5366324423531
#   Predicted: 2.9432146953087885
# ------------------------------
# Column: I_IP_y2
#   Actual: 277.0695850421702
#   Predicted: 5.424704362767377
# ------------------------------
# Column: I_IP_y3
#   Actual: 415.0949059465918
#   Predicted: 5.5405669204129095
# ------------------------------
# Column: I_IP_y4
#   Actual: 560.5857888582909
#   Predicted: 5.617001698793843
# ------------------------------
# Column: I_IP_y5
#   Actual: 659.5888657966026
#   Predicted: 3.765735552471047
# ------------------------------
# Column: I_FP_x0
#   Actual: 9056.90893401065
#   Predicted: 10034.316813210915
# ------------------------------
# Column: I_FP_x1
#   Actual: 8228.745101180142
#   Predicted: 8018.35214215166
# ------------------------------
# Column: I_FP_x2
#   Actual: 7385.951423183496
#   Predicted: 6914.105127939914
# ------------------------------
# Column: I_FP_x3
#   Actual: 6643.735638520523
#   Predicted: 6057.212094570245
# ------------------------------
# Column: I_FP_x4
#   Actual: 5877.995689928077
#   Predicted: 5322.651098963814
# ------------------------------
# Column: I_FP_x5
#   Actual: 4759.503090596167
#   Predicted: 4680.968906599736
# ------------------------------
# Column: I_FP_y0
#   Actual: 134.92317248172915
#   Predicted: 18.202616834145125
# ------------------------------
# Column: I_FP_y1
#   Actual: 264.9864605062048
#   Predicted: 5.460785050243538
# ------------------------------
# Column: I_FP_y2
#   Actual: 460.12740536948615
#   Predicted: 3.1098428627274552
# ------------------------------
# Column: I_FP_y3
#   Actual: 546.3430979092483
#   Predicted: 3.645305040201925
# ------------------------------
# Column: I_FP_y4
#   Actual: 681.4197998716354
#   Predicted: 3.8638749722670322
# ------------------------------
# Column: I_FP_y5
#   Actual: 718.4850272302314
#   Predicted: 3.9676633410770314
# ------------------------------
# ================================================== ROW 98 SUMMARY ==================================================
# Actual Values: [np.float64(268.08164945707153), np.float64(604.5255681124429), np.float64(1030.177965484217), np.float64(1536.8779784384076), np.float64(2101.869275408233), np.float64(945.703983173794), np.float64(1822.4742694932152), np.float64(2627.0862159786675), np.float64(3382.912959924716), np.float64(4084.824800202764), np.float64(161.86828013617355), np.float64(324.63983871264725), np.float64(467.0784692926407), np.float64(559.1257766755127), np.float64(633.2517673543451), np.float64(1012.1256244276416), np.float64(1906.121591182275), np.float64(2697.4678438436986), np.float64(3431.451345524852), np.float64(4138.344790099513), np.float64(4790.999126388902), np.float64(107.39136071732662), np.float64(279.4165229319358), np.float64(461.91850612542953), np.float64(625.8793291758279), np.float64(687.5123353702318), np.float64(684.2179913648085), np.float64(891.0046790922534), np.float64(1697.1754926577014), np.float64(2437.66479722686), np.float64(3116.522119756563), np.float64(3682.134917196108), np.float64(9140.577318322565), np.float64(8229.788630327248), np.float64(7434.254360152898), np.float64(6649.378740472021), np.float64(5701.843189851105), np.float64(118.5366324423531), np.float64(277.0695850421702), np.float64(415.0949059465918), np.float64(560.5857888582909), np.float64(659.5888657966026), np.float64(9056.90893401065), np.float64(8228.745101180142), np.float64(7385.951423183496), np.float64(6643.735638520523), np.float64(5877.995689928077), np.float64(4759.503090596167), np.float64(134.92317248172915), np.float64(264.9864605062048), np.float64(460.12740536948615), np.float64(546.3430979092483), np.float64(681.4197998716354), np.float64(718.4850272302314)]
# Predicted Values: [np.float64(51.609450228048736), np.float64(72.22605760549138), np.float64(91.80924096622927), np.float64(111.83568702561888), np.float64(129.80068836367636), np.float64(-7.1908903861676885), np.float64(-2.9563584455062015), np.float64(-1.5649718429045514), np.float64(-1.1483483868202737), np.float64(-0.4807078126051127), np.float64(-0.10715580212155706), np.float64(-0.4122178967080594), np.float64(1.9050057254889985), np.float64(1.8400994304990326), np.float64(2.339635069483715), np.float64(17.99925868660539), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(32.53102808985329), np.float64(0.0), np.float64(-0.05357790106077853), np.float64(-0.2061089483540297), np.float64(0.9525028627444992), np.float64(0.9200497152495163), np.float64(840.8725207525504), np.float64(1552.6749539559567), np.float64(2178.3699347630227), np.float64(2730.8907131767323), np.float64(3219.5069841727495), np.float64(9017.198970588832), np.float64(7965.961112376543), np.float64(7010.974941185479), np.float64(6168.347153821185), np.float64(5425.321814124695), np.float64(2.9432146953087885), np.float64(5.424704362767377), np.float64(5.5405669204129095), np.float64(5.617001698793843), np.float64(3.765735552471047), np.float64(10034.316813210915), np.float64(8018.35214215166), np.float64(6914.105127939914), np.float64(6057.212094570245), np.float64(5322.651098963814), np.float64(4680.968906599736), np.float64(18.202616834145125), np.float64(5.460785050243538), np.float64(3.1098428627274552), np.float64(3.645305040201925), np.float64(3.8638749722670322), np.float64(3.9676633410770314)]
#
#
# Column: P_V1
#   Actual: 249.75079607296564
#   Predicted: 40.06348862031797
# ------------------------------
# Column: P_V2
#   Actual: 574.8770852962967
#   Predicted: 60.675065202462704
# ------------------------------
# Column: P_V3
#   Actual: 989.774836335439
#   Predicted: 80.27490558467447
# ------------------------------
# Column: P_V4
#   Actual: 1482.1557698966096
#   Predicted: 100.30220535431876
# ------------------------------
# Column: P_V5
#   Actual: 2046.1678427984496
#   Predicted: 118.25896600442867
# ------------------------------
# Column: P_IP_x1
#   Actual: 918.049126864872
#   Predicted: -12.004984182630634
# ------------------------------
# Column: P_IP_x2
#   Actual: 1799.423200980555
#   Predicted: -5.3635878991747035
# ------------------------------
# Column: P_IP_x3
#   Actual: 2622.994019816804
#   Predicted: -2.7686877670743506
# ------------------------------
# Column: P_IP_x4
#   Actual: 3389.6202526388624
#   Predicted: -1.7499888292036507
# ------------------------------
# Column: P_IP_x5
#   Actual: 4098.477448290715
#   Predicted: -0.7815590976031641
# ------------------------------
# Column: P_IP_y1
#   Actual: 82.38398055276824
#   Predicted: -0.10715580212155706
# ------------------------------
# Column: P_IP_y2
#   Actual: 206.92714217978028
#   Predicted: -0.4122178967080594
# ------------------------------
# Column: P_IP_y3
#   Actual: 363.2845468225444
#   Predicted: 1.9050057254889985
# ------------------------------
# Column: P_IP_y4
#   Actual: 475.471046191686
#   Predicted: 1.8400994304990326
# ------------------------------
# Column: P_IP_y5
#   Actual: 560.513887125147
#   Predicted: 2.339635069483715
# ------------------------------
# Column: P_FP_x0
#   Actual: 970.1478445836788
#   Predicted: -3.167207616042468
# ------------------------------
# Column: P_FP_x1
#   Actual: 1861.5918207727336
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x2
#   Actual: 2681.815303979025
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x3
#   Actual: 3447.234634702455
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x4
#   Actual: 4156.945536884912
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_x5
#   Actual: 4817.923982720155
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y0
#   Actual: 84.18739450500152
#   Predicted: 20.992762704624173
# ------------------------------
# Column: P_FP_y1
#   Actual: 236.08962726840957
#   Predicted: 0.0
# ------------------------------
# Column: P_FP_y2
#   Actual: 388.8474675909904
#   Predicted: -0.05357790106077853
# ------------------------------
# Column: P_FP_y3
#   Actual: 519.810393576488
#   Predicted: -0.2061089483540297
# ------------------------------
# Column: P_FP_y4
#   Actual: 605.0522518499585
#   Predicted: 0.9525028627444992
# ------------------------------
# Column: P_FP_y5
#   Actual: 610.1177425739656
#   Predicted: 0.9200497152495163
# ------------------------------
# Column: I_V1
#   Actual: 885.2876261642976
#   Predicted: 839.8632244106761
# ------------------------------
# Column: I_V2
#   Actual: 1693.477644881997
#   Predicted: 1551.7168086977238
# ------------------------------
# Column: I_V3
#   Actual: 2424.1082799755904
#   Predicted: 2177.460553511662
# ------------------------------
# Column: I_V4
#   Actual: 3088.366706333076
#   Predicted: 2730.024466162701
# ------------------------------
# Column: I_V5
#   Actual: 3656.071234194597
#   Predicted: 3218.6789080520302
# ------------------------------
# Column: I_IP_x1
#   Actual: 9129.160289984406
#   Predicted: 9018.161567666351
# ------------------------------
# Column: I_IP_x2
#   Actual: 8243.416143402825
#   Predicted: 7966.785001728795
# ------------------------------
# Column: I_IP_x3
#   Actual: 7400.569599064317
#   Predicted: 7011.696681012134
# ------------------------------
# Column: I_IP_x4
#   Actual: 6622.902666146798
#   Predicted: 6168.978857434448
# ------------------------------
# Column: I_IP_x5
#   Actual: 5722.465732923856
#   Predicted: 5425.877122566259
# ------------------------------
# Column: I_IP_y1
#   Actual: 140.80384243343292
#   Predicted: 2.7864412240493017
# ------------------------------
# Column: I_IP_y2
#   Actual: 296.4598311865593
#   Predicted: 5.261167647153709
# ------------------------------
# Column: I_IP_y3
#   Actual: 396.32858201405793
#   Predicted: 5.392394455020254
# ------------------------------
# Column: I_IP_y4
#   Actual: 520.0514732186379
#   Predicted: 5.486257758789767
# ------------------------------
# Column: I_IP_y5
#   Actual: 537.8811028057528
#   Predicted: 3.6505566180222617
# ------------------------------
# Column: I_FP_x0
#   Actual: 9093.917399209897
#   Predicted: 10034.511224229564
# ------------------------------
# Column: I_FP_x1
#   Actual: 8212.904679636062
#   Predicted: 8019.0314102340635
# ------------------------------
# Column: I_FP_x2
#   Actual: 7409.334425921281
#   Predicted: 6914.790206903395
# ------------------------------
# Column: I_FP_x3
#   Actual: 6565.16564202945
#   Predicted: 6057.829562935416
# ------------------------------
# Column: I_FP_x4
#   Actual: 5845.71613373409
#   Predicted: 5323.197209386692
# ------------------------------
# Column: I_FP_x5
#   Actual: 4842.308152265632
#   Predicted: 4681.448591533232
# ------------------------------
# Column: I_FP_y0
#   Actual: 143.61498557503683
#   Predicted: 17.15513829917504
# ------------------------------
# Column: I_FP_y1
#   Actual: 276.3944906223027
#   Predicted: 5.1465414897525115
# ------------------------------
# Column: I_FP_y2
#   Actual: 431.36062612767495
#   Predicted: 2.937183058950404
# ------------------------------
# Column: I_FP_y3
#   Actual: 531.1730554752588
#   Predicted: 3.5117387412619756
# ------------------------------
# Column: I_FP_y4
#   Actual: 599.469640450749
#   Predicted: 3.7497188498887195
# ------------------------------
# Column: I_FP_y5
#   Actual: 624.9930248156935
#   Predicted: 3.8680445343614993
# ------------------------------
# ================================================== ROW 99 SUMMARY ==================================================
